# %%
from __future__ import print_function
 
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation,Flatten
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D,MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from keras.layers.recurrent import LSTM,GRU
from keras.layers.wrappers import Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils

from keras.models import model_from_json
import numpy as np
import json
import requests
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# ## turn back to main directory
# import os
# os.chdir("../")
# os.getcwd()

# %%
df_all = pd.read_csv('data/19999_question_category_a_v16.csv')
df_test = pd.read_csv('data/19999_test_question.csv')
print(f"df_all shape : {df_all.shape}")
print(f"df_test shape : {df_test.shape}")
# Out:
# df_all shape : (14243, 8)
# df_test shape : (27, 4)

# %%
mapping = df_all.category.astype('category').cat.categories
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
from NLP_JiebaSegmentor import JiebaSegmentor
jieba_dict_path1 = "jieba/dict_taiwan.txt"
jieba_dict_path2 = "jieba/userdict.txt"
jieba_dict_path3 = "jieba/dict.txt.big"
jieba_dict_path4 = "jieba/dict.txt.small"
jieba_dict_path5 = "jieba/dict_system.txt"
jieba_stopwords_path = "jieba/stopwords.txt"

js = JiebaSegmentor(dict_path=jieba_dict_path1,
                    userdict=[jieba_dict_path2,
                              jieba_dict_path3,
                              jieba_dict_path4],
                    stopwords=True,
                    stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /project/at081-group3/Project_19999/19999_CNN/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u1430022de19ce5d7760cc83d31504a1a.cache
# Loading model cost 0.529 seconds.
# Prefix dict has been built succesfully.

# %%
test_cut_raw_0 = js.lcut('FTP無法安裝', return_type='pandas')
test_cut_raw_0
# Out:
#   word
# 0  FTP
# 1   無法
# 2   安裝

# %%
# x_train=np.loadtxt("x_train.txt",dtype=int)
# y_train=np.loadtxt("y_train.txt",dtype=int)
 
# indices = np.arange(x_train.shape[0])
# np.random.shuffle(indices)
# x_train = x_train[indices]
# y_train = y_train[indices]
 
# print('Loading data...')
# #x_train=np.loadtxt("x_train.txt",dtype=int)
# #y_train=np.loadtxt("y_train.txt",dtype=int)
# x_test=x_train[20000:]
# y_test=y_train[20000:]
# x_train=x_train[:20000]
# y_train=y_train[:20000]
# #x_test=x_train
# #y_test=y_train
# print(len(x_train), 'train sequences')
# print(len(x_test), 'test sequences')
# print(x_train[:1])
# print('Pad sequences (samples x time)')

# %%
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0               無法會員登入,顯示訊息:無效的帳號或使用者不存在。帳號:96122401       CAMP       CAMP
# 1  因今天有事請假，要補登先前的加班，但開啟camp後，出勤表單顯示的內容看起來像測試的，沒有最...       CAMP       CAMP
# 2                           手機簽核BPM有問題,都顯示亂碼  #18227       CAMP       CAMP
# 3                     無法在手機上面使用CAMP進行表單簽核動作。分機：17132       CAMP       CAMP
# 4                                           無法打開報單資料       CAMP       CAMP
#
#   category_c category_d category  \
# 0       CAMP       CAMP     資訊系統
# 1       CAMP       CAMP     資訊系統
# 2       CAMP       CAMP     資訊系統
# 3       CAMP       CAMP     資訊系統
# 4       CAMP       CAMP     資訊系統
#
#                                    description_clean  category_target
# 0                              無法會員登入顯示訊息無效的帳號或不存在帳號                4
# 1  因有事請假要補登先前的加班但開啟camp後出勤表單顯示的內容像測試的沒有的時間也沒辦法使用已...                4
# 2                                      簽核bpm有問題都顯示亂碼                4
# 3                                無法在上面使用camp進行表單簽核動作                4
# 4                                           無法打開報單資料                4

# %%
# w_pandas = js.lcut('無法會員登入 顯示訊息 無效的帳號或不存在 帳號'.strip(), return_type='pandas')
# w_list = list(w_pandas['word'])
# w_list

# %%
df_test
# Out:
#                                 description    category  category_target  \
# 0                           218無法登入,logon失敗         SAP                1
# 1                                    無線網路不通          網路                3
# 2                   我的outlook薪資單打不開 # 19810  Outlook與郵件                0
# 3   MRO操作問題email:charles.huang@quantatw.com        資訊系統                4
# 4                             有關非法軟體安裝問題想詢問          其他                2
# 5                               電腦好像中毒了怎麼辦?          其他                2
# 6                               電腦變很慢是不是中毒?          其他                2
# 7                                 資訊需求單無法申請        資訊系統                4
# 8                       vendor data簽核流程簽到副總        資訊系統                4
# 9                                在職證明怎麼申請呢?        資訊系統                4
# 10                   CAMP密碼忘記了無法登入 很急,請盡快處理        資訊系統                4
# 11                           採購單簽核時發生錯誤!!!!        資訊系統                4
# 12                   sap168無法登入 #381-123456         SAP                1
# 13                       收發郵件,有漏信的問題啦,少很多信耶  Outlook與郵件                0
# 14                                 找不到研發服務雲        資訊系統                4
# 15                                   餐費儲值問題        資訊系統                4
# 16                              BMS怎麼系統無法登入        資訊系統                4
# 17                               異常SO單簽核有問題        資訊系統                4
# 18                               薪資系統金額顯示錯誤        資訊系統                4
# 19                                  FTP無法開啟          其他                2
# 20                            out look附件打不開  Outlook與郵件                0
# 21                    無法在手機上面使用CAMP進行表單簽核動作        資訊系統                4
# 22                              298無法logon         SAP                 1
# 23                     無法進入SAP268，請幫忙處理，謝謝！        SAP                 1
# 24    Office 所有相關都出現亂碼. 已將Office 進行移除重灌顯示亂碼          其他                2
# 25                        北棟一樓警衛電腦需要灌office          其他                2
# 26                            HP2014列印會出現亂碼          其他                2
#
#                         description_clean
# 0                              218logon失敗
# 1                                  無線網路不通
# 2                            我的outlook薪資單
# 3                                     mro
# 4                                非法軟體安裝問題
# 5                                   電腦中毒了
# 6                                電腦變很慢是中毒
# 7                                   資訊需求單
# 8                       vendor data簽核流程簽到
# 9                                   在職證明呢
# 10                              camp密碼忘記了
# 11                             採購單簽核時發生錯誤
# 12                                 sap168
# 13                         收發郵件有漏信的問題啦少信耶
# 14                                  研發服務雲
# 15                                 餐費儲值問題
# 16                                  bms系統
# 17                             異常so單簽核有問題
# 18                                 薪資系統金額
# 19                                    ftp
# 20                             out look附件
# 21                    無法在上面使用camp進行表單簽核動作
# 22                             298無法logon
# 23                                 sap268
# 24  office 所有相關都出現亂碼. 已將office 進行移除重灌顯示亂碼
# 25                      北棟一樓警衛電腦需要灌office
# 26                              hp列印會出現亂碼

# %%
def cut_to_word(s):
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        combie = combie + w
        if i < len(w_list) - 1:
            combie = combie + ','
            
    return combie    

# print (cut_to_word('可以幫我聯絡'.strip()))
df_all['cut_words'] = df_all['description_clean'].apply(lambda s: cut_to_word(s.strip()))
df_test['cut_words'] = df_test['description_clean'].apply(lambda s: cut_to_word(s.strip()))

# %%
# 資料打散
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)
df_all.head()
# Out:
#                                          description    category_a  \
# 0                 有線網路孔不通, 請幫忙檢查一下法務部的辦公室, 似乎都有相同的問題            網管
# 1   因客人因素，我們部門都會有MAC電腦使用需求。於是外購MAC，只是無法開啟公司的薪資單與公告信。            網管
# 2  之前已透過資訊需求申請單申請General Authorization,申請User ID(...  SAP-168(QCI)
# 3                                         無法登入SAP168  SAP-168(QCI)
# 4                                         加入會議異常無法使用            網管
#
#    category_b category_c   category_d    category  \
# 0          網路     電腦網路不通  網路不通 (QRDC)          網路
# 1  Outlook與郵件    Outlook      無法開啟薪資單  Outlook與郵件
# 2       Basis         帳號          新申請         SAP
# 3       Basis         其它  無法logon SAP         SAP
# 4  Outlook與郵件    Outlook         其他問題  Outlook與郵件
#
#                                    description_clean  category_target  \
# 0                      有線網路孔不通 檢查一下法務部的辦公室 似乎都有相同的問題                3
# 1                 因客人因素部門都會有mac電腦使用需求外購mac公司的薪資單與公告信                0
# 2  之前已透過資訊需求申請單申請general authorization申請 id第二層帳號單...                1
# 3                                             sap168                1
# 4                                             加入會議異常                0
#
#                                            cut_words
# 0                    有線網路,孔,不通,檢查一下,法務部,辦公室,似乎,相同,問題
# 1           客人,因素,部門,mac,電腦,使用,需求,外購,mac,公司,薪資單,公告,信
# 2  之前,已,透過,資訊,需求,申請單,申請,general,authorization,申請,...
# 3                                             sap168
# 4                                           加入,會議,異常

# %%
# df_all[3040:4010]

# %%
# 切分資料
X = df_all['cut_words']
y = df_all['category_target']

X_test = df_test['cut_words']
y_test = df_test['category_target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3, random_state = 40)

# %%
X_train.head()
# Out:
# 2748    驗證,嘗試,驗證,拔線,重開,沒用
# 101              電腦,是否,病毒
# 7486         無線網路,斷,北棟,三樓
# 9039      網路,不通,pf24,d120
# 7906              網孔,c220
# Name: cut_words, dtype: object

# %%
# label 做 onehot
y_train_one_hot = np_utils.to_categorical(y_train)
y_val_one_hot = np_utils.to_categorical(y_val)
print (y_train_one_hot[0])
print (y_val_one_hot[0])
# 總共類別數
num_classes = len((y_train_one_hot[0]))
print ('num_classes = {}'.format(num_classes))
# Out:
# [0. 0. 0. 1. 0.]
# [1. 0. 0. 0. 0.]
# num_classes = 5

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 50

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(X_train)
token_intent.fit_on_texts(X_val)

def preprocessing(x, max_len):

    #將文字轉為數字序列
    train_seq_intent = token_intent.texts_to_sequences(x)

    # 截長補短，讓所有數字序列長度一樣
    data = sequence.pad_sequences(train_seq_intent, maxlen=MAX_LEN)
    # print train_data_intent.shape
    return data

x_train = preprocessing(X_train, max_len=MAX_LEN)
x_val = preprocessing(X_val, max_len=MAX_LEN)
x_test = preprocessing(X_test, max_len=MAX_LEN)

# %%
x_train
# Out:
# array([[   0,    0,    0, ..., 3335,  283, 1090],
#        [   0,    0,    0, ...,   10,   50,  862],
#        [   0,    0,    0, ..., 1537,   55,  814],
#        ...,
#        [   0,    0,    0, ...,  422, 3387,  576],
#        [   0,    0,    0, ...,   68,  100,   94],
#        [   0,    0,    0, ...,    0, 1299,  150]], dtype=int32)

# %%
"""
訓練model
"""
# set parameters:

batch_size = 20
filters = 32
kernel_size = 7
epochs = 50
train_ratio = 0.9

# batch_size = 10
# filters = 50
# kernel_size = 3
# epochs = 50
# train_ratio = 0.8

# maxlen = 100
# embedding_dims = 50
# hidden_dims = 250

# %%
# model.add(Conv1D(activation="relu", padding="same", filters=64, kernel_size=5))
# model.add(MaxPooling1D(pool_size=4))

# %%
def build_1DCNN_model(num_classes, vocab_size, sentence_max_len):
    print('Build model...')
    model = Sequential()
    
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=32, 
                        input_length=sentence_max_len))

    model.add(Dropout(0.5))
    
    model.add(Conv1D(filters,
                     kernel_size,
                     padding='valid',
                     activation='relu',
                     strides=1))
    model.add(GlobalMaxPooling1D())
                     
    # We add a vanilla hidden layer:
#     model.add(Dense(128))
#     model.add(Dropout(0.5))
#     model.add(Activation('relu'))
    model.add(Dense(32))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
# def build_1DCNN_model2(num_classes, vocab_size, embedding_size, max_sentence_length, dropout=0.5):
#     model = Sequential()
#     model.add(Embedding(vocab_size,embedding_size,input_length=max_sentence_length))
#     model.add(Dropout(dropout))
    
#     #for filter_size in filter_sizes:
#     model.add(Conv1D(filters,
#                      kernel_size,
#                      padding='valid',
#                      activation='relu',
#                      strides=1))
#     model.add(MaxPooling1D())
#     model.add(Dropout(dropout))
#     model.add(Flatten())
#     model.add(Dense(num_classes ,activation='relu'))
#     model.add(Activation('softmax'))
#     #model.compile(loss=keras.losses.categorical_crossentropy,optimzer=keras.optimizers.SGD(),metrics=['accuracy'])
#     model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
#     return model

# %%
model = build_1DCNN_model(num_classes, NUM_WORDS, MAX_LEN)
# model = build_1DCNN_model2(num_classes, NUM_WORDS, 32, MAX_LEN)
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 32)            160032
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 44, 32)            7200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 168,453
# Trainable params: 168,453
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_path = '{}.h5'.format('19999_1dcnn')

checkpoint = ModelCheckpoint(model_path, monitor='val_acc', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_acc', patience=10, verbose=1)

model_history = model.fit(x_train, y_train_one_hot,
          batch_size=batch_size,
          epochs=epochs,
          validation_split= 1 - train_ratio,
          callbacks = [checkpoint, earlystop])
# Out:
# Train on 8973 samples, validate on 997 samples
# Epoch 1/50
# 8973/8973 [==============================] - 3s 343us/step - loss: 1.2627 - acc: 0.4916 - val_loss: 0.7372 - val_acc: 0.7081
#
# Epoch 00001: val_acc improved from -inf to 0.70812, saving model to 19999_1dcnn.h5
# Epoch 2/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.6755 - acc: 0.7653 - val_loss: 0.5377 - val_acc: 0.8295
#
# Epoch 00002: val_acc improved from 0.70812 to 0.82949, saving model to 19999_1dcnn.h5
# Epoch 3/50
# 8973/8973 [==============================] - 1s 144us/step - loss: 0.4963 - acc: 0.8397 - val_loss: 0.3775 - val_acc: 0.8816
#
# Epoch 00003: val_acc improved from 0.82949 to 0.88164, saving model to 19999_1dcnn.h5
# Epoch 4/50
# 8973/8973 [==============================] - 1s 142us/step - loss: 0.3920 - acc: 0.8847 - val_loss: 0.3164 - val_acc: 0.9007
#
# Epoch 00004: val_acc improved from 0.88164 to 0.90070, saving model to 19999_1dcnn.h5
# Epoch 5/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.3296 - acc: 0.9040 - val_loss: 0.2916 - val_acc: 0.9037
#
# Epoch 00005: val_acc improved from 0.90070 to 0.90371, saving model to 19999_1dcnn.h5
# Epoch 6/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.2880 - acc: 0.9173 - val_loss: 0.2935 - val_acc: 0.9047
#
# Epoch 00006: val_acc improved from 0.90371 to 0.90471, saving model to 19999_1dcnn.h5
# Epoch 7/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.2575 - acc: 0.9220 - val_loss: 0.2926 - val_acc: 0.9037
#
# Epoch 00007: val_acc did not improve from 0.90471
# Epoch 8/50
# 8973/8973 [==============================] - 1s 144us/step - loss: 0.2375 - acc: 0.9301 - val_loss: 0.3059 - val_acc: 0.9027
#
# Epoch 00008: val_acc did not improve from 0.90471
# Epoch 9/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.2209 - acc: 0.9318 - val_loss: 0.3151 - val_acc: 0.9037
#
# Epoch 00009: val_acc did not improve from 0.90471
# Epoch 10/50
# 8973/8973 [==============================] - 1s 144us/step - loss: 0.1972 - acc: 0.9393 - val_loss: 0.3256 - val_acc: 0.8937
#
# Epoch 00010: val_acc did not improve from 0.90471
# Epoch 11/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.1958 - acc: 0.9429 - val_loss: 0.3288 - val_acc: 0.8947
#
# Epoch 00011: val_acc did not improve from 0.90471
# Epoch 12/50
# 8973/8973 [==============================] - 1s 144us/step - loss: 0.1854 - acc: 0.9431 - val_loss: 0.3385 - val_acc: 0.8997
#
# Epoch 00012: val_acc did not improve from 0.90471
# Epoch 13/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.1712 - acc: 0.9500 - val_loss: 0.3512 - val_acc: 0.8937
#
# Epoch 00013: val_acc did not improve from 0.90471
# Epoch 14/50
# 8973/8973 [==============================] - 1s 144us/step - loss: 0.1717 - acc: 0.9491 - val_loss: 0.3774 - val_acc: 0.8837
#
# Epoch 00014: val_acc did not improve from 0.90471
# Epoch 15/50
# 8973/8973 [==============================] - 1s 145us/step - loss: 0.1613 - acc: 0.9513 - val_loss: 0.3806 - val_acc: 0.8937
#
# Epoch 00015: val_acc did not improve from 0.90471
# Epoch 16/50
# 8973/8973 [==============================] - 1s 143us/step - loss: 0.1515 - acc: 0.9520 - val_loss: 0.3741 - val_acc: 0.8847
#
# Epoch 00016: val_acc did not improve from 0.90471
# Epoch 00016: early stopping

# %%
# %pylab inline
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
show_train_history(model_history,'acc','val_acc')

# %%
show_train_history(model_history,'loss','val_loss')

# %%
def to_cat_name(x): 
        return mapping[x]
    
def predict(test):
    model = load_model(model_path)
    y_predict_probability = model.predict(test)
    y_predict = model.predict_classes(test)

    return to_cat_name(y_predict), y_predict, y_predict_probability

y_predict_name, y_predict, y_predict_probability = predict(x_val)
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
answer_name = to_cat_name(y_val)

# %%
model.predict_classes(x_val)
# Out:
# array([0, 1, 1, ..., 0, 3, 3])

# %%
x_val
# Out:
# array([[   0,    0,    0, ...,    8,  212,  311],
#        [   0,    0,    0, ...,    0,  307,  268],
#        [   0,    0,    0, ...,  128,  438,  984],
#        ...,
#        [   0,    0,    0, ...,    1,   31, 3265],
#        [   0,    0,    0, ...,    0,   11,    4],
#        [   0,    0,    0, ...,    4,  530,   69]], dtype=int32)

# %%
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
# model.predict(x_val)

# %%
# predict_df = pd.DataFrame({'1_sentence':df_test.sentence,
#               '2_y_predict':y_predict,
#               '3_y_predict_name':y_predict_name,
#               '4_answer':df_test.target,
#               '5_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
predict_df = pd.DataFrame({
              '1_sentence':X_val,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_val,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.8993681254388017 !!!!!!!!

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'], margins=True)
# Out:
# answer      Outlook與郵件  SAP   其他    網路  資訊系統   All
# predict
# Outlook與郵件        1205    8   20    37    11  1281
# SAP                 14  450   12    25    24   525
# 其他                  10   19  239    43    17   328
# 網路                  17   21   56  1626    30  1750
# 資訊系統                10   13   22    21   323   389
# All               1256  511  349  1752   405  4273

# %%
"""
預測錯誤的資料觀察
"""
predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
# Out:
#                                               1_sentence  2_y_predict  \
# 2765                 開啟,mybpm,後,出現,需要,登入,帳號密碼,視窗,輸入,後,反應            4
# 2342     設定,ios,10.02,收發,公司,郵件,faq,操作,進行,設定,之後,訊息,無法,伺服器            0
# 8111   早上,承辦人員,通話,重新,操作,後,ocs,系統,出現,舊,號碼,請,承辦人員,察看,系統...            2
# 9742                                         列印,安裝,出現,問題            2
# 3679   project,使用,mtk,平臺,mtk,部份,文件,使用,trustview,加密,原本...            4
# 9286                       線上,會議,無法,觀看,客戶,share,桌面,簡報,資料            4
# 2897                                      開啓,登入,頁面,出現,亂碼            4
# 7595                                          公司,外,ms,法上            3
# 5596   無法,連線到,qrdcprt02,mis,p,n4d,印表機,斷線,後,無法,連線,已經,重...            2
# 2281                                       wordpad,無法,開啓            0
# 1081                 三保,一退,pdf,word,doc,檔案,皆,無法,正常,顯示,下載            2
# 9451                                     填,受訪者,人,陪同,人員,時            1
# 12403                            qcooutlook,當掉,關不掉,時常,發生            4
# 6227            無法,連結,公司,內部,系統,myquanta,myehr,outlook,收信            0
# 9145                      上週,正確,登入,密碼,無法,再,重新,使用,須,變更,密碼            3
# 10035                        停車位,公告,信都會,收到,已經,好,幾次,這種,狀況            0
# 13358                                           安裝,安裝,失敗            2
# 3967                                   店,鬧,無發,連網,是測,有線網路            3
# 10183                                     申請,帳號,似乎,告知,密碼            3
# 2248                               adress,正常,應該,顯示,英文,姓名            4
# 546                                           無法,release            1
# 7282          myquick,quality,manager,iqc,禁藥,檢驗,料號,訊息,空白            1
# 7401                          can,t,login,in,please,call            1
# 6569              時,重灌,電腦,ghost,方式,重新,設定,網路,回,台後,使用,請,資訊            3
# 10022                     myquanta,研發,中心,資料庫,中,投影片,內容,問題            3
# 11643                        今剛,發現,電腦,看到,封,卻,看到,今早,至今,所有            4
# 10624                                     qsa1,印表機,無法,列印            2
# 5988                                   qmq1,printer,fail            2
# 4085                        常駐,使用,quanta,domain,廣達,菁英,學校            3
# 3333                                            密碼,過期,使用            2
# ...                                                  ...          ...
# 12213  需要,到,協力廠商,ftp,server,upgch,redbend,com,使用,廠商,提...            2
# 7812                                 密碼,過期,人,國外,請問,更新,密碼            3
# 8323                               投資部,寶來,點,精靈,環球通,工作,需要            0
# 3836                                      電腦,帳號,過期,網域,過期            3
# 2429                    請問,要用,outlook,建立,concall,bridge,            0
# 1836                                              qco,本機            0
# 11743  南棟,樓,警衛,使用,資產,出入,管理系統,放置,23min,後,系統,須,重新,關掉,ie...            4
# 982                                             筆電,密碼鎖,住            1
# 5192                                      履歷,畫面,無法,完整,顯示            1
# 13060                                   跳出,要求,輸入,帳號密碼,視窗            0
# 8262                               進入,myquanta,出現,伺服器,錯誤            4
# 11817                               can,t,login,myquanta            1
# 8788                           完,report,無法,存到,電腦,vu,槽,不行            4
# 10509  儲備幹部,招募,活動,多益,合作,多益,方面,提供,儲備幹部,招募,dm,印刷,圖檔,檔案,...            0
# 4569                                      ftp,server,連不上            2
# 12823                              outlook,收到,系統,發出,通知,信            0
# 11968                          跑,zv36,扣帳,message,mail,所示            0
# 10622                      cannot,connect,to,mail,server            3
# 2775                                            myquanta            3
# 9532                                           pq06,a414            1
# 3091                                    欲,下載,網路,英文,學習,軟體            3
# 11727                                              申請,兩組            1
# 2528                                    agilepdf,檔,詢問,窗口            0
# 1641                                            無法,儲存,檔案            2
# 11923  公司,網路,vpn,連線,狀況,之下,筆電,outlook,跳出,輸入,密碼,視窗,輸,密碼...            3
# 535                                          token,帳號,被鎖            3
# 13838  網路,斷線,後,outlook,重啟,要求,重新,key,入,window,安全性,認證碼,...            3
# 6681                                      接待,反應,目前,無法,制卡            3
# 5848                    電腦,登入後,顯示,administrator,導致,內部,系統            2
# 1432   家裡,登入,ssl,後,只能,看到,myquanta,首頁,再,進入,內部,系統,mybpm...            0
#
#       3_y_predict_name  4_answer 5_answer_name  \
# 2765              資訊系統         3            網路
# 2342        Outlook與郵件         2            其他
# 8111                其他         4          資訊系統
# 9742                其他         4          資訊系統
# 3679              資訊系統         3            網路
# 9286              資訊系統         2            其他
# 2897              資訊系統         1           SAP
# 7595                網路         2            其他
# 5596                其他         3            網路
# 2281        Outlook與郵件         2            其他
# 1081                其他         4          資訊系統
# 9451               SAP         4          資訊系統
# 12403             資訊系統         0    Outlook與郵件
# 6227        Outlook與郵件         3            網路
# 9145                網路         2            其他
# 10035       Outlook與郵件         4          資訊系統
# 13358               其他         1           SAP
# 3967                網路         4          資訊系統
# 10183               網路         1           SAP
# 2248              資訊系統         0    Outlook與郵件
# 546                SAP         4          資訊系統
# 7282               SAP         4          資訊系統
# 7401               SAP         3            網路
# 6569                網路         2            其他
# 10022               網路         4          資訊系統
# 11643             資訊系統         0    Outlook與郵件
# 10624               其他         1           SAP
# 5988                其他         1           SAP
# 4085                網路         4          資訊系統
# 3333                其他         3            網路
# ...                ...       ...           ...
# 12213               其他         3            網路
# 7812                網路         2            其他
# 8323        Outlook與郵件         3            網路
# 3836                網路         2            其他
# 2429        Outlook與郵件         2            其他
# 1836        Outlook與郵件         4          資訊系統
# 11743             資訊系統         2            其他
# 982                SAP         2            其他
# 5192               SAP         4          資訊系統
# 13060       Outlook與郵件         3            網路
# 8262              資訊系統         3            網路
# 11817              SAP         3            網路
# 8788              資訊系統         1           SAP
# 10509       Outlook與郵件         2            其他
# 4569                其他         3            網路
# 12823       Outlook與郵件         4          資訊系統
# 11968       Outlook與郵件         1           SAP
# 10622               網路         0    Outlook與郵件
# 2775                網路         4          資訊系統
# 9532               SAP         3            網路
# 3091                網路         2            其他
# 11727              SAP         3            網路
# 2528        Outlook與郵件         4          資訊系統
# 1641                其他         1           SAP
# 11923               網路         0    Outlook與郵件
# 535                 網路         2            其他
# 13838               網路         0    Outlook與郵件
# 6681                網路         4          資訊系統
# 5848                其他         3            網路
# 1432        Outlook與郵件         3            網路
#
#                                  6_y_predict_probability
# 2765   [0.11347441, 0.09886351, 0.12518898, 0.2930079...
# 2342   [0.9985422, 2.1525077e-05, 0.00095328724, 0.00...
# 8111   [0.025616318, 0.16478704, 0.47009566, 0.055888...
# 9742   [0.028253628, 0.17697449, 0.63195384, 0.080147...
# 3679   [0.02996184, 0.055424366, 0.17508416, 0.216462...
# 9286   [0.060813818, 0.000913951, 0.16157712, 0.01256...
# 2897   [0.03991935, 0.02507338, 0.11222396, 0.0366099...
# 7595   [0.044010222, 0.042088285, 0.09523962, 0.79815...
# 5596   [0.00034191803, 0.00052560464, 0.54721916, 0.4...
# 2281   [0.33727723, 0.11665245, 0.25780112, 0.1162613...
# 1081   [0.04828275, 0.031994313, 0.647871, 0.10383423...
# 9451   [0.015356455, 0.7433409, 0.057962503, 0.107636...
# 12403  [0.059867106, 0.068146676, 0.19968708, 0.05400...
# 6227   [0.9588199, 0.00013339854, 0.0077178986, 0.031...
# 9145   [0.015486053, 0.18021065, 0.32025126, 0.371233...
# 10035  [0.9360025, 0.009048864, 0.036758255, 0.013452...
# 13358  [0.011661765, 0.021003643, 0.8461946, 0.069463...
# 3967   [8.376288e-05, 1.8407011e-06, 0.0026077495, 0....
# 10183  [0.016636645, 0.20734419, 0.102506265, 0.55452...
# 2248   [0.05227759, 0.04548787, 0.09974401, 0.1563790...
# 546    [0.012834794, 0.88909113, 0.034299064, 0.04034...
# 7282   [0.0030653495, 0.56839895, 0.027813964, 0.0155...
# 7401   [0.01734624, 0.8901431, 0.03079705, 0.04686013...
# 6569   [0.0046617966, 0.0012081964, 0.08176175, 0.911...
# 10022  [0.014680717, 0.13208629, 0.28688002, 0.384987...
# 11643  [0.014113543, 0.036921885, 0.07525138, 0.02708...
# 10624  [0.019066459, 0.26426437, 0.6204311, 0.0393045...
# 5988   [0.07134529, 0.32425418, 0.38227838, 0.1015172...
# 4085   [0.0050191623, 0.013535606, 0.15920824, 0.7756...
# 3333   [0.020600459, 0.017560394, 0.72858685, 0.20514...
# ...                                                  ...
# 12213  [0.004140258, 0.0006903167, 0.8461315, 0.12605...
# 7812   [0.004777077, 0.0019861301, 0.39128244, 0.5955...
# 8323   [0.5124313, 0.066849574, 0.23800756, 0.1492057...
# 3836   [0.00091840304, 0.00043303627, 0.38529786, 0.6...
# 2429   [0.99477744, 0.00037034662, 0.0030263804, 0.00...
# 1836   [0.7999103, 0.04598407, 0.07683561, 0.06484629...
# 11743  [0.0018632277, 0.0017814293, 0.052309573, 0.45...
# 982    [0.10735183, 0.44343987, 0.19549997, 0.1977315...
# 5192   [0.014400331, 0.7654923, 0.030833676, 0.089752...
# 13060  [0.6850176, 0.1293081, 0.094228454, 0.07424596...
# 8262   [0.012011756, 0.03769276, 0.04295164, 0.118874...
# 11817  [0.031287, 0.77505517, 0.040783457, 0.12888901...
# 8788   [0.01817743, 0.07913933, 0.114309505, 0.188627...
# 10509  [0.6971996, 0.00028022347, 0.1943143, 0.031821...
# 4569   [0.0068007647, 0.0066141393, 0.75461257, 0.219...
# 12823  [0.9952974, 1.3974227e-05, 0.0036660312, 0.000...
# 11968  [0.595626, 0.35387594, 0.024331864, 0.02505091...
# 10622  [0.37187174, 0.010148953, 0.06031955, 0.553755...
# 2775   [0.034215465, 0.06630461, 0.10839726, 0.698752...
# 9532   [0.06515283, 0.4807494, 0.13324723, 0.1898763,...
# 3091   [0.0041147806, 0.00064068876, 0.15056348, 0.84...
# 11727  [0.059199795, 0.6198823, 0.13444194, 0.0932071...
# 2528   [0.34531152, 0.24575311, 0.22637802, 0.1145663...
# 1641   [0.07797663, 0.098981455, 0.5352054, 0.1590806...
# 11923  [0.3803016, 1.3773937e-06, 0.0030907528, 0.616...
# 535    [0.022433644, 0.06611172, 0.09962834, 0.778326...
# 13838  [0.064177535, 2.9624146e-06, 0.0072134533, 0.9...
# 6681   [0.04906963, 0.10228979, 0.13593803, 0.6438018...
# 5848   [0.031292167, 0.059655085, 0.4338289, 0.274886...
# 1432   [0.58377624, 0.00039237403, 0.051739343, 0.301...
#
# [430 rows x 6 columns]

# %%
"""
自訂測試句子
"""

y_predict_name, y_predict, y_predict_probability = predict(x_test)
answer_name = to_cat_name(y_test)
predict_df = pd.DataFrame({
              '1_sentence':X_test,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_test,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.7777777777777778 !!!!!!!!

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'], margins=True)
# Out:
# answer      Outlook與郵件  SAP  其他  網路  資訊系統  All
# predict
# Outlook與郵件           3    0   0   0     1    4
# SAP                  0    4   0   0     3    7
# 其他                   0    0   5   0     0    5
# 網路                   0    0   2   1     0    3
# 資訊系統                 0    0   0   0     8    8
# All                  3    4   7   1    12   27

# %%
# predict_df[predict_df['2_y_predict'] == predict_df['4_answer']]

# %%
"""
預測錯誤的資料觀察
"""
predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
# Out:
#      1_sentence  2_y_predict 3_y_predict_name  4_answer 5_answer_name  \
# 4    電腦,變,很慢,中毒            3               網路         2            其他
# 6         在職,證明            1              SAP         4          資訊系統
# 9        資訊,需求單            1              SAP         4          資訊系統
# 18  異常,so,簽核,問題            1              SAP         4          資訊系統
# 25  hp,列印,出現,亂碼            3               網路         2            其他
# 26     薪資,系統,金額            0       Outlook與郵件         4          資訊系統
#
#                               6_y_predict_probability
# 4   [0.0085647125, 0.015619673, 0.4205202, 0.49580...
# 6   [0.09726121, 0.34837732, 0.19209784, 0.1643001...
# 9   [0.037227172, 0.5122693, 0.12272033, 0.0985490...
# 18  [0.00010971772, 0.982268, 0.0024858238, 0.0021...
# 25  [0.09382492, 0.09116893, 0.38473132, 0.4063178...
# 26  [0.95379955, 0.001890844, 0.026999606, 0.00845...

# %%
# model_path = '{}.h5'.format('19999_1dcnn')
# model.save(model_path)

# %%
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)
# model.save_weights("model.h5")
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")
# loaded_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# score = loaded_model.evaluate(x_test, y_test, verbose=0)
# print(score)
