# %%
from __future__ import print_function
 
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation,Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D,GRU,Conv1D, MaxPooling1D,SpatialDropout1D
from keras.layers.recurrent import LSTM,GRU
from keras.layers.wrappers import Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils

from keras.models import model_from_json
import numpy as np
import json
import requests
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df_all = pd.read_csv('data/19999_question_category_b_is_v4.csv')
print(f"df_all shape : {df_all.shape}")
# Out:
# df_all shape : (1336, 8)

# %%
mapping = df_all.category.astype('category').cat.categories
mapping
# Out:
# Index(['BPM平台系統', 'R&D資訊系統', '內部資訊系統'], dtype='object')

# %%
from NLP_JiebaSegmentor import JiebaSegmentor
jieba_dict_path1 = "jieba/dict_taiwan.txt"
jieba_dict_path2 = "jieba/userdict.txt"
jieba_dict_path3 = "jieba/dict.txt.big"
jieba_dict_path4 = "jieba/dict.txt.small"
jieba_dict_path5 = "jieba/dict_system.txt"
jieba_stopwords_path = "jieba/stopwords.txt"

js = JiebaSegmentor(dict_path=jieba_dict_path1,
                    userdict=[jieba_dict_path2,
                              jieba_dict_path3,
                              jieba_dict_path4
                              #jieba_dict_path5
                             ],
                    stopwords=True,
                    stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /project/at081-group3/Project_19999/19999_2RNN/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u5f4d4d2a4ebf6cacbf248ccc4ee696aa.cache
# Loading model cost 0.541 seconds.
# Prefix dict has been built succesfully.

# %%
test_cut_raw_0 = js.lcut('FTP無法安裝', return_type='pandas')
test_cut_raw_0
# Out:
#   word
# 0  FTP
# 1   無法
# 2   安裝

# %%
# x_train=np.loadtxt("x_train.txt",dtype=int)
# y_train=np.loadtxt("y_train.txt",dtype=int)
 
# indices = np.arange(x_train.shape[0])
# np.random.shuffle(indices)
# x_train = x_train[indices]
# y_train = y_train[indices]
 
# print('Loading data...')
# #x_train=np.loadtxt("x_train.txt",dtype=int)
# #y_train=np.loadtxt("y_train.txt",dtype=int)
# x_test=x_train[20000:]
# y_test=y_train[20000:]
# x_train=x_train[:20000]
# y_train=y_train[:20000]
# #x_test=x_train
# #y_test=y_train
# print(len(x_train), 'train sequences')
# print(len(x_test), 'test sequences')
# print(x_train[:1])
# print('Pad sequences (samples x time)')

# %%
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0  下面issue 無法open…完成後會跳到另外一個issue   但原本issue 未Ope...    R&D資訊系統     測試相關服務
# 1  1. Issue Status秀出來的文字裡面,出現斷行符號,但實際上看不到斷行效果  2....    R&D資訊系統     測試相關服務
# 2  QCMC那邊的測試人員反應無法使用QITS系統,原本NB7的使用權限被刪除,如附件一  另外...    R&D資訊系統     測試相關服務
# 3                   Chris Wu (吳振瑋)  新增 BU3 bios   人員    R&D資訊系統     測試相關服務
# 4  Please help create new platform-Chipset “AMD R...    R&D資訊系統     測試相關服務
#
#        category_c category_d category  \
# 0  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 1  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 2  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 3  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 4  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
#
#                                    description_clean  category_target
# 0  下麵 無法open…完成後會跳到一個   但原本 未open完成      再幫忙看一下  ...                1
# 1  1.  status秀出來的文字裡面出現斷行符號但實際上看不到斷行效果  2.  assig...                1
# 2  的測試人員反應qits系統原本nb7的使用權限被刪除如附件一  原本已被刪除的權限現在又跑出...                1
# 3                                   新增 bu3 bios   人員                1
# 4  please help create new platformcpset “amd rich...                1

# %%
# w_pandas = js.lcut('無法會員登入 顯示訊息 無效的帳號或不存在 帳號'.strip(), return_type='pandas')
# w_list = list(w_pandas['word'])
# w_list

# %%
def cut_to_word(s):
    blCondition=True
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    combieNO=''
    beforeWord=''
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        conditionWord = str(combieNO) + str(w)
        
        if combieNO != '' and len(w)>1:# and len(conditionWord) == 4:
            #combie = combie + w +','
            combie = combie+combieNO+w
            #print(combieNO+w)
        else:        
            #87.2%=>
            if w in ['修改','顯示','作業','申請單','問題','系統'] and beforeWord!='' and blCondition and len(w)>1:
                combie = combie + w +','+beforeWord
                combie = combie+','+beforeWord+w
            else:
                if w not in ['無法'] and len(w)>1:
                    combie = combie + w
                 
        if i < len(w_list) - 1 and combie !='':
            combie = combie + ','
            
        if w in ['無法','不能'] and blCondition:#,'安裝','編輯','刪除','新增','作業','忘記','系統','發生','作業','下載','上傳','開啟','安裝']
            combieNO = w
        else:
            combieNO = ''
        beforeWord=w
    return combie    

# print (cut_to_word('可以幫我聯絡'.strip()))
df_all['cut_words'] = df_all['description_clean'].apply(lambda s: cut_to_word(s.strip()))

# %%
# 資料打散
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0  以目前設計FOR SIT1 QITS的設計而言，"Platform found'' 欄位，在...    R&D資訊系統     測試相關服務
# 1                                          單子派送error    BPM平台系統    人資類相關服務
# 2                     MRO2: APP0455487 無產生PO單號，請協助處理    BPM平台系統    採購類相關服務
# 3                                         無法進入HR系統網頁     內部資訊系統     人資資訊系統
# 4                 早上八點開Pre/E就無法取得License，麻煩請協助處理，謝謝。    R&D資訊系統     設計相關服務
#
#                        category_c   category_d category  \
# 0                  【QITS】研發議題追蹤系統       相關操作詢問  R&D資訊系統
# 1                           出差申請單       關卡流程詢問  BPM平台系統
# 2                   MRO採購系統(MRO2)       系統無法登入  BPM平台系統
# 3                          出勤相關服務         請假問題   內部資訊系統
# 4  【Design Tool】Pro/E、OrCAD設計工具管理  無法取得License  R&D資訊系統
#
#                                    description_clean  category_target  \
# 0  以目前設計for sit1 qits的設計platform found'' 欄位在creat...                1
# 1                                          單子派送error                0
# 2                                 mro2 app87 無產生po單號                0
# 3                                             hr系統網頁                2
# 4                             早上八點開pre/e就無法取得license                1
#
#                                            cut_words
# 0  目前,設計,for,sit1,qits,設計,platform,found,欄位,creat...
# 1                                        單子,派送,error
# 2                               mro2,app87,,產生,po,單號
# 3                                   hr,系統,hr,hr系統,網頁
# 4                          早上,,點開,pre,,,無法取得,license

# %%
df_all[3040:4010]
# Out:
# Empty DataFrame
# Columns: [description, category_a, category_b, category_c, category_d, category, description_clean, category_target, cut_words]
# Index: []

# %%
# 切分資料
X = df_all['cut_words']
y = df_all['category_target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 40)

# %%
X_train.head()
# Out:
# 880                                              上傳,考績,內容
# 369                                生產,大樓,外帶,證有,問題,證有,證有問題
# 284                       key,四筆,項目,最後,分攤,,顯示,只,只顯示,一筆,查看
# 1300    測試人員,反應,qits,系統,qits,qits系統,原本,nb7,使用,權限,刪除,附件...
# 954                                     反映,,無法觀看,廣達,學院,影片
# Name: cut_words, dtype: object

# %%
# label 做 onehot
y_train_one_hot = np_utils.to_categorical(y_train)
y_val_one_hot = np_utils.to_categorical(y_val)
print (y_train_one_hot[0])
print (y_val_one_hot[0])
# 總共類別數
num_classes = len((y_train_one_hot[0]))
print ('num_classes = {}'.format(num_classes))
# Out:
# [0. 0. 1.]
# [1. 0. 0.]
# num_classes = 3

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 30

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(X_train)
token_intent.fit_on_texts(X_val)

def preprocessing(x, max_len):

    #將文字轉為數字序列
    train_seq_intent = token_intent.texts_to_sequences(x)

    # 截長補短，讓所有數字序列長度一樣
    data = sequence.pad_sequences(train_seq_intent, maxlen=MAX_LEN)
    # print train_data_intent.shape
    return data

x_train = preprocessing(X_train, max_len=MAX_LEN)
x_val = preprocessing(X_val, max_len=MAX_LEN)

# %%
x_train
# Out:
# array([[   0,    0,    0, ...,   72,  116,   84],
#        [   0,    0,    0, ...,    4,  970, 1547],
#        [   0,    0,    0, ...,  972,  487,  248],
#        ...,
#        [   0,    0,    0, ...,    0,  204,  116],
#        [   0,    0,    0, ...,  180,   72,   59],
#        [   0,    0,    0, ...,   51,  800,  396]], dtype=int32)

# %%
# set parameters:
max_features = 5001
maxlen = 100
batch_size = 20
embedding_dims = 50
filters = 100
kernel_size = 10
hidden_dims = 250
epochs = 10
train_ratio = 0.9

# %%
#CCN-78%,85.8%
#https://www.kaggle.com/kakiac/deep-learning-4-text-classification-cnn-bi-lstm
#https://mlwhiz.com/blog/2019/03/09/deeplearning_architectures_text_classification/
from keras.layers.merge import concatenate, add
from keras.layers import CuDNNGRU,Input,MaxPooling1D
from keras.models import Sequential, load_model,Model
def build_CNN(num_classes, vocab_size, sentence_max_len,embedding_dim):
    inp = Input(shape=(sentence_max_len, ))
    embed_size = 240
    x = Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len)(inp)
    
    convs = []
    filter_sizes = [3,4,5] # in the loop, first apply 3 as size, then 4 then 5

    x = Dropout(0.5)(x)
    
    for filter_size in filter_sizes:
        l_conv = Conv1D(filters=128, kernel_size=filter_size, activation='relu')(x)
        #kernel is the filter
        l_pool = GlobalMaxPooling1D()(l_conv)
        convs.append(l_pool)

    l_merge = concatenate(convs, axis=1)
    
    # activated if extra_convoluted is true at the def
    # add a 1D convnet with global maxpooling, instead of Yoon Kim model
    conv = Conv1D(filters=128, kernel_size=19, activation='relu')(x)
    pool = MaxPooling1D(pool_size=3)(conv)
    x = Dropout(0.5)(l_merge)  
    
    #x = Conv1D(filters=512,kernel_size=10,padding='same', activation='relu')(x)
    #x = GlobalMaxPooling1D()(x)
    #x = Bidirectional(CuDNNGRU(512, return_sequences=True))(x)
    #x = GlobalMaxPooling1D()(x)
    
    #x = Flatten()(x)
    
    
    
    #x = Dense(128, activation="relu")(x)
    #x = Dropout(0.5)(x)
    
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.5)(x)
    #x = Dense(6, activation="sigmoid")(x)
    outp = Dense(num_classes, activation="softmax")(x)
    model = Model(inputs=inp, outputs=outp)
    print(model.summary())
    return model;

# %%
def build_1DCNN_model(num_classes, vocab_size, sentence_max_len,embedding_dim):
    print('Build model...')
    model = Sequential()
    
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))

    model.add(Dropout(0.5))
    
    model.add(Conv1D(filters,
                     kernel_size,
                     padding='valid',
                     activation='relu',
                     strides=1))
    model.add(GlobalMaxPooling1D())
                     
    # We add a vanilla hidden layer:
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(128))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
model = build_CNN(num_classes, NUM_WORDS, MAX_LEN,256)
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 30)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 30, 256)      1280256     input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 30, 256)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 28, 128)      98432       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 27, 128)      131200      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 26, 128)      163968      dropout_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 128)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 128)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384)          0           global_max_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 384)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           24640       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            195         dropout_3[0][0]
# ==================================================================================================
# Total params: 1,698,691
# Trainable params: 1,698,691
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model_path = '{}.h5'.format('19999_rnn')

epochs = 50
batch_size = 32
train_ratio = 0.9

checkpoint = ModelCheckpoint(model_path, monitor='val_acc', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=3, verbose=1)

model_history = model.fit(x=x_train, y=y_train_one_hot,
                            batch_size=batch_size, 
                            epochs=epochs,
                            validation_split= 1 - train_ratio,
                            callbacks = [checkpoint, earlystop])
# Out:
# Train on 961 samples, validate on 107 samples
# Epoch 1/50
# 961/961 [==============================] - 2s 2ms/step - loss: 1.0632 - acc: 0.4631 - val_loss: 1.0709 - val_acc: 0.3925
#
# Epoch 00001: val_acc improved from -inf to 0.39252, saving model to 19999_rnn.h5
# Epoch 2/50
# 961/961 [==============================] - 0s 151us/step - loss: 1.0289 - acc: 0.4953 - val_loss: 1.0254 - val_acc: 0.4019
#
# Epoch 00002: val_acc improved from 0.39252 to 0.40187, saving model to 19999_rnn.h5
# Epoch 3/50
# 961/961 [==============================] - 0s 150us/step - loss: 0.9145 - acc: 0.5765 - val_loss: 0.8805 - val_acc: 0.5607
#
# Epoch 00003: val_acc improved from 0.40187 to 0.56075, saving model to 19999_rnn.h5
# Epoch 4/50
# 961/961 [==============================] - 0s 173us/step - loss: 0.6687 - acc: 0.7430 - val_loss: 0.7009 - val_acc: 0.7664
#
# Epoch 00004: val_acc improved from 0.56075 to 0.76636, saving model to 19999_rnn.h5
# Epoch 5/50
# 961/961 [==============================] - 0s 150us/step - loss: 0.3501 - acc: 0.8897 - val_loss: 0.5993 - val_acc: 0.7757
#
# Epoch 00005: val_acc improved from 0.76636 to 0.77570, saving model to 19999_rnn.h5
# Epoch 6/50
# 961/961 [==============================] - 0s 148us/step - loss: 0.1605 - acc: 0.9636 - val_loss: 0.6313 - val_acc: 0.7944
#
# Epoch 00006: val_acc improved from 0.77570 to 0.79439, saving model to 19999_rnn.h5
# Epoch 7/50
# 961/961 [==============================] - 0s 149us/step - loss: 0.0916 - acc: 0.9719 - val_loss: 0.6795 - val_acc: 0.7944
#
# Epoch 00007: val_acc did not improve from 0.79439
# Epoch 8/50
# 961/961 [==============================] - 0s 150us/step - loss: 0.0612 - acc: 0.9865 - val_loss: 0.7462 - val_acc: 0.7944
#
# Epoch 00008: val_acc did not improve from 0.79439
# Epoch 00008: early stopping

# %%
from keras import models 
model=models.load_model(model_path)

# %%
# %pylab inline
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['concatenate', 'add']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
show_train_history(model_history,'acc','val_acc')

# %%
show_train_history(model_history,'loss','val_loss')

# %%
def to_cat_name(x): 
        return mapping[x]
    
def predict(test):
#     model = load_model(model_path)
    y_predict_probability = model.predict(test)
    y_predict = model.predict_classes(test)

    return to_cat_name(y_predict), y_predict, y_predict_probability

def predict_class(data):
    y_predict_probability = model.predict(data, batch_size=64, verbose=1)
    predict_arr = []
    predictClass = []
    for row in y_predict_probability: 
            classIndex=0
            selectClass=0
            selectProbability=0
            for item in row: 
                #print(float(item))
                if(selectProbability <= float(item)):
                    #print(classIndex)
                    selectProbability=float(item)
                    selectClass=classIndex
                classIndex=classIndex+1
            predictClass.append(selectClass)
            
    return to_cat_name(predictClass),predictClass,y_predict_probability

y_predict_name, y_predict, y_predict_probability = predict_class(x_val)
# Out:
# 268/268 [==============================] - 0s 334us/step

# %%
answer_name = to_cat_name(y_val)

# %%
#model.predict_classes(x_val)

# %%
x_val
# Out:
# array([[   0,    0,    0, ...,    0,   86,   94],
#        [ 958,  382, 1306, ...,   49,   58,  241],
#        [   0,    0,    0, ...,  273, 3167, 3168],
#        ...,
#        [   0,    0,    0, ...,  107,  147,   48],
#        [   0,    0,    0, ..., 3620,    6,  502],
#        [   0,    0,    0, ...,    0,    6, 3621]], dtype=int32)

# %%
mapping
# Out:
# Index(['BPM平台系統', 'R&D資訊系統', '內部資訊系統'], dtype='object')

# %%
# model.predict(x_val)

# %%
# predict_df = pd.DataFrame({'1_sentence':df_test.sentence,
#               '2_y_predict':y_predict,
#               '3_y_predict_name':y_predict_name,
#               '4_answer':df_test.target,
#               '5_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
predict_df = pd.DataFrame({
              '1_sentence':X_val,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_val,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.8731343283582089 !!!!!!!!

# %%
predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
# Out:
#                                              1_sentence  2_y_predict  \
# 983                                          帳號密碼,過期,幫忙            2
# 892           請假,出勤,資訊,點選,請假,作業,請假,請假作業,,,無法顯示,畫面,連線,錯誤            2
# 843                         因原,代理人,,部門,需將,原本,,設定,代理人,刪除            0
# 706                                            出現,登入,失敗            0
# 1033                                操作,,出現,帳戶,已過期,錯誤,訊息            0
# 1296                                           申請,pm,權限            0
# 944                              電腦,外帶,,發現,資產,並掛,,電腦,外帶            0
# 989                                      電腦,外帶,攜出,,無法列印            0
# 1009                                           無法設定,代理人            0
# 198                bu9,李偉嘉,系統,李偉嘉,李偉嘉系統,自動,將我,登入,,bu12,            2
# 192                                       家屬,申請,出現異常,訊息            0
# 1100                                  系統,使用,異常,會報,error            2
# 254                                             autocad            0
# 800                                       sheet,點開,一片空白            0
# 746                                     部門,導致,,部門,,無法簽核            2
# 923                                           無法license            0
# 1071                                    快遞,申請單,快遞,快遞申請單            0
# 1172                                           不到,部門,代碼            2
# 737                                   進入,網站,跳出,帳號,輸入,視窗            0
# 1334                          申請,請假,發生,錯誤,伺服器,,無法要求,999            0
# 1196                        離職,plm,申請,項目,,無法完成,取消,重新,申請            0
# 287   遠端,vpn,,公司,ui,顯示,ui,ui顯示,憑證,錯誤,,無法顯示,網頁,myquan...            1
# 407   hdd,損壞,重新,購置,hdd,容量,原來,資產,編號,貼紙,,更換,,正確,hdd,容量...            1
# 1269                       請假,作業系統,bpm,系統,bpm,bpm系統,進不去            0
# 622                           查不到,mrb,申請單,mrb,mrb申請單,ap            0
# 35                dna,系統,dna,dna系統,看不到,by,department,資料            1
# 1179  gams,系統,gams,gams系統,公務車,申請單,公務車,公務車申請單,系統,申請單,...            0
# 754                            專案,名稱欄,,字數,,製造成,搜尋,不到,專案            1
# 386         二位,,預約,系統,預約,預約系統,正常,因該,sda,可互,,預約,三個,廠區,所在            2
# 84                                         人事,異動表,,無法簽核            0
# 519   嘗試,編輯,位於,文件,庫中,excel,文件,,發生,編輯,文件,需要,windows,s...            2
# 990                                         反應,需要,將舊,刪除            0
# 1089                                        系統,訊息,,,,步驟            0
# 466                                               人員,資料            0
#
#      3_y_predict_name  4_answer 5_answer_name  \
# 983            內部資訊系統         0       BPM平台系統
# 892            內部資訊系統         1       R&D資訊系統
# 843           BPM平台系統         2        內部資訊系統
# 706           BPM平台系統         1       R&D資訊系統
# 1033          BPM平台系統         2        內部資訊系統
# 1296          BPM平台系統         1       R&D資訊系統
# 944           BPM平台系統         2        內部資訊系統
# 989           BPM平台系統         2        內部資訊系統
# 1009          BPM平台系統         2        內部資訊系統
# 198            內部資訊系統         0       BPM平台系統
# 192           BPM平台系統         2        內部資訊系統
# 1100           內部資訊系統         0       BPM平台系統
# 254           BPM平台系統         1       R&D資訊系統
# 800           BPM平台系統         1       R&D資訊系統
# 746            內部資訊系統         0       BPM平台系統
# 923           BPM平台系統         1       R&D資訊系統
# 1071          BPM平台系統         2        內部資訊系統
# 1172           內部資訊系統         0       BPM平台系統
# 737           BPM平台系統         2        內部資訊系統
# 1334          BPM平台系統         2        內部資訊系統
# 1196          BPM平台系統         1       R&D資訊系統
# 287           R&D資訊系統         0       BPM平台系統
# 407           R&D資訊系統         0       BPM平台系統
# 1269          BPM平台系統         2        內部資訊系統
# 622           BPM平台系統         2        內部資訊系統
# 35            R&D資訊系統         2        內部資訊系統
# 1179          BPM平台系統         2        內部資訊系統
# 754           R&D資訊系統         0       BPM平台系統
# 386            內部資訊系統         1       R&D資訊系統
# 84            BPM平台系統         2        內部資訊系統
# 519            內部資訊系統         1       R&D資訊系統
# 990           BPM平台系統         1       R&D資訊系統
# 1089          BPM平台系統         2        內部資訊系統
# 466           BPM平台系統         2        內部資訊系統
#
#                        6_y_predict_probability
# 983       [0.29367095, 0.05357567, 0.65275335]
# 892     [0.006698709, 0.014645321, 0.97865593]
# 843    [0.99244714, 0.0010746283, 0.006478224]
# 706        [0.6921506, 0.15437363, 0.15347572]
# 1033   [0.98095876, 0.0022325155, 0.016808702]
# 1296     [0.9100747, 0.016762074, 0.073163316]
# 944      [0.9485791, 0.015492314, 0.035928667]
# 989      [0.9641112, 0.006823186, 0.029065536]
# 1009       [0.95448, 0.008444196, 0.037075758]
# 198        [0.43528274, 0.12130546, 0.4434118]
# 192     [0.95827377, 0.004335098, 0.037391074]
# 1100       [0.15170847, 0.1123788, 0.73591274]
# 254       [0.46108708, 0.18098965, 0.35792327]
# 800       [0.39236242, 0.29725078, 0.31038678]
# 746        [0.30134547, 0.12804112, 0.5706134]
# 923       [0.56896615, 0.13412444, 0.29690945]
# 1071  [0.9978498, 0.00020053808, 0.0019496486]
# 1172       [0.22987235, 0.35492444, 0.4152032]
# 737       [0.7325755, 0.007871636, 0.25955293]
# 1334     [0.8794999, 0.0024774405, 0.11802255]
# 1196      [0.73074436, 0.13639922, 0.13285643]
# 287       [0.008159761, 0.6521485, 0.33969182]
# 407        [0.3367886, 0.59810466, 0.06510676]
# 1269    [0.85838413, 0.0029652868, 0.13865066]
# 622    [0.9929512, 0.0007644592, 0.0062843375]
# 35         [0.15936239, 0.5299486, 0.31068903]
# 1179   [0.95270914, 0.0019070244, 0.045383856]
# 754     [0.0017380835, 0.9773412, 0.020920744]
# 386      [0.0086750835, 0.07931207, 0.9120128]
# 84     [0.97713655, 0.0046834922, 0.018180024]
# 519       [0.13874875, 0.41713387, 0.44411737]
# 990       [0.50929797, 0.19287129, 0.29783076]
# 1089      [0.58208877, 0.056161776, 0.3617494]
# 466        [0.76591206, 0.09065705, 0.1434309]

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'])
# Out:
# answer   BPM平台系統  R&D資訊系統  內部資訊系統
# predict
# BPM平台系統      129        7      15
# R&D資訊系統        3       60       1
# 內部資訊系統         5        3      45

# %%
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)
# model.save_weights("model.h5")
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")
# loaded_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# score = loaded_model.evaluate(x_test, y_test, verbose=0)
# print(score)
