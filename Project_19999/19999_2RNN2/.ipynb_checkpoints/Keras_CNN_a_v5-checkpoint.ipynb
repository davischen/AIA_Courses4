# %%
from __future__ import print_function
 
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation,Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D,GRU,Conv1D, MaxPooling1D,SpatialDropout1D
from keras.layers.recurrent import LSTM,GRU
from keras.layers.wrappers import Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils

from keras.models import model_from_json
import numpy as np
import json
import requests
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df_all = pd.read_csv('data/19999_question_category_a_v16.csv')
print(f"df_all shape : {df_all.shape}")
# Out:
# df_all shape : (14247, 8)

# %%
mapping = df_all.category.astype('category').cat.categories
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
from NLP_JiebaSegmentor import JiebaSegmentor
jieba_dict_path1 = "jieba/dict_taiwan.txt"
jieba_dict_path2 = "jieba/userdict.txt"
jieba_dict_path3 = "jieba/dict.txt.big"
jieba_dict_path4 = "jieba/dict.txt.small"
jieba_dict_path5 = "jieba/dict_system.txt"
jieba_stopwords_path = "jieba/stopwords.txt"

js = JiebaSegmentor(dict_path=jieba_dict_path1,
                    userdict=[jieba_dict_path2,
                              jieba_dict_path3,
                              jieba_dict_path4
                              #jieba_dict_path5
                             ],
                    stopwords=True,
                    stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /project/at081-group3/Project_19999/19999_2RNN/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u5f4d4d2a4ebf6cacbf248ccc4ee696aa.cache
# Loading model cost 0.548 seconds.
# Prefix dict has been built succesfully.

# %%
test_cut_raw_0 = js.lcut('FTP無法安裝', return_type='pandas')
test_cut_raw_0
# Out:
#   word
# 0  FTP
# 1   安裝

# %%
# x_train=np.loadtxt("x_train.txt",dtype=int)
# y_train=np.loadtxt("y_train.txt",dtype=int)
 
# indices = np.arange(x_train.shape[0])
# np.random.shuffle(indices)
# x_train = x_train[indices]
# y_train = y_train[indices]
 
# print('Loading data...')
# #x_train=np.loadtxt("x_train.txt",dtype=int)
# #y_train=np.loadtxt("y_train.txt",dtype=int)
# x_test=x_train[20000:]
# y_test=y_train[20000:]
# x_train=x_train[:20000]
# y_train=y_train[:20000]
# #x_test=x_train
# #y_test=y_train
# print(len(x_train), 'train sequences')
# print(len(x_test), 'test sequences')
# print(x_train[:1])
# print('Pad sequences (samples x time)')

# %%
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0               無法會員登入,顯示訊息:無效的帳號或使用者不存在。帳號:96122401       CAMP       CAMP
# 1  因今天有事請假，要補登先前的加班，但開啟camp後，出勤表單顯示的內容看起來像測試的，沒有最...       CAMP       CAMP
# 2                           手機簽核BPM有問題,都顯示亂碼  #18227       CAMP       CAMP
# 3                     無法在手機上面使用CAMP進行表單簽核動作。分機：17132       CAMP       CAMP
# 4                                           無法打開報單資料       CAMP       CAMP
#
#   category_c category_d category  \
# 0       CAMP       CAMP     資訊系統
# 1       CAMP       CAMP     資訊系統
# 2       CAMP       CAMP     資訊系統
# 3       CAMP       CAMP     資訊系統
# 4       CAMP       CAMP     資訊系統
#
#                                    description_clean  category_target
# 0                              無法會員登入顯示訊息無效的帳號或不存在帳號                4
# 1  因有事請假要補登先前的加班但開啟camp後出勤表單顯示的內容像測試的沒有的時間也沒辦法使用已...                4
# 2                                      簽核bpm有問題都顯示亂碼                4
# 3                                無法在上面使用camp進行表單簽核動作                4
# 4                                           無法打開報單資料                4

# %%
# w_pandas = js.lcut('無法會員登入 顯示訊息 無效的帳號或不存在 帳號'.strip(), return_type='pandas')
# w_list = list(w_pandas['word'])
# w_list

# %%
def cut_to_word(s):
    blCondition=True
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    combieNO=''
    beforeWord=''
    blAdd=True
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        conditionWord = str(combieNO) + str(w)
        if combieNO != '' :# and len(conditionWord) == 4:
            combie = combie + w +','
            combie = combie+combieNO+w
            #print(combieNO+w)
        else:        
            if w in ['修改','顯示','申請單','問題','作業','系統'] and beforeWord!='' and blCondition and len(w)>1:#,,'問題','顯示',
                combie = combie +w
                combie = combie+','+beforeWord+w
            else:
                if w not in ['無法'] and len(w)>1:
                    combie = combie + w
                else:
                    blAdd = False
                 
        if i < len(w_list) - 1 and combie !='' and blAdd:
            combie = combie + ','
            
        blAdd = True
        
        if w in ['無法','不能'] and blCondition:#,'安裝','編輯','刪除','新增','作業','忘記','下載','上傳','系統','開啟'
            combieNO = w
        else:
            combieNO = ''
        beforeWord=w
    return combie    

def cut_to_word2(s):
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
            
        combie = combie + w
                 
        if i < len(w_list) - 1:
            combie = combie + ','
            
    return combie  

# print (cut_to_word('可以幫我聯絡'.strip()))
df_all['cut_words'] = df_all['description_clean'].apply(lambda s: cut_to_word2(s.strip()))

# %%
# 資料打散
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_all.head()
# Out:
#                                          description category_a  category_b  \
# 0      信箱爆掉以後, 後面的信件會到哪裡去了?  請問公司信箱空間容量有多大, 如何增加空間容量         網管  Outlook與郵件
# 1                                       無線網路不斷跳出驗證訊息         網管          網路
# 2                                 寄信給外部gamil信箱對方無法收到         網管  Outlook與郵件
# 3  無線網路不通, they can''t login wireless by using gu...         網管          網路
# 4                                           在家無法連回公司         網管       VPN連線
#
#   category_c  category_d    category  \
# 0    Outlook      郵件無法收發  Outlook與郵件
# 1     電腦網路不通  網路不斷出現驗證訊息          網路
# 2     郵件傳送追蹤    沒有收到某封郵件  Outlook與郵件
# 3     電腦網路不通      無線網路不通          網路
# 4   SSLVPN問題        無法登入          網路
#
#                                    description_clean  category_target  \
# 0             信箱爆掉以後 後面的信件會到去了  請問公司信箱空間容量有多大 增加空間容量                0
# 1                                       無線網路不斷跳出驗證訊息                3
# 2                                 寄信給外部gamil信箱對方無法收到                0
# 3  無線網路不通 they can''t login wireless by using gue...                3
# 4                                           在家無法連回公司                3
#
#                                            cut_words
# 0        信箱,爆掉,以後,後面,信件,會到,去,請問,公司,信箱,空間,容量,增加,空間,容量
# 1                                   無線網路,不斷,跳出,驗證,訊息
# 2                               寄信,外部,gamil,信箱,對方,收到
# 3  無線網路,不通,they,can,t,login,wireless,by,using,gue...
# 4                                           在家,連回,公司

# %%
df_all[3040:4010]
# Out:
#                                             description     category_a  \
# 3040             #18681    手機要收發公司郵件，但手機平台是黑莓機，不知道如何設定。             網管
# 3041  從昨天下午4:00開始(06/27)就沒有收到web-notice通知簽核, 但上BPM系統...             網管
# 3042                                           出現遠端密碼過期             網管
# 3043                                      無法成功安裝LYNC跟登入             網管
# 3044                      user 更新系統後，發現無法登入公司內部網站如myhr.             網管
# 3045                  有線網路突然無法使用，將網路線接到電話也一樣。  分機:18367             網管
# 3046                        忘記登入公司密碼 煩請協助聯絡處理 ext 16110             網管
# 3047  不管是LAN還是WLAN都要我提供驗證訊息，所以下方網路圖示都有黃色驚嘆號。  但是基本上還...             網管
# 3048                              EXT:16796  線上課程無法自動播放         內部資訊系統
# 3049         使用者反應電腦郵件內的URL都沒辦法連到網址，使用者反應有點急，請幫忙協助處理，謝謝             網管
# 3050                                     網路孔不通PH19/A163             網管
# 3051                                       這個系統的安全性記錄已滿             網管
# 3052  after update Cloud Computing system and restar...             網管
# 3053         office 2010 開啟 excel 2003 正常，但無法編修該檔，會造成當機             網管
# 3054                          windows自動更新後無法連上網路。#16510             網管
# 3055                    電腦抓不到Staff無線網路, 無法上網  分機: 12725             網管
# 3056     N718會議室   網路孔B126，網路不通   及桌上網路孔，網路不通   分機17285             網管
# 3057                                        outlook一直死當             網管
# 3058                                          PB08-D008             網管
# 3059                        Outlook不時會出現驗證畫面, 且收發信件速度很慢             網管
# 3060                                       無法接收外部寄的MAIL             網管
# 3061                                     網路孔不通 PT10A442             網管
# 3062             網路孔編號B622，接到網路電話不通、螢幕沒畫面，但接NB可要到IP、可連網             網管
# 3063                      OPENVPN安裝到一半有問題  無法安裝  #11891             網管
# 3064    #13676  用個人電腦在QSMC無法登入OCS，email可正常接收，還請幫忙處理，感謝!             網管
# 3065          開啟outlook 出現錯誤訊息，需重新啟動電腦才可以開啟，這幾天錯誤訊息出現頻繁             網管
# 3066                         使用者詢問為何每次登入都需要輸入驗證資訊,請協助處理   SAP-168(QCI)
# 3067  在process 串簽列要加人的時候系統會出現“原始流程取得錯誤，請關掉視窗，切回表單，重新...        BPM平台系統
# 3068                         #693127  出差 QCMC  申請加班發生問題         內部資訊系統
# 3069                   網路孔不通, 網路孔號:A151/PH07  分機: 12875             網管
# ...                                                 ...            ...
# 3980                                          outlook不通             網管
# 3981  已報告錯誤，Send and Recive有 Error  錯誤代碼：80041004  分...             網管
# 3982                          大廳接待　網孔不通　請儘速解決 ext:12112             網管
# 3983                                        outlook無法登入             網管
# 3984                                電腦帳戶移除: AN990112709             網管
# 3985                                   電腦網路不通，請協助處理，謝謝!             網管
# 3986                                             無線網路不通             網管
# 3987                                  有線,無線皆無法上網。#17471             網管
# 3988                                             有線網路不通             網管
# 3989      Cannot connect to company''s website at home.             網管
# 3990                                  無法連線CSAP21 #18281   SAP-168(QCI)
# 3991                                QCALL於重慶無法登入。#21333           CAMP
# 3992                                      航班申請單只能填寫QSMC        BPM平台系統
# 3993                             北棟5樓A215 分機15762 重覆驗證.             網管
# 3994                                 Q10210055 移除作業系統帳戶             網管
# 3995                                           南棟4樓c480             網管
# 3996              無法create New Project 請協助處理  EXT:12708  SAP-2X8(QSMC)
# 3997   出差需求取消,但出差申請單已簽核完成無法抽單.  請幫忙抽單,謝謝  單號:APP0080976        BPM平台系統
# 3998                             無法順利開啟信件裡的超連結。分機：17380             網管
# 3999  人在台灣, 要申請, 可以存取以下上海服務器的權限:   QSMCMAS02(文件夾: GP...             網管
# 4000                             無線網卡無法抓到Staff網路 #16333             網管
# 4001                             在廠商或家裡無法連結lync  #12384             網管
# 4002                                有線網路驗證失敗  分機: 11700             網管
# 4003                                     作業系統無法啟動，顯示需修復             網管
# 4004                         有Tcode帳號但要申請權限  #385-13279   SAP-168(QCI)
# 4005                         開啟薪資單mail,outlook會當掉(無法回應)             網管
# 4006  using Vista Basic, but could not use SAP syste...   SAP-168(QCI)
# 4007               使用者密碼過期，需要幫忙重新設定登入密碼‧  (請用MVPN連絡申請人)             網管
# 4008                                          信件無法傳送和收件             網管
# 4009   網路無法連線, 驗證無法通過,一直顯現在驗證中, 網孔號碼(D198)    TEL:13392             網管
#
#       category_b     category_c        category_d    category  \
# 3040  Outlook與郵件        Outlook            郵件無法收發  Outlook與郵件
# 3041  Outlook與郵件        Outlook              其他問題  Outlook與郵件
# 3042          網路         電腦網路不通        網路不斷出現驗證訊息          網路
# 3043    商務用Skype           其他問題              其他問題          其他
# 3044          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3045          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3046    作業系統與印表機             其它              其他事項          其他
# 3047          網路         電腦網路不通        網路不斷出現驗證訊息          網路
# 3048      人資資訊系統       廣達學院相關服務  e-Learning系統相關問題        資訊系統
# 3049  Outlook與郵件        Outlook           URL無法連結  Outlook與郵件
# 3050          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3051          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3052          網路         電腦網路不通           無法取得 IP          網路
# 3053    作業系統與印表機           軟體問題            軟體安裝問題          其他
# 3054          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3055          網路         電腦網路不通            無線網路不通          網路
# 3056          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3057  Outlook與郵件        Outlook              其他問題  Outlook與郵件
# 3058          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3059  Outlook與郵件        Outlook              其他問題  Outlook與郵件
# 3060  Outlook與郵件        Outlook            郵件無法收發  Outlook與郵件
# 3061          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3062          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3063       VPN連線       SSLVPN問題              無法登入          網路
# 3064    商務用Skype           無法登入              無法登入          其他
# 3065  Outlook與郵件        Outlook        Outlook點不開  Outlook與郵件
# 3066       Basis  Authorization              權限不足         SAP
# 3067     品保類相關服務       非標準材料鑑審表            系統無法登入        資訊系統
# 3068      人資資訊系統         出勤相關服務              加班問題        資訊系統
# 3069          網路         電腦網路不通       網路不通 (QRDC)          網路
# ...          ...            ...               ...         ...
# 3980  Outlook與郵件        Outlook            郵件無法收發  Outlook與郵件
# 3981  Outlook與郵件        Outlook            郵件無法收發  Outlook與郵件
# 3982          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3983  Outlook與郵件        Outlook        Outlook點不開  Outlook與郵件
# 3984    作業系統與印表機         作業系統問題            電腦帳戶移除          其他
# 3985          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3986          網路         電腦網路不通            無線網路不通          網路
# 3987          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3988          網路         電腦網路不通       網路不通 (TH20)          網路
# 3989       VPN連線       SSLVPN問題              無法登入          網路
# 3990       Basis             其它       無法logon SAP         SAP
# 3991        CAMP           CAMP              CAMP        資訊系統
# 3992     人資類相關服務          出差申請單            系統無法登入        資訊系統
# 3993          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3994    作業系統與印表機         作業系統問題            電腦帳戶移除          其他
# 3995          網路         電腦網路不通       網路不通 (QRDC)          網路
# 3996       Basis             帳號               新申請         SAP
# 3997     人資類相關服務          出差申請單            相關操作詢問        資訊系統
# 3998  Outlook與郵件        Outlook           URL無法連結  Outlook與郵件
# 3999          網路   無法連到大陸或其他分公司         連線分公司網路問題          網路
# 4000          網路         電腦網路不通       網路不通 (QRDC)          網路
# 4001    商務用Skype           無法登入              無法登入          其他
# 4002          網路         電腦網路不通       網路不通 (QRDC)          網路
# 4003    作業系統與印表機           軟體問題            軟體安裝問題          其他
# 4004       Basis             帳號            帳號無法使用         SAP
# 4005  Outlook與郵件        Outlook           無法開啟薪資單  Outlook與郵件
# 4006       Basis             其它             安裝SAP         SAP
# 4007          網路         電腦網路不通       網路不通 (TH20)          網路
# 4008  Outlook與郵件         郵件傳送追蹤          沒有收到某封郵件  Outlook與郵件
# 4009          網路         電腦網路不通       網路不通 (QRDC)          網路
#
#                                       description_clean  category_target  \
# 3040                                要收發公司郵件但平臺是黑莓機不知道設定                0
# 3041          從下午40006/27就沒有收到webnotice通知簽核 但上bpm系統可以看到                0
# 3042                                           出現遠端密碼過期                3
# 3043                                      無法成功安裝lync跟登入                2
# 3044                                 更新系統後發現公司內部網站如myhr                3
# 3045                                      有線網路突然將網路線接到也                3
# 3046                                           忘記登入公司密碼                2
# 3047  是lanwlan都要我提供驗證訊息下方網路圖示都有黃色驚嘆號  上還可以連得上網路比較容易斷...                3
# 3048                                         線上課程無法自動播放                4
# 3049                                  電腦郵件內的url都沒辦法連到網址                0
# 3050                                     網路孔不通ph19/a163                3
# 3051                                         系統的安全性記錄已滿                3
# 3052  after update cloud computing system and restar...                3
# 3053                   office  開啟 excel  正常但無法編修該檔會造成當機                2
# 3054                                 windows自動更新後無法連上網路                3
# 3055                                電腦抓不到staff無線網路 無法上網                3
# 3056                 n718會議室   網路孔b126網路不通   及桌上網路孔網路不通                3
# 3057                                          outlook死當                0
# 3058                                           pb08d008                3
# 3059                           outlook會出現驗證畫面 且收發信件速度很慢                0
# 3060                                       無法接收外部寄的mail                0
# 3061                                     網路孔不通 pt10a442                3
# 3062                   網路孔編號b622接到網路不通螢幕沒畫面但接nb可要到ip可連網                3
# 3063                              openvpn安裝到一半有問題  無法安裝                3
# 3064                                       用電腦ocs可正常接收還                2
# 3065                開啟outlook 訊息需重新啟動電腦才可以開啟這幾天錯誤訊息出現頻繁                0
# 3066                                    詢問每次登入都需要輸入驗證資訊                1
# 3067  在process 串簽列要加人的系統會出現“原始流程取得錯誤請關掉視窗切回表單重新進入流程後...                4
# 3068                                           申請加班發生問題                4
# 3069                                網路孔不通 網路孔號a151/ph07                3
# ...                                                 ...              ...
# 3980                                          outlook不通                0
# 3981                  已報告錯誤send and recive有 error  錯誤代碼                0
# 3982                                          大廳接待 網孔不通                3
# 3983                                            outlook                0
# 3984                                          電腦帳戶移除 an                2
# 3985                                             電腦網路不通                3
# 3986                                             無線網路不通                3
# 3987                                          有線無線皆無法上網                3
# 3988                                             有線網路不通                3
# 3989       cannot connect to company''s website at home                3
# 3990                                         無法連線csap21                1
# 3991                                             qcall於                4
# 3992                                          航班申請單只能填寫                4
# 3993                                     北棟5樓a215  重覆驗證                3
# 3994                                         q 移除作業系統帳戶                2
# 3995                                           南棟4樓c480                3
# 3996                               無法create new project                1
# 3997                    需求取消但申請單已簽核完成無法抽單.  抽單  單號app76                4
# 3998                                      無法順利開啟信件裡的超連結                0
# 3999  要申請 可以存取以下服務器的權限   mas02文件夾 gp實驗室   fs3文件夾  檢測...                3
# 4000                                    無線網卡無法抓到staff網路                3
# 4001                                     在廠商或家裡無法連結lync                2
# 4002                                           有線網路驗證失敗                3
# 4003                                         作業系統無法啟動顯示                2
# 4004                                     有tcode帳號但要申請權限                1
# 4005                            開啟薪資單mailoutlook會當掉無法回應                0
# 4006  using vista basic but could not use sap system...                1
# 4007                           密碼過期需要幫忙重新設定登入密碼‧  請用申請人                3
# 4008                                          信件無法傳送和收件                0
# 4009                       網路無法連線 驗證無法通過顯現在驗證中 網孔號碼d198                3
#
#                                               cut_words
# 3040                              收發,公司,郵件,平臺,黑莓機,知道,設定
# 3041           下午,40006,27,收到,webnotice,通知,簽核,bpm,系統,看到
# 3042                                        出現,遠端,密碼,過期
# 3043                                      成功,安裝,lync,登入
# 3044                           更新,系統,後,發現,公司,內部,網站,myhr
# 3045                                     有線網路,突然,網路線,接到
# 3046                                        忘記,登入,公司,密碼
# 3047  lanwlan,提供,驗證,訊息,下方,網路,圖示,黃色,驚嘆號,還可以,上網,路,比較,容...
# 3048                                         線上,課程,自動播放
# 3049                                     電腦,郵件,url,到,網址
# 3050                                  網路,孔,不通,ph19,a163
# 3051                                       系統,安全性,記錄,已滿
# 3052  after,update,cloud,computing,system,and,restar...
# 3053                      office,開啟,excel,正常,編修,檔會,造成,機
# 3054                                windows,自動更新,後,上網,路
# 3055                               電腦,抓不到,staff,無線網路,上網
# 3056             n718,會議室,網路,孔,b126,網路,不通,桌上,網路,孔,網路,不通
# 3057                                         outlook,死當
# 3058                                           pb08d008
# 3059                       outlook,出現,驗證,畫面,收發,信件,速度,很慢
# 3060                                       接收,外部,寄,mail
# 3061                                   網路,孔,不通,pt10a442
# 3062       網路,孔,編號,b622,接到,網路,不通,螢幕,畫面,但接,nb,可要,到,ip,連網
# 3063                               openvpn,安裝到,一半,問題,安裝
# 3064                                       電腦,ocs,正常,接收
# 3065        開啟,outlook,訊息,需,重新,啟動,電腦,開啟,這幾天,錯誤,訊息,出現,頻繁
# 3066                               詢問,每次,登入,需要,輸入,驗證,資訊
# 3067  process,串,簽列要,加人,系統,出現,原始,流程,取得,錯誤,請,關掉,視窗,切回,...
# 3068                                        申請,加班,發生,問題
# 3069                            網路,孔,不通,網路,孔號,a151,ph07
# ...                                                 ...
# 3980                                         outlook,不通
# 3981                 已,報告,錯誤,send,and,recive,error,錯誤代碼
# 3982                                        大廳,接待,網孔,不通
# 3983                                            outlook
# 3984                                        電腦,帳戶,移除,an
# 3985                                            電腦網路,不通
# 3986                                            無線網路,不通
# 3987                                         有線,無線,皆,上網
# 3988                                            有線網路,不通
# 3989        cannot,connect,to,company,s,website,at,home
# 3990                                          連線,csap21
# 3991                                              qcall
# 3992                                       航班,申請單,只能,填寫
# 3993                                  北棟,5,樓,a215,重覆,驗證
# 3994                                       q,移除,作業系統,帳戶
# 3995                                        南棟,4,樓,c480
# 3996                                 create,new,project
# 3997                   需求,取消,申請單,已,簽核,完成,抽單,抽單,單號,app76
# 3998                                          開啟,信件,超連結
# 3999  申請,存取,以下,服務器,權限,mas02,文件夾,gp,實驗室,fs3,文件夾,檢測,中心...
# 4000                                  無線,網卡,抓到,staff,網路
# 4001                                      廠商,家裡,連結,lync
# 4002                                         有線網路,驗證,失敗
# 4003                                         作業系統,啟動,顯示
# 4004                                     tcode,帳號,申請,權限
# 4005                          開啟,薪資單,mailoutlook,當掉,回,應
# 4006  using,vista,basic,but,could,not,use,sap,system...
# 4007                   密碼,過期,需要,幫忙,重新,設定,登入,密碼,‧,請用,申請人
# 4008                                           信件,傳送,收件
# 4009                        網路,連線,驗證,顯現,驗證,中,網孔,號碼,d198
#
# [970 rows x 9 columns]

# %%
# 切分資料
X = df_all['cut_words']
y = df_all['category_target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 40)

# %%
X_train.head()
# Out:
# 4483                           電腦,顯示,window,啟用,時限,僅限,23,天
# 2179                                         app2830,點,不開
# 4810                                    進入,sslvpn,bpm,進不去
# 2209    請,mis,幫忙,抓取,部門,人員,1,1,3,8,每天,第一封,發信,時間,最後,一封,發...
# 5179                                          網孔,pu19b499
# Name: cut_words, dtype: object

# %%
# label 做 onehot
y_train_one_hot = np_utils.to_categorical(y_train)
y_val_one_hot = np_utils.to_categorical(y_val)
print (y_train_one_hot[0])
print (y_val_one_hot[0])
# 總共類別數
num_classes = len((y_train_one_hot[0]))
print ('num_classes = {}'.format(num_classes))
# Out:
# [0. 0. 1. 0. 0.]
# [0. 0. 0. 1. 0.]
# num_classes = 5

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 30

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(X_train)
token_intent.fit_on_texts(X_val)

def preprocessing(x, max_len):

    #將文字轉為數字序列
    train_seq_intent = token_intent.texts_to_sequences(x)

    # 截長補短，讓所有數字序列長度一樣
    data = sequence.pad_sequences(train_seq_intent, maxlen=MAX_LEN)
    # print train_data_intent.shape
    return data

x_train = preprocessing(X_train, max_len=MAX_LEN)
x_val = preprocessing(X_val, max_len=MAX_LEN)

# %%
x_train
# Out:
# array([[   0,    0,    0, ..., 4894,  513, 1137],
#        [   0,    0,    0, ..., 4895,  195,  344],
#        [   0,    0,    0, ...,  267,   88,  434],
#        ...,
#        [   0,    0,    0, ...,    7,    5,  420],
#        [   0,    0,    0, ...,    0,    0, 3213],
#        [   0,    0,    0, ...,    0,  446,   82]], dtype=int32)

# %%
# set parameters:
max_features = 5001
maxlen = 100
batch_size = 20
embedding_dims = 50
filters = 100
kernel_size = 10
hidden_dims = 250
epochs = 10
train_ratio = 0.9

# %%
#CCN-87.7%,89%,90.5%,90%
#https://www.kaggle.com/kakiac/deep-learning-4-text-classification-cnn-bi-lstm
#https://mlwhiz.com/blog/2019/03/09/deeplearning_architectures_text_classification/
from keras.layers.merge import concatenate, add
from keras.layers import CuDNNGRU,Input,MaxPooling1D
from keras.models import Sequential, load_model,Model
def build_CNN(num_classes, vocab_size, sentence_max_len,embedding_dim):
    inp = Input(shape=(sentence_max_len, ))
    embed_size = 240
    x = Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len)(inp)
    
    convs = []
    filter_sizes = [3,4,5] # in the loop, first apply 3 as size, then 4 then 5

    x = Dropout(0.5)(x)
    
    for filter_size in filter_sizes:
        l_conv = Conv1D(filters=128, kernel_size=filter_size, activation='relu')(x)
        #kernel is the filter
        l_pool = GlobalMaxPooling1D()(l_conv)
        convs.append(l_pool)

    l_merge = concatenate(convs, axis=1)
    
    # activated if extra_convoluted is true at the def
    # add a 1D convnet with global maxpooling, instead of Yoon Kim model
    conv = Conv1D(filters=128, kernel_size=19, activation='relu')(x)
    pool = MaxPooling1D(pool_size=3)(conv)
    x = Dropout(0.5)(l_merge)  
    
    #x = Conv1D(filters=512,kernel_size=10,padding='same', activation='relu')(x)
    #x = GlobalMaxPooling1D()(x)
    #x = Bidirectional(CuDNNGRU(512, return_sequences=True))(x)
    #x = GlobalMaxPooling1D()(x)
    
    #x = Flatten()(x)
    
    
    
    #x = Dense(128, activation="relu")(x)
    #x = Dropout(0.5)(x)
    
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.5)(x)
    #x = Dense(6, activation="sigmoid")(x)
    outp = Dense(num_classes, activation="softmax")(x)
    model = Model(inputs=inp, outputs=outp)
    print(model.summary())
    return model;

# %%
def build_1DCNN_model(num_classes, vocab_size, sentence_max_len,embedding_dim):
    print('Build model...')
    model = Sequential()
    
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))

    model.add(Dropout(0.5))
    
    model.add(Conv1D(filters,
                     kernel_size,
                     padding='valid',
                     activation='relu',
                     strides=1))
    model.add(GlobalMaxPooling1D())
                     
    # We add a vanilla hidden layer:
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(128))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
model = build_CNN(num_classes, NUM_WORDS, MAX_LEN,256)
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 30)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 30, 256)      1280256     input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 30, 256)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 28, 128)      98432       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 27, 128)      131200      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 26, 128)      163968      dropout_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 128)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 128)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384)          0           global_max_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 384)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           24640       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            325         dropout_3[0][0]
# ==================================================================================================
# Total params: 1,698,821
# Trainable params: 1,698,821
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model_path = '{}.h5'.format('19999_rnn')

epochs = 50
batch_size = 32
train_ratio = 0.9

checkpoint = ModelCheckpoint(model_path, monitor='val_acc', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=6, verbose=1)

model_history = model.fit(x=x_train, y=y_train_one_hot,
                            batch_size=batch_size, 
                            epochs=epochs,
                            validation_split= 1 - train_ratio,
                            callbacks = [checkpoint, earlystop])
# Out:
# Train on 10257 samples, validate on 1140 samples
# Epoch 1/50
# 10257/10257 [==============================] - 4s 368us/step - loss: 0.8292 - acc: 0.6923 - val_loss: 0.3838 - val_acc: 0.8737
#
# Epoch 00001: val_acc improved from -inf to 0.87368, saving model to 19999_rnn.h5
# Epoch 2/50
# 10257/10257 [==============================] - 2s 147us/step - loss: 0.3727 - acc: 0.8882 - val_loss: 0.2885 - val_acc: 0.9114
#
# Epoch 00002: val_acc improved from 0.87368 to 0.91140, saving model to 19999_rnn.h5
# Epoch 3/50
# 10257/10257 [==============================] - 2s 147us/step - loss: 0.2590 - acc: 0.9216 - val_loss: 0.2711 - val_acc: 0.9175
#
# Epoch 00003: val_acc improved from 0.91140 to 0.91754, saving model to 19999_rnn.h5
# Epoch 4/50
# 10257/10257 [==============================] - 2s 147us/step - loss: 0.1921 - acc: 0.9430 - val_loss: 0.3020 - val_acc: 0.9132
#
# Epoch 00004: val_acc did not improve from 0.91754
# Epoch 5/50
# 10257/10257 [==============================] - 2s 147us/step - loss: 0.1716 - acc: 0.9482 - val_loss: 0.3154 - val_acc: 0.9123
#
# Epoch 00005: val_acc did not improve from 0.91754
# Epoch 6/50
# 10257/10257 [==============================] - 2s 149us/step - loss: 0.1428 - acc: 0.9570 - val_loss: 0.3388 - val_acc: 0.9070
#
# Epoch 00006: val_acc did not improve from 0.91754
# Epoch 7/50
# 10257/10257 [==============================] - 1s 146us/step - loss: 0.1208 - acc: 0.9632 - val_loss: 0.3741 - val_acc: 0.9105
#
# Epoch 00007: val_acc did not improve from 0.91754
# Epoch 8/50
# 10257/10257 [==============================] - 2s 147us/step - loss: 0.1002 - acc: 0.9676 - val_loss: 0.3883 - val_acc: 0.9018
#
# Epoch 00008: val_acc did not improve from 0.91754
# Epoch 9/50
# 10257/10257 [==============================] - 2s 147us/step - loss: 0.0979 - acc: 0.9695 - val_loss: 0.3987 - val_acc: 0.9018
#
# Epoch 00009: val_acc did not improve from 0.91754
# Epoch 00009: early stopping

# %%
from keras import models 
model=models.load_model(model_path)

# %%
# %pylab inline
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['concatenate', 'add']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
show_train_history(model_history,'acc','val_acc')

# %%
show_train_history(model_history,'loss','val_loss')

# %%
def to_cat_name(x): 
        return mapping[x]
    
def predict(test):
#     model = load_model(model_path)
    y_predict_probability = model.predict(test)
    y_predict = model.predict_classes(test)

    return to_cat_name(y_predict), y_predict, y_predict_probability

def predict_class(data):
    y_predict_probability = model.predict(data, batch_size=64, verbose=1)
    predict_arr = []
    predictClass = []
    for row in y_predict_probability: 
            classIndex=0
            selectClass=0
            selectProbability=0
            for item in row: 
                #print(float(item))
                if(selectProbability <= float(item)):
                    #print(classIndex)
                    selectProbability=float(item)
                    selectClass=classIndex
                classIndex=classIndex+1
            predictClass.append(selectClass)
            
    return to_cat_name(predictClass),predictClass,y_predict_probability

y_predict_name, y_predict, y_predict_probability = predict_class(x_val)
# Out:
# 2850/2850 [==============================] - 0s 48us/step

# %%
answer_name = to_cat_name(y_val)

# %%
#model.predict_classes(x_val)

# %%
x_val
# Out:
# array([[   0,    0,    0, ...,    0,   80,    7],
#        [   0,    0,    0, ...,  582, 4806,  126],
#        [   0,    0,    0, ...,    9,  329,  207],
#        ...,
#        [   0,    0,    0, ...,    0,    0,    2],
#        [   0,    0,    0, ...,   30,   53,   42],
#        [   0,    0,    0, ...,  110,  563, 4389]], dtype=int32)

# %%
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
# model.predict(x_val)

# %%
# predict_df = pd.DataFrame({'1_sentence':df_test.sentence,
#               '2_y_predict':y_predict,
#               '3_y_predict_name':y_predict_name,
#               '4_answer':df_test.target,
#               '5_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
predict_df = pd.DataFrame({
              '1_sentence':X_val,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_val,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.8905263157894737 !!!!!!!!

# %%
differ_ans=predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
differ_ans
# Out:
#                                               1_sentence  2_y_predict  \
# 5387             要求,輸入,密碼,認證,輸入,後,無用,跳,到,網址,172.20,170.3            0
# 6551                                         申請,電腦,帳戶,移除            2
# 11704                        上週,正確,登入,密碼,再,重新,使用,須,變更,密碼            3
# 10302                                             伺服器,連線            0
# 12425                                 upgrade,到,後,電腦,怪怪的            3
# 9668                                       meeting,place            0
# 1984                                         請,提供,ocs,載點            3
# 11408                                           連入,sap22            3
# 4285                              發生,情況,群組,會議,通話,時,一連,斷線            3
# 5596   出勤,網站,連上,顯示出,請,輸入,hrmsap,quanta,corp,認證,error,...            3
# 7273                                     app58,無,法規,檔,列印            1
# 2274   win7,裝,virtual,pc,linux,64,位元,出現,64,位元,錯誤,virt...            3
# 5457   1,安裝,放行,系統,列印,軟體,時,系統,要求,管理員,權限,開放,安裝,2,電腦,入網,...            3
# 12880                                     名片,申請,系統,顯示,頁面            4
# 5390                     nb,有線網路,無線網路,皆,不通,使用,nb,有線網路,正常            3
# 14215        ftp,連線,內部,ip,10.241,57.2,外部,ip,203.75,58.38            3
# 9640                             二專,以下,加班,制度,變更,出勤,規則,說明            4
# 13829                                 需,連線至,客人,ftp,下載,資料            3
# 12955                                     zmza,can,t,use            3
# 8427   電腦,未,使用,達,15,分鐘,後,自動,休眠,輸入,正確,密碼,後,出現,工作站,主要,網...            3
# 9916                     webmail,改,密碼,之後,再用,webmail,改,密碼            0
# 10250                      電腦,右下角,出現,安全,危脅,警訊,詢問,是否,正常,應            3
# 7950   加密,公告,文件,雲端,信箱,人事,組織,異動,錯誤,顯示,發生,意外,錯誤,系統管理員,稍...            0
# 11123  出勤,網站,連上,顯示出,請,輸入,hrmsap,quanta,corp,認證,error,...            3
# 6625             使用,wifichorm,跳出,輸入,帳密,視窗,ie,則是,直接,報錯,連線            4
# 7345                                         收發,郵件,設定,問題            0
# 10186  請問,我會,收到,以下,人,請假,簽核,通知,似乎,bu10,事業部,軟體,組,軟體,三處,...            2
# 11935                                 lync,outlook,正常,使用            0
# 12609                                        刪除,xv1h,8.1            0
# 14053                                        vendor,code            4
# ...                                                  ...          ...
# 11516                                          重新,建立,申請單            4
# 7698                          更改,桌上型電腦,密碼,後,nb,新密碼,登入,連線            3
# 2796                                需要,訂,會議室,發現到,總務,資訊系統            3
# 248                                          發行,轉,pdf,格式            1
# 9626                                   passwod,超過,8,碼,輸入            0
# 13138          電腦,上網,正常,登入,公司,首頁,內部,網站,需要,每次,重新,登錄,網域,才行            3
# 10078                                             抓不到,資料            3
# 4508                                 qrdcfs01,資料夾,看不到,資料            0
# 4103                                   到,ftp10.241,24.19            3
# 1301   透過,有線網路,outlook,收發,異常,無,網路,問題,正常,上網,無線網路,則能,正常,收發            3
# 4229                                申請單,申打,外線,功能,剛剛,測試,卻            4
# 6957                                               看到,價錢            0
# 5123                               電腦,已改,cn,網域,ocs,設定,tw            3
# 5052              打開,office,時會,跑出,副本,尚未,啟動,只剩,16,天,警告,視窗            4
# 9328                                         master,data            3
# 5313                       cannot,connect,to,mail,server            3
# 1248                      網頁,顯示,瀏覽器,過舊,安裝,chrome,後,部分,網頁            3
# 4239                                        額度,已,滿多,開帳,號            3
# 602                           點擊,sapcsap37,跳至,輸入,帳號密碼,介面            0
# 5376                                       申請,網路,顯示,已,申請            3
# 7978                10.243,23.56,login,12,31,晚上,發生,同樣,情形            0
# 415    使用,ie,chrome,出現,連線,狀況,網路,名稱,解析,皆,正常,是連,公司,內部,部...            3
# 3174                            網路,連線,印表機,列印,資料,寄給,請,卻,印            3
# 12475                南棟,s306,78,人,大部份,人會,收不到,訊號,幫忙,查看,問題            0
# 11164                                  使用,plm,系統,存取,file            4
# 7722                     資產,編號欄,位,輸入,後,出現,查無,資產,編號,產編,信箱            0
# 11948                         人事部門,寄,信件,中,更新,資料,附加,連結,網址            0
# 1621                                        webmail,做,78            0
# 10631                                   invoice,帶出,多個,品項            1
# 1990                                         詢問,申請,費用,問題            4
#
#       3_y_predict_name  4_answer 5_answer_name  \
# 5387        Outlook與郵件         3            網路
# 6551                其他         3            網路
# 11704               網路         2            其他
# 10302       Outlook與郵件         3            網路
# 12425               網路         2            其他
# 9668        Outlook與郵件         3            網路
# 1984                網路         2            其他
# 11408               網路         1           SAP
# 4285                網路         2            其他
# 5596                網路         4          資訊系統
# 7273               SAP         4          資訊系統
# 2274                網路         2            其他
# 5457                網路         4          資訊系統
# 12880             資訊系統         3            網路
# 5390                網路         2            其他
# 14215               網路         2            其他
# 9640              資訊系統         0    Outlook與郵件
# 13829               網路         2            其他
# 12955               網路         1           SAP
# 8427                網路         2            其他
# 9916        Outlook與郵件         2            其他
# 10250               網路         2            其他
# 7950        Outlook與郵件         4          資訊系統
# 11123               網路         4          資訊系統
# 6625              資訊系統         3            網路
# 7345        Outlook與郵件         3            網路
# 10186               其他         4          資訊系統
# 11935       Outlook與郵件         2            其他
# 12609       Outlook與郵件         4          資訊系統
# 14053             資訊系統         1           SAP
# ...                ...       ...           ...
# 11516             資訊系統         3            網路
# 7698                網路         2            其他
# 2796                網路         4          資訊系統
# 248                SAP         4          資訊系統
# 9626        Outlook與郵件         1           SAP
# 13138               網路         4          資訊系統
# 10078               網路         1           SAP
# 4508        Outlook與郵件         3            網路
# 4103                網路         2            其他
# 1301                網路         0    Outlook與郵件
# 4229              資訊系統         2            其他
# 6957        Outlook與郵件         1           SAP
# 5123                網路         2            其他
# 5052              資訊系統         2            其他
# 9328                網路         1           SAP
# 5313                網路         0    Outlook與郵件
# 1248                網路         4          資訊系統
# 4239                網路         1           SAP
# 602         Outlook與郵件         1           SAP
# 5376                網路         4          資訊系統
# 7978        Outlook與郵件         1           SAP
# 415                 網路         2            其他
# 3174                網路         2            其他
# 12475       Outlook與郵件         3            網路
# 11164             資訊系統         3            網路
# 7722        Outlook與郵件         4          資訊系統
# 11948       Outlook與郵件         4          資訊系統
# 1621        Outlook與郵件         2            其他
# 10631              SAP         4          資訊系統
# 1990              資訊系統         2            其他
#
#                                  6_y_predict_probability
# 5387   [0.51258004, 0.005767224, 0.109080374, 0.34095...
# 6551   [0.013497465, 0.01606548, 0.891083, 0.05241673...
# 11704  [0.049565364, 0.038314078, 0.20734827, 0.66100...
# 10302  [0.48872393, 0.01398858, 0.10455476, 0.3145716...
# 12425  [0.12397077, 0.01753482, 0.3950825, 0.41152558...
# 9668   [0.52872014, 0.040017173, 0.16738984, 0.211272...
# 1984   [0.011120564, 0.008438444, 0.21002951, 0.75521...
# 11408  [0.048451394, 0.11242952, 0.08623107, 0.692810...
# 4285   [0.1269273, 0.0022901392, 0.28017768, 0.578677...
# 5596   [0.011954004, 0.008908128, 0.03131468, 0.48242...
# 7273   [0.23970506, 0.33274272, 0.23787852, 0.0753086...
# 2274   [0.00043578062, 1.8371e-05, 0.014733, 0.967403...
# 5457   [0.00021107723, 0.005467088, 0.42745993, 0.440...
# 12880  [0.0077178017, 0.2512259, 0.009437476, 0.01109...
# 5390   [7.121135e-08, 1.050077e-08, 1.9585113e-05, 0....
# 14215  [0.00021768492, 0.00011430098, 0.10183419, 0.8...
# 9640   [0.099866286, 0.001689775, 0.0056217434, 0.003...
# 13829  [0.0027202778, 0.000738038, 0.48340574, 0.5109...
# 12955  [0.20634693, 0.10571264, 0.09600312, 0.5164044...
# 8427   [0.00024241018, 0.00020653348, 0.0056975475, 0...
# 9916   [0.9625611, 0.0003429447, 0.019674746, 0.01587...
# 10250  [0.02997081, 0.015465938, 0.33536738, 0.586254...
# 7950   [0.99866545, 7.5993976e-06, 0.0005973173, 0.00...
# 11123  [0.011954004, 0.008908128, 0.03131468, 0.48242...
# 6625   [0.029219996, 0.059538748, 0.11274554, 0.36265...
# 7345   [0.99971753, 1.2486514e-07, 0.00014823698, 0.0...
# 10186  [0.07387148, 0.0015005742, 0.51914626, 0.02026...
# 11935  [0.9092568, 5.067153e-06, 0.086534075, 0.00400...
# 12609  [0.6035393, 0.07821043, 0.11771678, 0.10522239...
# 14053  [0.083478875, 0.18638107, 0.04590487, 0.204602...
# ...                                                  ...
# 11516  [0.13390926, 0.05777977, 0.0716413, 0.02582302...
# 7698   [0.0029414415, 0.003431009, 0.21906896, 0.7643...
# 2796   [0.05244515, 0.0273153, 0.33720154, 0.47825527...
# 248    [0.0246773, 0.6371662, 0.20857117, 0.062616564...
# 9626   [0.64579314, 0.049161967, 0.10227381, 0.122787...
# 13138  [0.0016185077, 0.01177294, 0.034472063, 0.9165...
# 10078  [0.045060117, 0.09625774, 0.09060958, 0.723824...
# 4508   [0.5380247, 0.09502017, 0.17595215, 0.11961435...
# 4103   [0.023255322, 0.008437519, 0.03789403, 0.91509...
# 1301   [0.14925759, 2.607512e-07, 0.0031610052, 0.847...
# 4229   [0.00960853, 0.00804621, 0.21445392, 0.0213180...
# 6957   [0.41196734, 0.15526916, 0.07497513, 0.0682129...
# 5123   [0.0008576847, 7.062362e-05, 0.101625875, 0.89...
# 5052   [0.11363608, 0.007417354, 0.27209306, 0.057960...
# 9328   [0.14444552, 0.17513278, 0.21210308, 0.2977620...
# 5313   [0.16829915, 0.016808731, 0.041483317, 0.68104...
# 1248   [0.004692702, 0.011282335, 0.11514807, 0.68574...
# 4239   [0.06831035, 0.05961559, 0.107300654, 0.690089...
# 602    [0.7588082, 0.011970515, 0.106700405, 0.063068...
# 5376   [0.0022126408, 0.0069590667, 0.014823479, 0.96...
# 7978   [0.41331568, 0.1726388, 0.059854902, 0.2672645...
# 415    [0.00040440416, 0.0012083323, 0.018369092, 0.9...
# 3174   [0.0019866228, 0.0056980373, 0.21711358, 0.773...
# 12475  [0.7135846, 0.003086224, 0.07308804, 0.1159584...
# 11164  [0.008795817, 0.10096371, 0.0131083615, 0.0386...
# 7722   [0.50535214, 0.005098687, 0.04829101, 0.023042...
# 11948  [0.9966529, 2.6696327e-05, 0.0018910485, 0.001...
# 1621   [0.98836166, 0.00010776698, 0.005499747, 0.005...
# 10631  [0.0035558671, 0.9436305, 0.0077780616, 0.0081...
# 1990   [0.046280302, 0.33916077, 0.057052813, 0.02627...
#
# [312 rows x 6 columns]

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'])
# Out:
# answer      Outlook與郵件  SAP   其他    網路  資訊系統
# predict
# Outlook與郵件         759   12   19    28    12
# SAP                  2  298    6     7    17
# 其他                   8   10  164    15     7
# 網路                  21   22   49  1104    28
# 資訊系統                 8    7   14    20   213

# %%
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)
# model.save_weights("model.h5")
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")
# loaded_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# score = loaded_model.evaluate(x_test, y_test, verbose=0)
# print(score)

# %%
pd.DataFrame(differ_ans).to_csv('CNN_v4.csv')
