# %%
from __future__ import print_function
 
from keras.preprocessing import sequence
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout, Activation,Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D,GRU,Conv1D, MaxPooling1D,SpatialDropout1D
from keras.layers.recurrent import LSTM,GRU
from keras.layers.wrappers import Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.layers import CuDNNGRU
from keras.layers.merge import concatenate, add
from keras.layers import Input,Reshape,Conv2D,MaxPool2D, concatenate

from keras.utils import multi_gpu_model
from keras.models import model_from_json
import numpy as np
import json
import requests
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df_all = pd.read_csv('data/19999_question_category_a_v16.csv')
print(f"df_all shape : {df_all.shape}")
# Out:
# df_all shape : (14247, 8)

# %%
mapping = df_all.category.astype('category').cat.categories
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
from NLP_JiebaSegmentor import JiebaSegmentor
jieba_dict_path1 = "jieba/dict_taiwan.txt"
jieba_dict_path2 = "jieba/userdict.txt"
jieba_dict_path3 = "jieba/dict.txt.big"
jieba_dict_path4 = "jieba/dict.txt.small"
jieba_dict_path5 = "jieba/dict_system.txt"
jieba_stopwords_path = "jieba/stopwords.txt"

js = JiebaSegmentor(dict_path=jieba_dict_path1,
                    userdict=[jieba_dict_path2,
                              jieba_dict_path3,
                              jieba_dict_path4#,
                              #jieba_dict_path5
                             ],
                    stopwords=True,
                    stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /project/at081-group3/Project_19999/19999_2RNN/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u5f4d4d2a4ebf6cacbf248ccc4ee696aa.cache
# Loading model cost 0.531 seconds.
# Prefix dict has been built succesfully.

# %%
test_cut_raw_0 = js.lcut('FTP無法安裝', return_type='pandas')
test_cut_raw_0
# Out:
#    word
# 0   FTP
# 1  無法安裝
# 2    安裝

# %%
# x_train=np.loadtxt("x_train.txt",dtype=int)
# y_train=np.loadtxt("y_train.txt",dtype=int)
 
# indices = np.arange(x_train.shape[0])
# np.random.shuffle(indices)
# x_train = x_train[indices]
# y_train = y_train[indices]
 
# print('Loading data...')
# #x_train=np.loadtxt("x_train.txt",dtype=int)
# #y_train=np.loadtxt("y_train.txt",dtype=int)
# x_test=x_train[20000:]
# y_test=y_train[20000:]
# x_train=x_train[:20000]
# y_train=y_train[:20000]
# #x_test=x_train
# #y_test=y_train
# print(len(x_train), 'train sequences')
# print(len(x_test), 'test sequences')
# print(x_train[:1])
# print('Pad sequences (samples x time)')

# %%
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0               無法會員登入,顯示訊息:無效的帳號或使用者不存在。帳號:96122401       CAMP       CAMP
# 1  因今天有事請假，要補登先前的加班，但開啟camp後，出勤表單顯示的內容看起來像測試的，沒有最...       CAMP       CAMP
# 2                           手機簽核BPM有問題,都顯示亂碼  #18227       CAMP       CAMP
# 3                     無法在手機上面使用CAMP進行表單簽核動作。分機：17132       CAMP       CAMP
# 4                                           無法打開報單資料       CAMP       CAMP
#
#   category_c category_d category  \
# 0       CAMP       CAMP     資訊系統
# 1       CAMP       CAMP     資訊系統
# 2       CAMP       CAMP     資訊系統
# 3       CAMP       CAMP     資訊系統
# 4       CAMP       CAMP     資訊系統
#
#                                    description_clean  category_target
# 0                              無法會員登入顯示訊息無效的帳號或不存在帳號                4
# 1  因有事請假要補登先前的加班但開啟camp後出勤表單顯示的內容像測試的沒有的時間也沒辦法使用已...                4
# 2                                      簽核bpm有問題都顯示亂碼                4
# 3                                無法在上面使用camp進行表單簽核動作                4
# 4                                           無法打開報單資料                4

# %%
# w_pandas = js.lcut('無法會員登入 顯示訊息 無效的帳號或不存在 帳號'.strip(), return_type='pandas')
# w_list = list(w_pandas['word'])
# w_list

# %%
def cut_to_word(s):
    blCondition=False
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    combieNO=''
    beforeWord=''
    blAdd=True
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        conditionWord = str(combieNO) + str(w)
        
        if combieNO != '' and len(w)>1:# and len(conditionWord) == 4:
            combie = combie + w +','
            combie = combie+combieNO+w
            #print(combieNO+w)
        else:        
            #87.2%=>
            if w in ['修改','顯示','申請單','問題','系統'] and beforeWord!='' and blCondition and len(w)>1:
                combie = combie +w+','
                combie = combie+beforeWord+w
            else:
                if w not in ['無法'] and len(w)>1:
                    combie = combie + w
                else:
                    blAdd=False
                 
        if i < len(w_list) - 1 and combie !='' and blAdd:
            combie = combie + ','
            
        blAdd = True
        if w in ['無法','不能'] and blCondition:#,'安裝','編輯','刪除','新增','作業','忘記','系統','發生','作業','下載','上傳','開啟','安裝']#,'加班','請假','預約','作業'
            combieNO = w
        else:
            combieNO = ''
        beforeWord=w
    return combie    

# print (cut_to_word('可以幫我聯絡'.strip()))
df_all['cut_words'] = df_all['description_clean'].apply(lambda s: cut_to_word(s.strip()))

# %%
# 資料打散
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_all.head()
# Out:
#                                          description    category_a  \
# 0          \\qrdcfs01\vncviewer 沒有Server版本, 無法讓對方連過來            網管
# 1                                    開薪資信後OUTLOOK打不開            網管
# 2                                        無法logon SAP  SAP-168(QCI)
# 3                                sap34無法登入  分機：15327  SAP-168(QCI)
# 4  分機: 14123  問題: outlook 收信後，原收件位置的垃圾郵件資料夾有顯示未讀數...            網管
#
#    category_b category_c   category_d    category  \
# 0    作業系統與印表機       軟體問題       軟體安裝問題          其他
# 1  Outlook與郵件    Outlook   Outlook點不開  Outlook與郵件
# 2       Basis         其它  無法logon SAP         SAP
# 3       Basis         其它  無法logon SAP         SAP
# 4  Outlook與郵件    Outlook     信件有時無法下載  Outlook與郵件
#
#                           description_clean  category_target  \
# 0  \\qrdcfs01\vncviewer 沒有server版本 無法讓對方連過來                2
# 1                              開薪資信後outlook                0
# 2                               無法logon sap                1
# 3                                     sap34                1
# 4      outlook 收信後原收件位置的垃圾郵件資料夾有顯示未讀數字看不到郵件                0
#
#                                            cut_words
# 0           qrdcfs01,vncviewer,server,版本,對方,方連,連過,過來
# 1                                      薪資,資信,outlook
# 2                                          logon,sap
# 3                                              sap34
# 4  outlook,收信,收件,位置,垃圾,垃圾郵件,郵件,資料,資料夾,夾有,顯示,夾有顯示,...

# %%
df_all[3040:4010]
# Out:
#                                             description    category_a  \
# 3040                                        SAP二層是登入有問題  SAP-168(QCI)
# 3041                                連外網常常連不上  分機: 17332            網管
# 3042         每次進入會出現同步處理資料夾時發生錯誤 [80004005-501-4B9-560]            網管
# 3043                               本機outlook 點寄件備份就會當掉。            網管
# 3044  於公司外部使用 NB 無法透過 SSLVPN 登入 from Last Saturday. ...            網管
# 3045  HP 無法使用VPN遠端桌面連線到TAIQTADIV03 Server.  Quanta I...            網管
# 3046                                電腦無法讀取到硬碟  分機:13018            網管
# 3047       使用者反應電話和網路忽然不通(網孔編號: PP06/B342) (Ext. 12914)            網管
# 3048  hi 你好,outlook目前停留在藍色"正在啟動"畫面中已達20min(嘗試重開機依然卡在...            網管
# 3049                                     network broken            網管
# 3050                                         網路無法使用沒有訊號            網管
# 3051                          公司電腦灌好OpenVPN以後,用外網測試無法啟動            網管
# 3052                       Port不通, Port numberPC23 B047            網管
# 3053                                  重新開機後網路還是不斷出現驗證訊息            網管
# 3054  OpenVPN 連線後 show 綠色, 但無法上網或連到公司的系統. BPM, PLM 也...            網管
# 3055                                            p44網孔不通            網管
# 3056                                  今天連到外網時,全部被鎖,無法連上            網管
# 3057       使用者反應目前網路孔無法使用，另外一位同仁工號:10208038也是同樣問題，請協助處理            網管
# 3058                       PD03/D051 Port 網路不通(連接網線無訊號)            網管
# 3059                    outlook收件延遲,最久延遲到1天以上(手機收信不會延遲)            網管
# 3060                                    sales查詢產線及產銷的PO  SAP-168(QCI)
# 3061                                外部郵件傳送問題詢問, 分機17012            網管
# 3062                                 分機18400 北東棟4樓 A365            網管
# 3063                                  新人，網孔不通：PP02 D338            網管
# 3064                        USER 無法 LOGON SAP, EXT13142  SAP-168(QCI)
# 3065                                   網路版 outlook無法開啟。            網管
# 3066  用remote desktop上網  but webpage shows "license ...            網管
# 3067  在QITS系統中的search功能, 是否能新增一個條件"Discretionary Fie...       R&D資訊系統
# 3068  出差至大陸電腦損壞，當地MIS以協助提供電腦，但是硬碟接上網路無法使用；聯絡方式：38760...            網管
# 3069            今天無法連上客人的網頁，但是其他對外的網頁均可正常顯示，煩請處理 #12354            網管
# ...                                                 ...           ...
# 3980  開啟薪資單信件時，經常出現"Cannot generate SSPI context"、"開...            網管
# 3981                                             更新安裝失敗            網管
# 3982                             N152會議室網孔 PC05 B029 不通            網管
# 3983                              HR部份印表機皆為離線狀態  #11388            網管
# 3984   無法 輸入 起始日期,   到期日期  連 此項 19999問題單,  也無法填寫 希望完成日期       BPM平台系統
# 3985  顯示 server error in Certificaiton Application  ...            網管
# 3986                                      network issue            網管
# 3987                                             重複收到信件            網管
# 3988         雙作業系統，MAC的部分連上Staff ，顯示需要憑證信任設定，輸入工號密碼還是不行            網管
# 3989              聯想開啟FTP，需要我們把資料丟到他們的FTP上面。  EXT:11566            網管
# 3990                                分機12778，outlook 不能用            網管
# 3991  今天(8/27)原本不透過部門server無法連上網, 但此問題你們已幫我解決, 但現在無法...            網管
# 3992           BPM 畫面出來很慢, 且左手邊的選項一直無法正常顯示, 無法key 訪客申請單       BPM平台系統
# 3993                            無法收到廠商litepoint.com 的信件            網管
# 3994                                            無法連外部網站            網管
# 3995                                      廠商提供的軟體安裝上有問題            網管
# 3996                          1.  無法開啟公告信   2.  無法開啟薪資單            網管
# 3997                                             外部網路不通            網管
# 3998  座位網路孔的網路不通, 將網路線插入NB, 控制台的區域連線都是''已拔除網路電纜''. 插...            網管
# 3999                Outlook mail 展運及其他廠商信件被退件    #16911            網管
# 4000                           網路孔有問題,伺服器的網路狀態不穩定,請協助處理            網管
# 4001           每次開啟outlook會出現驗證資料完整性,每次都需要超過半天時間,無法進行工作            網管
# 4002        使用搬移規則，但系統提示與伺服器端規則衝突，無法正常使用進行搬移。  分機：13738            網管
# 4003       使用者反應從外部公司網站連進SLVPN的MyeHR有相當多功能不能使用，請協助處理，謝謝        內部資訊系統
# 4004  User was unabl to login ASP via my Quanta Web ...  SAP-168(QCI)
# 4005              USER表示NB1有一網孔會拿到10.243.8.96的IP..請協助調整            網管
# 4006                                    欲切割信件 以日期做區分來接收            網管
# 4007                           開機之後電腦會出現有檔案遺失的訊息 #13489            網管
# 4008                  收信件可以收到local端 但是寄件備份還是線上,詢問如何修改設定            網管
# 4009                    網孔port被鎖住 :PO24 C336  ext:17320            網管
#
#       category_b      category_c    category_d    category  \
# 3040       Basis              帳號        帳號無法使用         SAP
# 3041          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3042  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 3043  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 3044       VPN連線        SSLVPN問題          無法登入          網路
# 3045          網路    無法連到某台Server  無法連到某些Server          網路
# 3046    作業系統與印表機              其它          其他事項          其他
# 3047          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3048  Outlook與郵件         Outlook    Outlook點不開  Outlook與郵件
# 3049          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3050          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3051       VPN連線        SSLVPN問題          無法登入          網路
# 3052          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3053          網路          電腦網路不通    網路不斷出現驗證訊息          網路
# 3054       VPN連線        SSLVPN問題          無法登入          網路
# 3055          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3056          網路    無法連到某台Server  無法連到某些Server          網路
# 3057          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3058          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3059  Outlook與郵件         Outlook      信件有時無法下載  Outlook與郵件
# 3060          MM      Purchasing      PO issue         SAP
# 3061  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 3062          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3063          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3064       Basis              其它   無法logon SAP         SAP
# 3065  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 3066          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3067      測試相關服務  【QITS】研發議題追蹤系統        相關操作詢問        資訊系統
# 3068          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3069          網路    無法連到某台Server  無法連到某些Server          網路
# ...          ...             ...           ...         ...
# 3980  Outlook與郵件         Outlook       無法開啟薪資單  Outlook與郵件
# 3981    作業系統與印表機            軟體問題        軟體安裝問題          其他
# 3982          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3983    作業系統與印表機           印表機問題       印表機無法列印          其他
# 3984     事務類相關服務       電腦外帶攜出申請單        系統無法登入        資訊系統
# 3985  Outlook與郵件         Outlook       無法開啟薪資單  Outlook與郵件
# 3986          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3987  Outlook與郵件         Outlook       信件會重複收到  Outlook與郵件
# 3988          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3989    檔案共用或FTP       FTP連線與上下載     無法連到外部FTP          其他
# 3990  Outlook與郵件         Outlook        郵件無法收發  Outlook與郵件
# 3991          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3992     事務類相關服務           訪客申請單        系統無法登入        資訊系統
# 3993  Outlook與郵件          郵件傳送追蹤      沒有收到某封郵件  Outlook與郵件
# 3994          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3995    作業系統與印表機            軟體問題        軟體安裝問題          其他
# 3996  Outlook與郵件         Outlook       無法開啟薪資單  Outlook與郵件
# 3997          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3998          網路          電腦網路不通   網路不通 (QRDC)          網路
# 3999  Outlook與郵件         Outlook        郵件無法收發  Outlook與郵件
# 4000          網路          電腦網路不通   網路不通 (QRDC)          網路
# 4001  Outlook與郵件         Outlook    Outlook點不開  Outlook與郵件
# 4002  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 4003      人資資訊系統       MyeHR相關服務          系統操作        資訊系統
# 4004       Basis              其它   無法logon SAP         SAP
# 4005          網路          電腦網路不通   網路不通 (QRDC)          網路
# 4006  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 4007        電腦防毒          防毒軟體操作        其他防毒相關          其他
# 4008  Outlook與郵件         Outlook          其他問題  Outlook與郵件
# 4009          網路          電腦網路不通   網路不通 (QRDC)          網路
#
#                                       description_clean  category_target  \
# 3040                                        sap二層是登入有問題                1
# 3041                                             連外網連不上                3
# 3042                          每次進入會出現同步資料夾時發生錯誤 84b9560                0
# 3043                                本機outlook 點寄件備份就會當掉                0
# 3044  於公司外部使用 nb 無法透過 sslvpn 登入 from last saturday. ...                3
# 3045  hp vpn遠端桌面連線到taiqtadiv03 server.  quanta ip 10...                3
# 3046                                          電腦無法讀取到硬碟                2
# 3047                                和網路不通網孔編號 pp06/b342                3
# 3048  outlook目前停留在藍色啟動畫面中已達20min嘗試重開機依然卡在這畫面skype正常可...                0
# 3049                                     network broken                3
# 3050                                             網路沒有訊號                3
# 3051                           公司電腦灌好openvpn以後用外網測試無法啟動                3
# 3052                        port不通 port numberpc23 b047                3
# 3053                                    重新開機後網路不斷出現驗證訊息                3
# 3054      openvpn 連線後 show 綠色 但無法上網或連到公司的系統. bpm plm 也都                3
# 3055                                            p44網孔不通                3
# 3056                                      連到外網時全部被鎖無法連上                3
# 3057                                      目前網路孔一位也是同樣問題                3
# 3058                         pd03/d051 port 網路不通連接網線無訊號                3
# 3059                           outlook收件延遲最久延遲到1天以上收信延遲                0
# 3060                                      sales產線及產銷的po                1
# 3061                                         外部郵件傳送問題詢問                0
# 3062                                         北東棟4樓 a365                3
# 3063                                    新人網孔不通pp02 d338                3
# 3064                                       無法 logon sap                1
# 3065                                        網路版 outlook                0
# 3066  用remote desktop上網  but webpage shows license e...                3
# 3067  在qits系統中的search功能 是否能新增一個條件discretionary field...                4
# 3068                          至電腦損壞當地mis以協助提供電腦硬碟接上網路方式                3
# 3069                               無法連上客人的網頁對外的網頁均可正常顯示                3
# ...                                                 ...              ...
# 3980  開啟薪資單信件時出現cannot generate sspi cont開啟受資訊版權管理保護...                0
# 3981                                             更新安裝失敗                2
# 3982                             n152會議室網孔 pc05 b029 不通                3
# 3983                                      hr部份印表機皆為離線狀態                2
# 3984          無法 輸入 起始日期   到期日期  連 此項 問題單  也無法填寫 希望完成日期                4
# 3985       顯示 server error in certificaiton application                0
# 3986                                            network                3
# 3987                                             重複收到信件                0
# 3988                雙作業系統mac的部分連上staff 顯示需要憑證信任設定輸入密碼不行                3
# 3989                               聯想開啟ftp需要把資料丟到的ftp上面                2
# 3990                                        outlook 不能用                0
# 3991  8/27原本不透過部門server無法連上網 但此問題已幫 但現在無法透過部門server連...                3
# 3992               bpm 畫面出來很慢 且左手邊的選項無法正常顯示 無法key 訪客申請單                4
# 3993                            無法收到廠商litepoint.com 的信件                0
# 3994                                            無法連外部網站                3
# 3995                                      廠商提供的軟體安裝上有問題                2
# 3996                                  1.  公告信   2.  薪資單                0
# 3997                                             外部網路不通                3
# 3998  座位網路孔的網路不通 將網路線插入nb 控制台的區域連線都是''已拔除網路電纜''. 插入座...                3
# 3999                            outlook mail 展運他廠商信件被退件                0
# 4000                                  網路孔有問題伺服器的網路狀態不穩定                3
# 4001             每次開啟outlook會出現驗證資料完整性每次都需要超過半天時間無法進行工作                0
# 4002                     使用搬移規則但系統提示與伺服器端規則衝突無法正常使用進行搬移                0
# 4003                     從外部公司網站連進slvpn的myehr有相當多功能不能使用                4
# 4004  was unabl to login asp via my quanta web site....                1
# 4005                     表示nb1有一網孔會拿到10.243.8.96的ip..調整                3
# 4006                                    欲切割信件 以日期做區分來接收                0
# 4007                                  開機之後電腦會出現有檔案遺失的訊息                2
# 4008                           收信件可以收到local端 寄件備份線上詢問設定                0
# 4009                                網孔port被鎖住 po24 c336                3
#
#                                               cut_words
# 3040                                  sap,二層,登入,問題,登入問題
# 3041                                          外網,連不上,不上
# 3042        每次,進入,入會,出現,同步,資料,資料夾,發生,發生錯誤,生錯,錯誤,84b9560
# 3043                                本機,outlook,寄件,備份,當掉
# 3044  公司,外部,使用,nb,透過,sslvpn,登入,from,last,saturday,連入...
# 3045  hp,vpn,遠端,遠端桌面,桌面,連線,連線到,taiqtadiv03,server,qu...
# 3046                                        電腦,讀取,取到,硬碟
# 3047                      網路,網路不通,不通,網孔,孔編,編號,pp06,b342
# 3048  outlook,目前,停留,留在,藍色,啟動,動畫,畫面,20min,嘗試,重開,開機,依然...
# 3049                                     network,broken
# 3050                                              網路,訊號
# 3051                    公司,電腦,灌好,openvpn,以後,後用,外網,測試,啟動
# 3052                       port,不通,port,numberpc23,b047
# 3053                 重新,開機,網路,網路不斷出現驗證訊息,不斷,斷出,出現,驗證,訊息
# 3054  openvpn,連線,show,綠色,無法上網,法上,上網,連到,公司,系統,公司系統,bp...
# 3055                                          p44,網孔,不通
# 3056                                   連到,外網,全部,無法連上,連上
# 3057                             目前,網路,一位,也是,同樣,問題,同樣問題
# 3058              pd03,d051,port,網路,網路不通,不通,通連,連接,網線,訊號
# 3059                 outlook,收件,延遲,最久,延遲,遲到,以上,上收,收信,延遲
# 3060                                     sales,產線,產銷,po
# 3061                           外部,郵件,郵件傳送,傳送,問題,傳送問題,詢問
# 3062                                            北東,a365
# 3063                                 新人,網孔,不通,pp02,d338
# 3064                                          logon,sap
# 3065                                     網路,網路版,outlook
# 3066  remote,desktop,上網,but,webpage,shows,license,ex...
# 3067  qits,系統,qits系統,中的,search,功能,是否,新增,一個,條件,discre...
# 3068            電腦,損壞,當地,mis,協助,提供,供電,電腦,硬碟,接上,上網,網路,方式
# 3069                  無法連上,連上,上客,客人,網頁,對外,網頁,正常,顯示,正常顯示
# ...                                                 ...
# 3980  開啟,薪資,薪資單,信件,出現,cannot,generate,sspi,cont,開啟,資...
# 3981                                        更新,新安,安裝,失敗
# 3982                        n152,會議,會議室,網孔,pc05,b029,不通
# 3983                         hr,部份,印表,印表機,離線,離線狀態,線狀,狀態
# 3984  輸入,起始,起始日,日期,到期,到期日,期日,日期,此項,問題,此項問題,填寫,希望,完成,...
# 3985       顯示,server,error,in,certificaiton,application
# 3986                                            network
# 3987                                           重複,收到,信件
# 3988  作業,作業系統,系統,作業系統系統,mac,部分,連上,staff,顯示,staff顯示,需...
# 3989                       聯想,想開,開啟,ftp,需要,資料,丟到,ftp,上面
# 3990                                         outlook,能用
# 3991  27,原本,透過,部門,server,無法連上,連上,上網,問題,上網問題,現在,透過,部門...
# 3992  bpm,畫面,很慢,左手,左手邊,手邊,選項,無法正常顯示,正常,顯示,正常顯示,key,訪...
# 3993                     無法收到,收到,廠商,litepoint,com,的信,信件
# 3994                                              外部,網站
# 3995                     廠商,提供,軟體,軟體安裝,安裝,裝上,上有,問題,上有問題
# 3996                                          公告,薪資,薪資單
# 3997                                      外部,網路,網路不通,不通
# 3998  座位,網路,網路,網路不通,不通,網路,網路線,路線,線插,插入,nb,控制,控制台,制台,...
# 3999                              outlook,mail,廠商,信件,退件
# 4000                       網路,問題,孔問題,伺服,伺服器,網路,狀態,不穩,穩定
# 4001  每次,開啟,outlook,出現,驗證,資料,資料完整,完整,完整性,每次,需要,超過,過半...
# 4002       使用,搬移,規則,系統,規則系統,提示,伺服,伺服器,規則,衝突,正常,使用,進行,搬移
# 4003     外部,公司,網站,連進,slvpn,myehr,相當,多功,多功能,功能,能不,能不能,使用
# 4004  was,unabl,to,login,asp,via,my,quanta,web,site,...
# 4005                 表示,nb1,有一,一網,網孔,拿到,10,243,96,ip,調整
# 4006                                  切割,信件,日期,區分,分來,接收
# 4007                            開機,之後,電腦,出現,現有,檔案,遺失,訊息
# 4008                      收信,信件,收到,local,寄件,備份,線上,詢問,設定
# 4009                               網孔,port,鎖住,po24,c336
#
# [970 rows x 9 columns]

# %%
# 切分資料
X = df_all['cut_words']
y = df_all['category_target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 40)

# %%
X_train.head()
# Out:
# 4483                                   搜尋,搜尋到,尋到,staff,網路
# 2179                              郵件,件夾,夾帶,檔案,後會,公司,檔掉,寄出
# 4810                 有線,有線網,有線網路,線網,網路,頻繁,斷網,網孔,pd07,b055
# 2209                                       網路,自動,斷線,內網,收信
# 5179    信件,超連結,連結,連結點,結點,點選,時會,出現,阻檔,視窗,複製,超連結,連結,放置,瀏...
# Name: cut_words, dtype: object

# %%
# label 做 onehot
y_train_one_hot = np_utils.to_categorical(y_train)
y_val_one_hot = np_utils.to_categorical(y_val)
print (y_train_one_hot[0])
print (y_val_one_hot[0])
# 總共類別數
num_classes = len((y_train_one_hot[0]))
print ('num_classes = {}'.format(num_classes))
# Out:
# [0. 0. 0. 1. 0.]
# [1. 0. 0. 0. 0.]
# num_classes = 5

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 30

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(X_train)
token_intent.fit_on_texts(X_val)

def preprocessing(x, max_len):

    #將文字轉為數字序列
    train_seq_intent = token_intent.texts_to_sequences(x)
    
    #print(char_index)
    # 截長補短，讓所有數字序列長度一樣
    data = sequence.pad_sequences(train_seq_intent, maxlen=MAX_LEN)
    # print train_data_intent.shape
    return data

x_train = preprocessing(X_train, max_len=MAX_LEN)
x_val = preprocessing(X_val, max_len=MAX_LEN)
char_index = token_intent.word_index

# %%
x_train
# Out:
# array([[   0,    0,    0, ...,  803,   87,    1],
#        [   0,    0,    0, ...,   18, 2334,  170],
#        [   0,    0,    0, ..., 2692,   26, 3194],
#        ...,
#        [   0,    0,    0, ...,    0,    1,    3],
#        [   0,    0,    0, ...,  729,  687, 2675],
#        [   0,    0,    0, ..., 2724,  913,  211]], dtype=int32)

# %%
# set parameters:
max_features = 5001
maxlen = 100
batch_size = 20
embedding_dims = 50
filters = 100
kernel_size = 10
hidden_dims = 250
epochs = 10
train_ratio = 0.9

# %%
from keras.layers import Layer
def dot_product(x, kernel):
    """
    Wrapper for dot product operation, in order to be compatible with both
    Theano and Tensorflow
    Args:
        x (): input
        kernel (): weights
    Returns:
    """
    if K.backend() == 'tensorflow':
        return K.squeeze(K.dot(x, K.expand_dims(kernel)), axis=-1)
    else:
        return K.dot(x, kernel)
 
 
class AttentionWithContext(Layer):
    """
    Attention operation, with a context/query vector, for temporal data.
    Supports Masking.
    Follows the work of Yang et al. [https://www.cs.cmu.edu/~diyiy/docs/naacl16.pdf]
    "Hierarchical Attention Networks for Document Classification"
    by using a context vector to assist the attention
    # Input shape
        3D tensor with shape: `(samples, steps, features)`.
    # Output shape
        2D tensor with shape: `(samples, features)`.
    How to use:
    Just put it on top of an RNN Layer (GRU/LSTM/SimpleRNN) with return_sequences=True.
    The dimensions are inferred based on the output shape of the RNN.
    Note: The layer has been tested with Keras 2.0.6
    Example:
        model.add(LSTM(64, return_sequences=True))
        model.add(AttentionWithContext())
        # next add a Dense layer (for classification/regression) or whatever...
    """
 
    def __init__(self,
                 W_regularizer=None, u_regularizer=None, b_regularizer=None,
                 W_constraint=None, u_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
 
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')
 
        self.W_regularizer = regularizers.get(W_regularizer)
        self.u_regularizer = regularizers.get(u_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)
 
        self.W_constraint = constraints.get(W_constraint)
        self.u_constraint = constraints.get(u_constraint)
        self.b_constraint = constraints.get(b_constraint)
 
        self.bias = bias
        super(AttentionWithContext, self).__init__(**kwargs)
 
    def build(self, input_shape):
        assert len(input_shape) == 3
 
        self.W = self.add_weight((input_shape[-1], input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        if self.bias:
            self.b = self.add_weight((input_shape[-1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
 
        self.u = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_u'.format(self.name),
                                 regularizer=self.u_regularizer,
                                 constraint=self.u_constraint)
 
        super(AttentionWithContext, self).build(input_shape)
 
    def compute_mask(self, input, input_mask=None):
        # do not pass the mask to the next layers
        return None
 
    def call(self, x, mask=None):
        uit = dot_product(x, self.W)
 
        if self.bias:
            uit += self.b
 
        uit = K.tanh(uit)
        ait = dot_product(uit, self.u)
 
        a = K.exp(ait)
 
        # apply mask after the exp. will be re-normalized next
        if mask is not None:
            # Cast the mask to floatX to avoid float64 upcasting in theano
            a *= K.cast(mask, K.floatx())
 
        # in some cases especially in the early stages of training the sum may be almost zero
        # and this results in NaN's. A workaround is to add a very small positive number ε to the sum.
        # a /= K.cast(K.sum(a, axis=1, keepdims=True), K.floatx())
        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())
 
        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)
 
    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[-1]

# %%
# https://www.kaggle.com/qqgeogor/keras-lstm-attention-glove840b-lb-0-043
from keras.engine.topology import Layer
from keras import initializers, regularizers, constraints
from keras import backend as K
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
#84.6%,83%,84%,83.9%,85%,84%,85.3%,86.2%
from keras.layers import core,BatchNormalization
from keras.layers import CuDNNLSTM
def BidCuDNNLSTM2(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
#     model.add(GRU(128))
    model.add(Bidirectional(CuDNNLSTM(32)))#, return_sequences=True
#    model.add(Attention(30))
#     model.add(Bidirectional(LSTM(128,implementation=2)))
    model.add(Dropout(0.5))
    model.add(Dense(16,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#83.8%,83.4%,83.9%,84.8%,84.3%,87.7%
def BidCuDNNLSTM2_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
#     model.add(GRU(128))
    model.add(Bidirectional(CuDNNLSTM(32, return_sequences=True)))#
    model.add(AttentionWithContext())
#     model.add(Bidirectional(LSTM(128,implementation=2)))
    model.add(Dropout(0.5))
    model.add(Dense(16,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#84.7%,88.29%
def BidLSTM_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(LSTM(32,implementation=2, return_sequences=True))
    model.add(AttentionWithContext())
    #model.add(Flatten())
    #model.add(Dense(64,activation='tanh'))
    model.add(Dense(16,activation='relu'))
    model.add(Dropout(0.5))
    #model.add(Dense(50,activation='tanh'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#74.8%#83%,82%,84%,83%,81%
def BidLSTM(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
#     model.add(GRU(128))
    model.add(Bidirectional(LSTM(32)))
#     model.add(Bidirectional(LSTM(128,implementation=2)))

    model.add(Dense(16,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#79%,83%
def BidCuDNNGRU(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(Bidirectional(CuDNNGRU(64)))#
    #model.add(Conv1D(32, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform"))
    #model.add(Attention(29))
    model.add(Dropout(0.5))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#70.2%,83.7%,83.18%,83.8%
def BidCuDNNGRU_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(CuDNNGRU(64,return_sequences=True))#
    model.add(Conv1D(32, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform"))
    model.add(AttentionWithContext())
    model.add(Dropout(0.5))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
def GRU2(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(Bidirectional(GRU(64)))#return_sequences=True
    #model.add(Conv1D(32, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform"))
    #model.add(Attention(29))
    model.add(Dropout(0.5))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#84%,81.9%
def GRU_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(GRU(64,return_sequences=True))#
    model.add(Conv1D(32, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform"))
    model.add(AttentionWithContext())
    model.add(Dropout(0.5))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#84.09%,85.5%,84.6%,86%,84.9%,87.8%,86.8%
#https://github.com/jdp527/DL_Text_Classification/blob/master/models/gpu_model.py
#https://aclweb.org/anthology/C16-1329
def blstm_2dcnn(num_classes, max_features, maxlen,embed_size,
               embedding_dropout = .5,
               blstm_units = 1024,
               blstm_dropout = .2,
               cnn_filters = 256,
               cnn_kernel_size = (5,5),
               max_pool_size = (5,5),
               dense_dropout = .5,
               l2_reg = .00001,
               gpus = 2):
    
    '''
    Bidirectional LSTM with Two-dimensional Max Pooling
    
    :param maxlen: max length of sequence
    :param max_features: max number of word embeddings
    :param embed_size: dimension of word embeddings
    :param embedding_matrix: embedding matrix created from embed file
    :param embedding_dropout: dropout after embedding layer
    :param blstm_units: number of lstm units for the biderectional lstm
    :param blstm_dropout: dropout after the blstm layer
    :param cnn_filters: number of CNN filters
    :param cnn_kernel_size: kernel size of the convolution
    :param max_pool_size: max pool size
    :param dense_dropout: dropout before dense layer
    :param l2_reg: l2 kernel regularizer parameter
    :gpus: number of gpus
    :returns: Keras parallel model
    '''
    
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size, #weights=[embedding_matrix], 
                  input_length=maxlen)(inp)
    x = Dropout(embedding_dropout)(x)    

    x = Bidirectional(CuDNNLSTM(blstm_units, return_sequences=True), merge_mode='sum')(x)
    x = Dropout(blstm_dropout)(x)
    x = Reshape((maxlen, blstm_units, 1))(x)

    x = Conv2D(cnn_filters, kernel_size=cnn_kernel_size, padding='valid', kernel_initializer='glorot_uniform')(x)
    x = MaxPool2D(pool_size=max_pool_size)(x)

    x = Flatten()(x)
    x = Dropout(dense_dropout)(x)
    x = Dense(num_classes, activation = "softmax",  kernel_regularizer=regularizers.l2(l2_reg))(x)
    
    parallel_model = Model(inputs = inp, outputs = x)
    #parallel_model = multi_gpu_model(parallel_model, gpus=gpus)
    parallel_model.summary()
    return parallel_model

# %%
#85.2%,85.4%,86%,85.5%,87.9%,87.4%,87.3%,87.5%,88%,87.6%,88.1%,88%,88.8%
def bgru_2dcnn(num_classes, max_features, maxlen,embed_size,
               embedding_dropout = .5,
               bgru_units = 1024,
               bgru_dropout = .2,
               cnn_filters = 256,
               cnn_kernel_size = (5,5),
               max_pool_size = (5,5),
               dense_dropout = .5,
               l2_reg = .00001,
               gpus = 2):
    
    '''
    Bidirectional GRU with Two-dimensional Max Pooling
    
    :param maxlen: max length of sequence
    :param max_features: max number of word embeddings
    :param embed_size: dimension of word embeddings
    :param embedding_matrix: embedding matrix created from embed file
    :param embedding_dropout: dropout after embedding layer
    :param bgru_units: number of gru units for the biderectional gru
    :param bgru_dropout: dropout after the bgru layer
    :param cnn_filters: number of cnn filters
    :param cnn_kernel_size: kernel size of the convolution
    :param max_pool_size: max pool size
    :param dense_dropout: dropout before dense layer
    :param l2_reg: l2 kernel regularizer parameter
    :gpus: number of gpus
    :returns: Keras parallel model
    '''
    
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size, #weights=[embedding_matrix], 
                  input_length=maxlen)(inp)
    x = Dropout(embedding_dropout)(x)    

    x = Bidirectional(CuDNNGRU(bgru_units, return_sequences=True), merge_mode='sum')(x)
    x = Dropout(bgru_dropout)(x)
    x = Reshape((maxlen, bgru_units, 1))(x)

    x = Conv2D(cnn_filters, kernel_size=cnn_kernel_size, padding='valid', kernel_initializer='glorot_uniform')(x)
    x = MaxPool2D(pool_size=max_pool_size)(x)

    x = Flatten()(x)
    x = Dropout(dense_dropout)(x)
    x = Dense(num_classes, activation = "softmax",  kernel_regularizer=regularizers.l2(l2_reg))(x)
    
    parallel_model = Model(inputs = inp, outputs = x)
    #parallel_model = multi_gpu_model(parallel_model, gpus=gpus)
    #parallel_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return parallel_model

# %%
from keras.layers import TimeDistributed
def HAM(num_classes, vocab_size, sentence_max_len,embedding_dim):
    GPU_IMPL = 2          
    GRU_UNITS = 100   
    REG_PARAM = 1e-13
    l2_reg = regularizers.l2(REG_PARAM)
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(Bidirectional(GRU(64,return_sequences=True,kernel_regularizer=l2_reg, 
                           implementation=GPU_IMPL)))#
    model.add(AttentionWithContext())
    model.add(Dropout(0.5))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
model = bgru_2dcnn(num_classes, NUM_WORDS, MAX_LEN,32)
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model_path = '{}.h5'.format('19999_rnn')

epochs = 50
batch_size = 32
train_ratio = 0.9

checkpoint = ModelCheckpoint(model_path, monitor='val_acc', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=3, verbose=1)

model_history = model.fit(x=x_train, y=y_train_one_hot,
                            batch_size=batch_size, 
                            epochs=epochs,
                            validation_split= 1 - train_ratio
                          ,callbacks = [checkpoint, earlystop]
                         )
# Out:
# Train on 10257 samples, validate on 1140 samples
# Epoch 1/50
# 10257/10257 [==============================] - 24s 2ms/step - loss: 0.8780 - acc: 0.6692 - val_loss: 0.5295 - val_acc: 0.8184
#
# Epoch 00001: val_acc improved from -inf to 0.81842, saving model to 19999_rnn.h5
# Epoch 2/50
# 10257/10257 [==============================] - 20s 2ms/step - loss: 0.4701 - acc: 0.8424 - val_loss: 0.3881 - val_acc: 0.8728
#
# Epoch 00002: val_acc improved from 0.81842 to 0.87281, saving model to 19999_rnn.h5
# Epoch 3/50
# 10257/10257 [==============================] - 20s 2ms/step - loss: 0.3378 - acc: 0.8923 - val_loss: 0.3577 - val_acc: 0.8825
#
# Epoch 00003: val_acc improved from 0.87281 to 0.88246, saving model to 19999_rnn.h5
# Epoch 4/50
# 10257/10257 [==============================] - 20s 2ms/step - loss: 0.2665 - acc: 0.9179 - val_loss: 0.3746 - val_acc: 0.8807
#
# Epoch 00004: val_acc did not improve from 0.88246
# Epoch 5/50
# 10257/10257 [==============================] - 20s 2ms/step - loss: 0.2359 - acc: 0.9288 - val_loss: 0.3851 - val_acc: 0.8789
#
# Epoch 00005: val_acc did not improve from 0.88246
# Epoch 6/50
# 10257/10257 [==============================] - 20s 2ms/step - loss: 0.2095 - acc: 0.9363 - val_loss: 0.3790 - val_acc: 0.8842
#
# Epoch 00006: val_acc improved from 0.88246 to 0.88421, saving model to 19999_rnn.h5
# Epoch 00006: early stopping

# %%
from keras import models
model=models.load_model(model_path)

# %%
# %pylab inline
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['concatenate', 'add']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
show_train_history(model_history,'acc','val_acc')

# %%
show_train_history(model_history,'loss','val_loss')

# %%
def to_cat_name(x): 
        return mapping[x]
    
def predict(test):
#     model = load_model(model_path)
    y_predict_probability = model.predict(test)
    y_predict = model.predict_classes(test)

    return to_cat_name(y_predict), y_predict, y_predict_probability

def predict_class(data):
    y_predict_probability = model.predict(data, batch_size=64, verbose=1)
    predict_arr = []
    predictClass = []
    for row in y_predict_probability: 
            classIndex=0
            selectClass=0
            selectProbability=0
            for item in row: 
                #print(float(item))
                if(selectProbability <= float(item)):
                    #print(classIndex)
                    selectProbability=float(item)
                    selectClass=classIndex
                classIndex=classIndex+1
            predictClass.append(selectClass)
            
    return to_cat_name(predictClass),predictClass,y_predict_probability

y_predict_name, y_predict, y_predict_probability = predict_class(x_val)
# Out:
# 2850/2850 [==============================] - 2s 647us/step

# %%
answer_name = to_cat_name(y_val)

# %%
#model.predict_classes(x_val)

# %%
x_val
# Out:
# array([[   0,    0,    0, ...,  130, 2190,  475],
#        [   0,    0,    0, ...,   46, 1182,  922],
#        [   0,    0,    0, ...,  553, 2707,  487],
#        ...,
#        [   0,    0,    0, ...,   50, 1922,  931],
#        [   0,    0,    0, ...,  115,  127,  200],
#        [   0,    0,    0, ...,   12,   50,   38]], dtype=int32)

# %%
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
# model.predict(x_val)

# %%
# predict_df = pd.DataFrame({'1_sentence':df_test.sentence,
#               '2_y_predict':y_predict,
#               '3_y_predict_name':y_predict_name,
#               '4_answer':df_test.target,
#               '5_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
predict_df = pd.DataFrame({
              '1_sentence':X_val,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_val,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.8754385964912281 !!!!!!!!

# %%
predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
# Out:
#                                               1_sentence  2_y_predict  \
# 146        從公,公司,公司網域,網域,不到,客人,ftp,server,ftp,usa,hp,com            2
# 9369                      桌上,桌上型,pc,安裝,裝好,os,需要,協助,網域,設定            2
# 8910                                             印表,印表機,            2
# 3779                                         ecn,認証,ecn0            3
# 1029   daisy,yu,sit,測試,三部,測試,二課,device,import,excel,發...            2
# 7945   申請,申請者,常駐,人員,使用,mac,電腦,代理,代理伺服器,伺服,伺服器,申請,申請者,...            4
# 1885   proe,使用,容易,踢出,不確,確定,是否,是否是,license,問題,license問...            4
# 7701                                   位於,反應,無法連上,連上,msn            2
# 588                                           project,安裝            1
# 13588                    開啟,ie,出現,要求,輸入,入帳,帳號,帳號密碼,密碼,畫面            0
# 11596                 無法安裝,安裝,project,出現,記憶,記憶體,容量,不足,訊息            0
# 13088                        資源,人力,管理,管理系,管理系統,系統,管理系統系統            2
# 8798                                             outlook            0
# 11853  please,help,with,it,many,quanta,mail,system,偵測...            0
# 12604  無線,無線網,無線網路,線網,網路,申請,帳號,帳號密碼,密碼,申請,申請單,申請申請單,單...            4
# 5596                                my,quanta,登錄,icon,遺失            4
# 7871          mail,超連結,連結,點選,表單,簽核,核發,發生,發生錯誤,生錯,錯誤,lync            4
# 10008                                        協理,遇到,認證,訊息            0
# 12182                      zmmi,中建,建立,model,建立,建立完,model            2
# 5510                                            pj10d202            4
# 10072  目前,前無,無法連結,連結,出勤,系統,出勤系統,畫面,訊息,錯誤,連結,網址,url,正確...            4
# 9609   電腦,出現,現無,法開,開機,情況,啟動,功能,不正,正常,電腦,log,in,quanta...            2
# 10031                                        密碼,密碼過期,過期,            3
# 9833              ctrix,之後,跳出,六七,六七個,七個,critrix,error,視窗            4
# 2126                                        設定,iphone,連線            0
# 842    在家,無法收信,收信,skype,有時,通有,有時,不通,通不,不知,不知道,知道,認證,是...            2
# 5394                                顯示,資料,資料夾,無法存取,存取,檔案            2
# 324                                        要求,輸入,輸入密碼,密碼            0
# 10250                                    無法連線,連線,edi,810            3
# 7950                                      無法連線,連線,伺服,伺服器            3
# ...                                                  ...          ...
# 7492   internet,畫面,面會,出現,access,denial,過去,曾經,發生,生過,密碼...            2
# 6957    只能,進入,公司,首頁,少許,內部,內部網,網站,pdm,bpm,windcll,無法連線,連線            4
# 12266                                             crtrix            4
# 3409                                          mailquanta            4
# 10022                            出現,要求,輸入,入帳,帳號,密碼,畫面,下午            0
# 461          點選,資料,資料夾,顯示,時顯示,資料,資料夾,無法存取,存取,檔案,存取,檔案,權限            2
# 4028                    訪客,帳號,登入,we,mail,點選,信件,內容,超連結,連結            0
# 11048                                              有毒,刪除            1
# 4510                         出現,跳出,出帳,帳號,帳號密碼,密碼,問題,密碼問題            4
# 13554                                     電腦,借給,使用,過後,密碼            3
# 9561                                            忘記,網域,密碼            3
# 3092                                      狀況,檢查,查帳,帳號,設定            1
# 9672   之前,mail,了一,一個,11,給他,希望,正常,方式,產生,公用,公用資料夾,用資,資料...            2
# 11391    使用,wifichorm,跳出,輸入,入帳,帳密,視窗,ie,直接,接報,報錯,無法連線,連線            4
# 1342   mac,os,domain,name,方式,開起,公司,公司內部,內部,內部網,網站,顯示,...            2
# 4698                                去取,取得,ip,位址,位置,卻又,取得            2
# 13723                csmc,台幹,方式,打開,outlookwb,mial,連不上,不上            3
# 3655   問題,敘述,cnbu,內部,所有,server,hste201,iot,qxdm,swqas...            4
# 2972   下午,電腦,突然,網路,網路不通,不通,右下,右下角,下角,區域,區域網路,網路,tcp,i...            2
# 2103                                can,not,access,disk,            3
# 766    開機,輸入,入帳,帳號,帳號密碼,密碼,已於,電腦,帳號,帳號密碼,密碼,無誤,登入,web...            0
# 7722   安裝,外部,軟體,連出,公司,網外,客戶,伺服,伺服器,下載,下載安裝,安裝,顯示,安裝顯示...            2
# 3046                                         電腦,讀取,取到,硬碟            4
# 7858                       聯線,以下,連結,要求,輸入,入帳,帳密,課程,報名,連結            4
# 4692                                       廠內,myquick,網頁            3
# 4107                                              csap3x            4
# 7223                                         解鎖,離職,電腦,硬碟            4
# 2328                                          附件,word,檔案            4
# 3467                              setting,error,password            4
# 10373  unable,to,share,folder,to,others,but,able,to,a...            2
#
#       3_y_predict_name  4_answer 5_answer_name  \
# 146                 其他         3            網路
# 9369                其他         3            網路
# 8910                其他         1           SAP
# 3779                網路         1           SAP
# 1029                其他         4          資訊系統
# 7945              資訊系統         3            網路
# 1885              資訊系統         2            其他
# 7701                其他         3            網路
# 588                SAP         2            其他
# 13588       Outlook與郵件         3            網路
# 11596       Outlook與郵件         2            其他
# 13088               其他         4          資訊系統
# 8798        Outlook與郵件         2            其他
# 11853       Outlook與郵件         2            其他
# 12604             資訊系統         3            網路
# 5596              資訊系統         1           SAP
# 7871              資訊系統         0    Outlook與郵件
# 10008       Outlook與郵件         3            網路
# 12182               其他         1           SAP
# 5510              資訊系統         3            網路
# 10072             資訊系統         3            網路
# 9609                其他         3            網路
# 10031               網路         2            其他
# 9833              資訊系統         1           SAP
# 2126        Outlook與郵件         3            網路
# 842                 其他         0    Outlook與郵件
# 5394                其他         0    Outlook與郵件
# 324         Outlook與郵件         3            網路
# 10250               網路         1           SAP
# 7950                網路         0    Outlook與郵件
# ...                ...       ...           ...
# 7492                其他         3            網路
# 6957              資訊系統         3            網路
# 12266             資訊系統         1           SAP
# 3409              資訊系統         3            網路
# 10022       Outlook與郵件         3            網路
# 461                 其他         0    Outlook與郵件
# 4028        Outlook與郵件         3            網路
# 11048              SAP         2            其他
# 4510              資訊系統         0    Outlook與郵件
# 13554               網路         2            其他
# 9561                網路         2            其他
# 3092               SAP         0    Outlook與郵件
# 9672                其他         1           SAP
# 11391             資訊系統         3            網路
# 1342                其他         3            網路
# 4698                其他         3            網路
# 13723               網路         0    Outlook與郵件
# 3655              資訊系統         3            網路
# 2972                其他         3            網路
# 2103                網路         1           SAP
# 766         Outlook與郵件         3            網路
# 7722                其他         3            網路
# 3046              資訊系統         2            其他
# 7858              資訊系統         3            網路
# 4692                網路         4          資訊系統
# 4107              資訊系統         1           SAP
# 7223              資訊系統         2            其他
# 2328              資訊系統         0    Outlook與郵件
# 3467              資訊系統         2            其他
# 10373               其他         3            網路
#
#                                  6_y_predict_probability
# 146    [5.5456516e-05, 9.830919e-07, 0.8385089, 0.161...
# 9369   [0.0042564906, 0.0007917691, 0.9051334, 0.0849...
# 8910   [0.038996466, 0.31548846, 0.5819055, 0.0066523...
# 3779   [0.015395353, 0.14913347, 0.029426297, 0.71482...
# 1029   [0.0024069822, 0.0002584211, 0.5256676, 0.0053...
# 7945   [0.055489246, 0.012793046, 0.21447445, 0.19748...
# 1885   [6.9293433e-06, 5.39101e-05, 0.0039337454, 0.0...
# 7701   [0.048530445, 0.0630988, 0.5377715, 0.30795252...
# 588    [0.040638402, 0.43299082, 0.07779731, 0.045984...
# 13588  [0.51535004, 0.0464177, 0.06969939, 0.13861172...
# 11596  [0.80517024, 0.0015941099, 0.13738026, 0.04535...
# 13088  [0.07604967, 0.0073324814, 0.77721095, 0.08051...
# 8798   [0.9983542, 8.262635e-06, 0.0005057475, 0.0009...
# 11853  [0.99987876, 2.5319238e-10, 0.00010964168, 1.1...
# 12604  [0.0014214824, 0.00044527763, 0.011547345, 0.3...
# 5596   [0.010847819, 0.033235196, 0.028553342, 0.0162...
# 7871   [0.0030856815, 2.2997698e-05, 0.0012289184, 3....
# 10008  [0.91682464, 0.0009994066, 0.021202186, 0.0316...
# 12182  [0.019578882, 0.17848994, 0.72519636, 0.006469...
# 5510   [0.20950711, 0.20626868, 0.12688507, 0.1861325...
# 10072  [0.0018020291, 0.0008024623, 0.17352076, 0.064...
# 9609   [0.15921581, 1.7274076e-07, 0.8397508, 0.00102...
# 10031  [0.034595147, 0.012905477, 0.36940926, 0.40834...
# 9833   [0.095561385, 0.076108426, 0.22978655, 0.13622...
# 2126   [0.35539138, 0.03915664, 0.1802628, 0.30332276...
# 842    [0.028646808, 2.1328095e-05, 0.9538702, 0.0173...
# 5394   [0.11643913, 0.046518184, 0.4226499, 0.1300060...
# 324    [0.58851874, 0.085982546, 0.015519664, 0.05054...
# 10250  [0.020993162, 0.036303695, 0.072121926, 0.7744...
# 7950   [0.14813039, 0.04358003, 0.16460405, 0.5125273...
# ...                                                  ...
# 7492   [0.0003220495, 0.31052157, 0.6485979, 0.012133...
# 6957   [0.00012768089, 0.00022200725, 0.048262957, 0....
# 12266  [0.20950711, 0.20626868, 0.12688507, 0.1861325...
# 3409   [0.20950711, 0.20626868, 0.12688507, 0.1861325...
# 10022  [0.63806945, 0.12333213, 0.023624172, 0.067494...
# 461    [0.0238445, 0.25493526, 0.37264132, 0.03046285...
# 4028   [0.9225284, 1.4859872e-05, 0.0011263653, 0.056...
# 11048  [0.14690861, 0.5031174, 0.070769966, 0.0761346...
# 4510   [0.01413698, 0.024961047, 0.048994027, 0.07424...
# 13554  [0.031709243, 0.06698166, 0.32941866, 0.448825...
# 9561   [0.015379572, 0.01325985, 0.11301894, 0.802580...
# 3092   [0.052163042, 0.5670386, 0.13232231, 0.1395056...
# 9672   [0.093940906, 0.036490925, 0.73622787, 0.04102...
# 11391  [0.028581625, 0.01094702, 0.05787666, 0.087055...
# 1342   [0.059298117, 0.0004283767, 0.8345011, 0.08033...
# 4698   [0.009982833, 0.0036882558, 0.61938965, 0.3322...
# 13723  [0.0027708265, 0.002482688, 0.01365131, 0.9772...
# 3655   [0.010967495, 0.15691496, 0.21781561, 0.002873...
# 2972   [0.0004501166, 2.0511918e-06, 0.5720403, 0.426...
# 2103   [0.063609436, 0.004533568, 0.03904276, 0.88661...
# 766    [0.9258813, 0.01326447, 0.035188712, 0.0205130...
# 7722   [0.0033057663, 0.00019218144, 0.9125142, 0.083...
# 3046   [0.2867078, 0.010802095, 0.20355612, 0.0468811...
# 7858   [0.107705206, 0.00015868703, 0.00095578947, 0....
# 4692   [0.01303458, 0.006061406, 0.01835856, 0.774011...
# 4107   [0.2095071, 0.2062687, 0.12688507, 0.1861325, ...
# 7223   [0.12771639, 0.00629179, 0.27347186, 0.0986933...
# 2328   [0.26366186, 0.008016246, 0.26782987, 0.040424...
# 3467   [0.03319708, 0.10309296, 0.050198764, 0.080677...
# 10373  [0.01819082, 0.0010144582, 0.8855971, 0.049229...
#
# [355 rows x 6 columns]

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'])
# Out:
# answer      Outlook與郵件  SAP   其他    網路  資訊系統
# predict
# Outlook與郵件         778    1   24    23     9
# SAP                  8  291   10     9    12
# 其他                  17   12  158    49    14
# 網路                   9   10   35  1021    14
# 資訊系統                14   25   25    35   247

# %%
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)
# model.save_weights("model.h5")
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")
# loaded_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# score = loaded_model.evaluate(x_test, y_test, verbose=0)
# print(score)

# %%
dfTest = pd.read_csv('data/19999_test_question.csv')#usecols=['description','category_a', 'category_a_target']

# %% [markdown]
# ## dfTest

# %%
def cut_to_word3(s):
    blCondition=True
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    combieNO=''
    beforeWord=''
    blAdd=True
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        conditionWord = str(combieNO) + str(w)
        
        if combieNO != '' and len(w)>1:# and len(conditionWord) == 4:
            combie = combie + w +','
            combie = combie+combieNO+w
            #print(combieNO+w)
        else:        
            #87.2%=>
            if w in ['修改','顯示','作業','申請單','問題','系統'] and beforeWord!='' and blCondition and len(w)>1:
                combie = combie +w+','
                combie = combie+beforeWord+w
            else:
                if w not in ['無法'] and len(w)>1:
                    combie = combie + w
                else:
                    blAdd=False
                 
        if i < len(w_list) - 1 and combie !='' and blAdd:
            combie = combie + ','
            
        blAdd = True
        if w in ['無法','不能','加班','請假','預約'] and blCondition:#,'安裝','編輯','刪除','新增','作業','忘記','系統','發生','作業','下載','上傳','開啟','安裝']
            combieNO = w
        else:
            combieNO = ''
        beforeWord=w
    return combie    

dfTest['cut_words'] = dfTest['description_clean'].apply(lambda s: cut_to_word3(s.strip()))

# %%
dfTest
# Out:
#                                 description    category  category_target  \
# 0                           218無法登入,logon失敗         SAP                1
# 1                                    無線網路不通          網路                3
# 2                   我的outlook薪資單打不開 # 19810  Outlook與郵件                0
# 3   MRO操作問題email:charles.huang@quantatw.com        資訊系統                4
# 4                             有關非法軟體安裝問題想詢問          其他                2
# 5                               電腦好像中毒了怎麼辦?          其他                2
# 6                               電腦變很慢是不是中毒?          其他                2
# 7                                 資訊需求單無法申請        資訊系統                4
# 8                       vendor data簽核流程簽到副總        資訊系統                4
# 9                                在職證明怎麼申請呢?        資訊系統                4
# 10                   CAMP密碼忘記了無法登入 很急,請盡快處理        資訊系統                4
# 11                           採購單簽核時發生錯誤!!!!        資訊系統                4
# 12                   sap168無法登入 #381-123456         SAP                1
# 13                       收發郵件,有漏信的問題啦,少很多信耶  Outlook與郵件                0
# 14                                 找不到研發服務雲        資訊系統                4
# 15                                   餐費儲值問題        資訊系統                4
# 16                              BMS怎麼系統無法登入        資訊系統                4
# 17                               異常SO單簽核有問題        資訊系統                4
# 18                               薪資系統金額顯示錯誤        資訊系統                4
# 19                                  FTP無法開啟          其他                2
# 20                            out look附件打不開  Outlook與郵件                0
# 21                    無法在手機上面使用CAMP進行表單簽核動作        資訊系統                4
# 22                              298無法logon         SAP                 1
# 23                     無法進入SAP268，請幫忙處理，謝謝！        SAP                 1
# 24    Office 所有相關都出現亂碼. 已將Office 進行移除重灌顯示亂碼          其他                2
# 25                        北棟一樓警衛電腦需要灌office          其他                2
# 26                            HP2014列印會出現亂碼          其他                2
#
#                         description_clean  \
# 0                              218logon失敗
# 1                                  無線網路不通
# 2                            我的outlook薪資單
# 3                                     mro
# 4                                非法軟體安裝問題
# 5                                   電腦中毒了
# 6                                電腦變很慢是中毒
# 7                                   資訊需求單
# 8                       vendor data簽核流程簽到
# 9                                   在職證明呢
# 10                              camp密碼忘記了
# 11                             採購單簽核時發生錯誤
# 12                                 sap168
# 13                         收發郵件有漏信的問題啦少信耶
# 14                                  研發服務雲
# 15                                 餐費儲值問題
# 16                                  bms系統
# 17                             異常so單簽核有問題
# 18                                 薪資系統金額
# 19                                    ftp
# 20                             out look附件
# 21                    無法在上面使用camp進行表單簽核動作
# 22                             298無法logon
# 23                                 sap268
# 24  office 所有相關都出現亂碼. 已將office 進行移除重灌顯示亂碼
# 25                      北棟一樓警衛電腦需要灌office
# 26                              hp列印會出現亂碼
#
#                                         cut_words
# 0                                     218logon,失敗
# 1                無線,無線網,無線網路,無線網路不通,線網,網路,網路不通,不通
# 2                                  outlook,薪資,薪資單
# 3                                             mro
# 4                    非法,軟體,軟體安裝,軟體安裝問題,安裝,問題,安裝問題
# 5                                   電腦,電腦中毒,腦中,中毒
# 6                                     電腦,很慢,是中,中毒
# 7                                       資訊,需求,需求單
# 8                       vendor,data,簽核,簽核流程,流程,簽到
# 9                                           在職,證明
# 10                                camp,密碼,密碼忘記,忘記
# 11                        採購,採購單,簽核,發生,發生錯誤,生錯,錯誤
# 12                                         sap168
# 13                              收發,發郵件,郵件,問題,信問題,
# 14                                         研發,服務,
# 15                                  餐費,儲值,問題,儲值問題
# 16                                   bms,系統,bms系統
# 17                               異常,so,簽核,問題,簽核問題
# 18                                  薪資,資系,系統,資系系統
# 19                                            ftp
# 20                                    out,look,附件
# 21                         上面,使用,camp,進行,表單,簽核,動作
# 22                                      298,logon
# 23                                         sap268
# 24  office,所有,出現,亂碼,已將,office,進行,移除,重灌,顯示,重灌顯示,亂碼
# 25                          北棟,一樓,警衛,電腦,需要,office
# 26                                    hp,列印,出現,亂碼

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 30

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(dfTest.cut_words)

x_test_new = preprocessing(dfTest.cut_words, max_len=MAX_LEN)
char_index = token_intent.word_index

# %%
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
y_test_new=dfTest.category_target

# %%
from data_utils import *

# %%
y_predict_name_new, y_predict_new, predict_arr_new,y_predict_probability_new = predict_class(model,x_test_new,64,mapping)
# Out:
# 27/27 [==============================] - 0s 3ms/step

# %%
predict_df = pd.DataFrame({'1_sentence':dfTest.description_clean,'2_sentence':dfTest.cut_words,
              '3_y_predict':y_predict_new,
              '4_y_predict_name':y_predict_name_new,
              '5_answer':y_test_new,
              '6_answer':mapping[y_test_new],
              '7_y_predict_probability':list(predict_arr_new),
              })
#print( format(y_predict_probability, '.3%'))
predict_df[:14]
# Out:
#            1_sentence                        2_sentence  3_y_predict  \
# 0          218logon失敗                       218logon,失敗            0
# 1              無線網路不通  無線,無線網,無線網路,無線網路不通,線網,網路,網路不通,不通            1
# 2        我的outlook薪資單                    outlook,薪資,薪資單            1
# 3                 mro                               mro            0
# 4            非法軟體安裝問題      非法,軟體,軟體安裝,軟體安裝問題,安裝,問題,安裝問題            3
# 5               電腦中毒了                     電腦,電腦中毒,腦中,中毒            3
# 6            電腦變很慢是中毒                       電腦,很慢,是中,中毒            0
# 7               資訊需求單                         資訊,需求,需求單            3
# 8   vendor data簽核流程簽到         vendor,data,簽核,簽核流程,流程,簽到            0
# 9               在職證明呢                             在職,證明            3
# 10          camp密碼忘記了                   camp,密碼,密碼忘記,忘記            0
# 11         採購單簽核時發生錯誤           採購,採購單,簽核,發生,發生錯誤,生錯,錯誤            0
# 12             sap168                            sap168            3
# 13     收發郵件有漏信的問題啦少信耶                 收發,發郵件,郵件,問題,信問題,            0
#
#    4_y_predict_name  5_answer    6_answer  \
# 0        Outlook與郵件         1         SAP
# 1               SAP         3          網路
# 2               SAP         0  Outlook與郵件
# 3        Outlook與郵件         4        資訊系統
# 4                網路         2          其他
# 5                網路         2          其他
# 6        Outlook與郵件         2          其他
# 7                網路         4        資訊系統
# 8        Outlook與郵件         4        資訊系統
# 9                網路         4        資訊系統
# 10       Outlook與郵件         4        資訊系統
# 11       Outlook與郵件         4        資訊系統
# 12               網路         1         SAP
# 13       Outlook與郵件         0  Outlook與郵件
#
#                               7_y_predict_probability
# 0   [Outlook與郵件:0.9950655, SAP:0.000025825306, 其他:...
# 1   [Outlook與郵件:0.048711166, SAP:0.94005007, 其他:0....
# 2   [Outlook與郵件:0.124740206, SAP:0.4060555, 其他:0.1...
# 3   [Outlook與郵件:0.9855195, SAP:0.00047182312, 其他:0...
# 4   [Outlook與郵件:0.000009397816, SAP:0.000003065449...
# 5   [Outlook與郵件:0.011623399, SAP:0.08979095, 其他:0....
# 6   [Outlook與郵件:0.65725684, SAP:0.00043244704, 其他:...
# 7   [Outlook與郵件:0.032407377, SAP:0.024061326, 其他:0...
# 8   [Outlook與郵件:0.786232, SAP:0.0000061460755, 其他:...
# 9   [Outlook與郵件:0.017573668, SAP:0.015880203, 其他:0...
# 10  [Outlook與郵件:0.9686822, SAP:0.0017304672, 其他:0....
# 11  [Outlook與郵件:0.9954796, SAP:0.00000016510648, 其...
# 12  [Outlook與郵件:0.12467791, SAP:0.09521082, 其他:0.1...
# 13  [Outlook與郵件:0.95638907, SAP:0.000026969989, 其他...
