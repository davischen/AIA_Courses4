# %% [markdown]
# # 1. Import Library

# %% [markdown]
# # 資料準備

# %%
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation,Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM,GRU
from keras.layers.wrappers import Bidirectional
from keras.utils import np_utils
from datetime import datetime,timedelta
import numpy as np
import json
import requests
import pandas as pd

# import urllib.request
import os
import tarfile
np.random.seed(10)

# %%
from NLP_JiebaSegmentor import JiebaSegmentor

# %%
# os.chdir("../")
# os.getcwd()

# %%
from NLP_JiebaSegmentor import JiebaSegmentor
jieba_dict_path1 = "jieba/dict_taiwan.txt"
jieba_dict_path2 = "jieba/userdict.txt"
jieba_dict_path3 = "jieba/dict.txt.big"
jieba_dict_path4 = "jieba/dict.txt.small"
jieba_dict_path5 = "jieba/dict_system.txt"
jieba_stopwords_path = "jieba/stopwords.txt"

js = JiebaSegmentor(dict_path=jieba_dict_path1,
                    userdict=[jieba_dict_path2,
                              jieba_dict_path3,
                              jieba_dict_path4,
                              jieba_dict_path5],
                    stopwords=True,
                    stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /project/at081-group3/Project_19999/19999_RNN/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.ub496413b6051565ea73611dbd65d9084.cache
# Loading model cost 0.537 seconds.
# Prefix dict has been built succesfully.

# %%
test_cut_raw_0 = js.lcut('北京在哪呢', return_type='pandas')
test_cut_raw_0
# Out:
#   word
# 0   北京

# %%
#先讀取所有文章建立字典，限制字典的數量為nb_words=2000

# %%
df_train = pd.read_csv('data/19999_question_category_a_v13.csv')
df_test = pd.read_csv('data/19999_test_question.csv')
print(f"df_train shape : {df_train.shape}")
print(f"df_test shape : {df_test.shape}")
# Out:
# df_train shape : (12813, 8)
# df_test shape : (27, 4)

# %%
df_train.head()
# Out:
#                                          description category_a category_b  \
# 0               無法會員登入,顯示訊息:無效的帳號或使用者不存在。帳號:96122401       CAMP       CAMP
# 1  因今天有事請假，要補登先前的加班，但開啟camp後，出勤表單顯示的內容看起來像測試的，沒有最...       CAMP       CAMP
# 2                           手機簽核BPM有問題,都顯示亂碼  #18227       CAMP       CAMP
# 3                     無法在手機上面使用CAMP進行表單簽核動作。分機：17132       CAMP       CAMP
# 4                               出差同仁無法登入camp, 委請同事詢問       CAMP       CAMP
#
#   category_c category_d category  \
# 0       CAMP       CAMP     資訊系統
# 1       CAMP       CAMP     資訊系統
# 2       CAMP       CAMP     資訊系統
# 3       CAMP       CAMP     資訊系統
# 4       CAMP       CAMP     資訊系統
#
#                                    description_clean  category_target
# 0                           無法會員登入 顯示訊息 無效的帳號或不存在 帳號                4
# 1  因有事請假 要補登先前的加班 但開啟camp後 出勤表單顯示的內容像測試的 沒有的時間也沒辦...                4
# 2                                     簽核BPM有問題 都顯示亂碼                4
# 3                                無法在上面使用CAMP進行表單簽核動作                4
# 4                                       出差同仁無法登入camp                4

# %%
df_train.shape
# Out:
# (12813, 8)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12813 entries, 0 to 12812
# Data columns (total 8 columns):
# description          12813 non-null object
# category_a           12813 non-null object
# category_b           12813 non-null object
# category_c           12813 non-null object
# category_d           12813 non-null object
# category             12813 non-null object
# description_clean    12813 non-null object
# category_target      12813 non-null int64
# dtypes: int64(1), object(7)
# memory usage: 800.9+ KB

# %%
# df = df.drop( [ 'category_b', 'category_c','category_d' ], axis = 1 )
# df.info()

# %%
# # categories to index mapping
# df['category_a'] = df.category_a.astype('category').cat.codes
# df.head(10)

# %%
# index to categories mapping
mapping = df_train.category.astype('category').cat.categories
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
df_train.groupby(["category"]).size()
# Out:
# category
# Outlook與郵件    3629
# SAP           1443
# 其他            1494
# 網路            4867
# 資訊系統          1380
# dtype: int64

# %%
# df_train.head(10)

# %%
def cut_to_word(s):
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        combie = combie + w
        if i < len(w_list) - 1:
            combie = combie + ','
            
    return combie    

# print (cut_to_word('可以幫我聯絡'.strip()))
df_train['cut_words'] = df_train['description_clean'].apply(lambda s: cut_to_word(s.strip()))
df_test['cut_words'] = df_test['description_clean'].apply(lambda s: cut_to_word(s.strip()))

# print (cut_to_word('可以幫我聯絡'.strip()))
# df_train['cut_words'] = df_train['sentence'].apply(lambda s: cut_to_word(s.strip()))
# df_test['cut_words'] = df_test['sentence'].apply(lambda s: cut_to_word(s.strip()))

# %%
# 資料打散
df_train = df_train.sample(frac=1).reset_index(drop=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)
df_train.head()
# Out:
#                                          description category_a category_b  \
# 0                       核示申請單異常APP0045675  分機: 15777    BPM平台系統    管理類相關服務
# 1                     網路不通  網孔: PN11-C299  TEL:17048         網管         網路
# 2      南棟4樓 NB2 網孔shutdown (D217) ,請協處理 MVPN# 213133         網管         網路
# 3  公司內部的無線STAFF網路無法連線  但是無線網路設定內有STAFF的選項  但是無法手動...         網管         網路
# 4                                      無法連接內網，但可連到外網         網管         網路
#
#   category_c   category_d category  \
# 0      核示申請單       關卡流程詢問     資訊系統
# 1     電腦網路不通  網路不通 (QRDC)       網路
# 2     電腦網路不通  網路不通 (QRDC)       網路
# 3     電腦網路不通       無線網路不通       網路
# 4     電腦網路不通  網路不通 (TH20)       網路
#
#                                    description_clean  category_target  \
# 0                                       核示申請單異常APP75                4
# 1                                網路不通  網孔  PN11 C299                3
# 2                     南棟4樓 NB2 網孔shutdown  D217   請協                3
# 3  公司內部的無線STAFF網路無法連線  無線網路設定內有STAFF的選項  無法手動連線到S...                3
# 4                                      無法連接內網 但可連到外網                3
#
#                                            cut_words
# 0                                     核示申請單,異常,APP75
# 1                                  網路不通,網孔,PN11,C299
# 2                       南棟,樓,NB2,網孔,shutdown,D217,請協
# 3  公司,內部,無線,STAFF,網路無法連線,無線網路,設定,內有,STAFF,選項,無法,手...
# 4                                    無法,連接,內網,可連到,外網

# %%
# 切分資料
X = df_train['cut_words']
y = df_train['category_target']

X_test = df_test['cut_words']
y_test = df_test['category_target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3, random_state = 40)

# %%
# label 做 onehot
y_train_one_hot = np_utils.to_categorical(y_train)
y_val_one_hot = np_utils.to_categorical(y_val)
print (y_train_one_hot[0])
print (y_val_one_hot[0])
# 總共類別數
num_classes = len((y_train_one_hot[0]))
print ('num_classes = {}'.format(num_classes))
# Out:
# [0. 0. 0. 1. 0.]
# [1. 0. 0. 0. 0.]
# num_classes = 5

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 30

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(X_train)
token_intent.fit_on_texts(X_val)

def preprocessing(x, max_len):

    #將文字轉為數字序列
    train_seq_intent = token_intent.texts_to_sequences(x)

    # 截長補短，讓所有數字序列長度一樣
    data = sequence.pad_sequences(train_seq_intent, maxlen=MAX_LEN)
    # print train_data_intent.shape
    return data

x_train = preprocessing(X_train, max_len=MAX_LEN)
x_val = preprocessing(X_val, max_len=MAX_LEN)
x_test = preprocessing(X_test, max_len=MAX_LEN)

# %%
print (x_train.shape)
x_train
# Out:
# (8969, 30)
# array([[   0,    0,    0, ...,    5,  297,  101],
#        [   0,    0,    0, ...,   19,  127,   23],
#        [   0,    0,    0, ...,  137,  692,   38],
#        ...,
#        [   0,    0,    0, ...,  965,   11,   30],
#        [   0,    0,    0, ...,   10,   14, 1076],
#        [   0,    0,    0, ...,  220, 1782, 1605]], dtype=int32)

# %% [markdown]
# # 建立模型

# %%
def build_model(num_classes, vocab_size, sentence_max_len):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=256, 
                        input_length=sentence_max_len))
    model.add(GRU(128))
#     model.add(Bidirectional(LSTM(64)))
#     model.add(Bidirectional(LSTM(128,implementation=2)))
    model.add(Dropout(0.75))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

model = build_model(num_classes, NUM_WORDS, MAX_LEN)
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 30, 256)           1280256
# _________________________________________________________________
# gru_1 (GRU)                  (None, 128)               147840
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 1,428,741
# Trainable params: 1,428,741
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 訓練模型

# %%
model_path = '{}.h5'.format('19999_rnn')

epochs = 50
batch_size = 100
train_ratio = 0.9

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=15, verbose=1)

model_history = model.fit(x=x_train, y=y_train_one_hot,
                            batch_size=batch_size, 
                            epochs=epochs,
                            validation_split= 1 - train_ratio,
                            callbacks = [checkpoint, earlystop])
# Out:
# Train on 8072 samples, validate on 897 samples
# Epoch 1/50
# 8072/8072 [==============================] - 4s 518us/step - loss: 1.0889 - acc: 0.5896 - val_loss: 0.6780 - val_acc: 0.7815
#
# Epoch 00001: val_loss improved from inf to 0.67798, saving model to 19999_rnn.h5
# Epoch 2/50
# 8072/8072 [==============================] - 2s 307us/step - loss: 0.4980 - acc: 0.8331 - val_loss: 0.4553 - val_acc: 0.8528
#
# Epoch 00002: val_loss improved from 0.67798 to 0.45534, saving model to 19999_rnn.h5
# Epoch 3/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.3035 - acc: 0.9065 - val_loss: 0.4268 - val_acc: 0.8606
#
# Epoch 00003: val_loss improved from 0.45534 to 0.42685, saving model to 19999_rnn.h5
# Epoch 4/50
# 8072/8072 [==============================] - 2s 305us/step - loss: 0.2103 - acc: 0.9384 - val_loss: 0.4597 - val_acc: 0.8528
#
# Epoch 00004: val_loss did not improve from 0.42685
# Epoch 5/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.1519 - acc: 0.9543 - val_loss: 0.5066 - val_acc: 0.8562
#
# Epoch 00005: val_loss did not improve from 0.42685
# Epoch 6/50
# 8072/8072 [==============================] - 2s 305us/step - loss: 0.1197 - acc: 0.9654 - val_loss: 0.6207 - val_acc: 0.8540
#
# Epoch 00006: val_loss did not improve from 0.42685
# Epoch 7/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0989 - acc: 0.9718 - val_loss: 0.6217 - val_acc: 0.8506
#
# Epoch 00007: val_loss did not improve from 0.42685
# Epoch 8/50
# 8072/8072 [==============================] - 2s 306us/step - loss: 0.0798 - acc: 0.9762 - val_loss: 0.6592 - val_acc: 0.8473
#
# Epoch 00008: val_loss did not improve from 0.42685
# Epoch 9/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0681 - acc: 0.9796 - val_loss: 0.7631 - val_acc: 0.8562
#
# Epoch 00009: val_loss did not improve from 0.42685
# Epoch 10/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0640 - acc: 0.9796 - val_loss: 0.8102 - val_acc: 0.8395
#
# Epoch 00010: val_loss did not improve from 0.42685
# Epoch 11/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0616 - acc: 0.9830 - val_loss: 0.8299 - val_acc: 0.8484
#
# Epoch 00011: val_loss did not improve from 0.42685
# Epoch 12/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0519 - acc: 0.9850 - val_loss: 0.8208 - val_acc: 0.8517
#
# Epoch 00012: val_loss did not improve from 0.42685
# Epoch 13/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0487 - acc: 0.9849 - val_loss: 0.8611 - val_acc: 0.8317
#
# Epoch 00013: val_loss did not improve from 0.42685
# Epoch 14/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0535 - acc: 0.9849 - val_loss: 0.8818 - val_acc: 0.8462
#
# Epoch 00014: val_loss did not improve from 0.42685
# Epoch 15/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0376 - acc: 0.9886 - val_loss: 0.8871 - val_acc: 0.8528
#
# Epoch 00015: val_loss did not improve from 0.42685
# Epoch 16/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0404 - acc: 0.9870 - val_loss: 0.9709 - val_acc: 0.8406
#
# Epoch 00016: val_loss did not improve from 0.42685
# Epoch 17/50
# 8072/8072 [==============================] - 2s 304us/step - loss: 0.0361 - acc: 0.9889 - val_loss: 0.9136 - val_acc: 0.8450
#
# Epoch 00017: val_loss did not improve from 0.42685
# Epoch 18/50
# 8072/8072 [==============================] - 2s 306us/step - loss: 0.0378 - acc: 0.9907 - val_loss: 0.9958 - val_acc: 0.8484
#
# Epoch 00018: val_loss did not improve from 0.42685
# Epoch 00018: early stopping

# %%
# %pylab inline
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
show_train_history(model_history,'acc','val_acc')

# %%
show_train_history(model_history,'loss','val_loss')

# %%
# model.save(model_path)

# %%
def to_cat_name(x): 
        return mapping[x]
    
def predict(test):
    model = load_model(model_path)
    y_predict_probability = model.predict(test)
    y_predict = model.predict_classes(test)

    return to_cat_name(y_predict), y_predict, y_predict_probability

y_predict_name, y_predict, y_predict_probability = predict(x_val)

# %%
answer_name = to_cat_name(y_val)

# %%
model.predict_classes(x_val)
# Out:
# array([0, 3, 0, ..., 3, 3, 1])

# %%
mapping
# Out:
# Index(['Outlook與郵件', 'SAP', '其他', '網路', '資訊系統'], dtype='object')

# %%
model.predict(x_val)
# Out:
# array([[9.9996114e-01, 7.0552268e-08, 9.6805043e-06, 2.8293913e-05,
#         6.8342194e-07],
#        [5.9983034e-07, 1.4406367e-05, 1.3474277e-05, 9.9996591e-01,
#         5.6592357e-06],
#        [9.9999988e-01, 8.8165368e-09, 6.9802468e-08, 9.1777942e-08,
#         4.6136943e-09],
#        ...,
#        [4.8421868e-04, 4.4395691e-03, 1.5138937e-03, 9.8464358e-01,
#         8.9186551e-03],
#        [4.3924379e-01, 9.6813478e-03, 1.8514439e-03, 4.4796893e-01,
#         1.0125449e-01],
#        [7.8592271e-02, 5.0444669e-01, 3.3772427e-01, 3.0821808e-02,
#         4.8415013e-02]], dtype=float32)

# %%
predict_df = pd.DataFrame({
              '1_sentence':X_val,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_val,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
predict_df
# Out:
#                                               1_sentence  2_y_predict  \
# 818               老闆,寄,信會,收不到,同事,寄,信,收,得到,已,老闆,同事,填寫,無誤,            0
# 1006                                can,t,access,network            3
# 4205   Outlook,信件,寄出,時,Outlook,自動,重啟,無,暫存,草稿,區,已,嚴重,影...            0
# 1195                          參中,專案,無法,閱覽,專案,內容,收到,信件,通知            4
# 12403                                        郵箱,信件,無法收發,            0
# 7599                                       信件,連結,檔案,無法開啟            0
# 7622                  Meeting,Locatio,502,WLAN,無法上網,請協,助            3
# 3723                             無法,順利,簽核,表單,表單,編號,APP96            4
# 6832                                      網孔,pu19b499,不通            3
# 4411    有線,無線網路,不通,早上,變更,密碼,正常,使用,網路,到,剛剛,回到,辦公室,之後,無法使用            3
# 7101                                        兩點,之後,收不到,信件            0
# 12312                                    想將,本機,信件,資料夾,分拆            0
# 6379                                 使用,PLM,系統,無法存取,file            4
# 3382                從早,上班,到,現在,為止,無法使用,Pro,E,Creo2,可用,套數            4
# 3045                                     網路不通,開,MYQUANTA            3
# 12017                   notebook,can,t,access,some,ports            3
# 3068                        Outlook,無法收發,信,186,0234,1511            0
# 1866                                      port,shut,down            3
# 3678                             10.242,185.25,無法連結,請,幫忙            3
# 7201      說,之前,連繫,mail,一個,11,碼,料,號給,希望,正常,方式,產生,到,公用,資料夾            2
# 962                          網常,需要,重新,驗證,網孔,編號,C293,C498            3
# 11814              實驗室,南棟,5F,AG,收不到,staff,無線,是否,安裝,實體,網路            3
# 2230                                  訪客,長期,使用,帳號密碼,無法登入            3
# 12550                           outlook,預約,會議室,Lync,Icon            0
# 6001                                  說,已,提出申請,遲遲,未有,回,應            4
# 8804            執行,qrdcfs01,RMSclient,RMS,FIX,reg,後,無法開啟            0
# 3949                             OUTLOO,無法開啟,影響,週日,出差,行程            0
# 10973  BU9,有線網路,實在,太慢,慢到,連到,雲端,根本無法,執行,作業,網路,太,繁忙,造成,...            3
# 12010                                   有線網路,不通,Port,122            3
# 12755                                        SAP,208,連不上            1
# ...                                                  ...          ...
# 2773                                 outlook,安排,會議,功能,消失            0
# 2380             使用,ctrix,登入,sap,30,31,32,無法登入,以前,登入,sap            1
# 451                       出差,前有,勾,選用,OCS,依然,無法使用,出差,中,34            3
# 6020     客人,寄來,PDF,檔,裏頭,日文,無法顯示,Adobe,Reader,開啟,檔案,出現,亂碼            0
# 6382                                   SAP,218,無法連線,相關同仁            1
# 0                                         核示申請單,異常,APP75            1
# 5151                                BPM,需能,跳出,修改,帳號密碼,視窗            3
# 9996                                    Desktop,加入,廣達,網域            3
# 10983               ZAPR,ME22,兩個,t,code,work,按下去,running            1
# 12223                                   雲端,Outlook,無法,打開            0
# 8474                                       話機,正常,電腦,網路不通            3
# 3148                                     寄信,時,outlook,當掉            0
# 11553                                         有線,無線網路,不通            3
# 8529                        SAP,168,跑,SE16,速度很慢,同事,相關,人員            1
# 3391                                   欲,新增,SAP,帳號,詢問,操作            1
# 6953                                       無法,自行,安裝,win7            2
# 3560                                    SAP,268,無法,LOGIN            1
# 5045                                       Outlook,無法,收信            0
# 7381                                PDM,維護,資料,後,未,同步,SAP            1
# 7761   做,Credit,memo,時,出現,已,做過,訊息,Delivery,號碼,去,顯示,沒開...            1
# 7625     原本,使用,有線,廣達,網域,重新安裝,有線,驅動程式,後,無法,登上,廣達,網域,無線,ok            3
# 3754                   PLM,捷徑,遺失,無法,移除,PLM,人,現在,位於,廠商,無可            2
# 5391                   有線網路,不通,北棟,4F,NB5,port,C156,無線,有通            3
# 12364                                有線網路,中午,過後,不通,北棟,3F            3
# 6887              登入後,視窗,跳出,電腦,日期,網路,日期,時間,一致,導致,無法使用,網路            3
# 1807   outlook,出現,錯誤訊息,認證,已過期,更新,密碼,登入,m,exchange,稍早,...            0
# 6099                加入,project,leader,卻,無法,看到,project,東西            4
# 11597                                    系統,時間,變為,2009,年            4
# 10691                                    簽核,人員,已,離職,需,修改            4
# 2672   That,didn,t,work,We,re,sorry,but,can,t,be,foun...            1
#
#       3_y_predict_name  4_answer 5_answer_name  \
# 818         Outlook與郵件         0    Outlook與郵件
# 1006                網路         3            網路
# 4205        Outlook與郵件         0    Outlook與郵件
# 1195              資訊系統         4          資訊系統
# 12403       Outlook與郵件         0    Outlook與郵件
# 7599        Outlook與郵件         0    Outlook與郵件
# 7622                網路         3            網路
# 3723              資訊系統         4          資訊系統
# 6832                網路         3            網路
# 4411                網路         3            網路
# 7101        Outlook與郵件         0    Outlook與郵件
# 12312       Outlook與郵件         0    Outlook與郵件
# 6379              資訊系統         3            網路
# 3382              資訊系統         4          資訊系統
# 3045                網路         3            網路
# 12017               網路         3            網路
# 3068        Outlook與郵件         0    Outlook與郵件
# 1866                網路         3            網路
# 3678                網路         3            網路
# 7201                其他         1           SAP
# 962                 網路         3            網路
# 11814               網路         3            網路
# 2230                網路         3            網路
# 12550       Outlook與郵件         0    Outlook與郵件
# 6001              資訊系統         1           SAP
# 8804        Outlook與郵件         0    Outlook與郵件
# 3949        Outlook與郵件         0    Outlook與郵件
# 10973               網路         3            網路
# 12010               網路         3            網路
# 12755              SAP         1           SAP
# ...                ...       ...           ...
# 2773        Outlook與郵件         0    Outlook與郵件
# 2380               SAP         1           SAP
# 451                 網路         2            其他
# 6020        Outlook與郵件         2            其他
# 6382               SAP         1           SAP
# 0                  SAP         4          資訊系統
# 5151                網路         2            其他
# 9996                網路         3            網路
# 10983              SAP         1           SAP
# 12223       Outlook與郵件         0    Outlook與郵件
# 8474                網路         3            網路
# 3148        Outlook與郵件         0    Outlook與郵件
# 11553               網路         3            網路
# 8529               SAP         1           SAP
# 3391               SAP         1           SAP
# 6953                其他         2            其他
# 3560               SAP         1           SAP
# 5045        Outlook與郵件         0    Outlook與郵件
# 7381               SAP         1           SAP
# 7761               SAP         1           SAP
# 7625                網路         3            網路
# 3754                其他         2            其他
# 5391                網路         3            網路
# 12364               網路         3            網路
# 6887                網路         3            網路
# 1807        Outlook與郵件         0    Outlook與郵件
# 6099              資訊系統         4          資訊系統
# 11597             資訊系統         2            其他
# 10691             資訊系統         4          資訊系統
# 2672               SAP         3            網路
#
#                                  6_y_predict_probability
# 818    [0.99510807, 6.973259e-05, 0.001822849, 0.0013...
# 1006   [0.00063728454, 0.0055243243, 0.003257072, 0.9...
# 4205   [0.99446976, 0.00019931707, 0.0018677542, 0.00...
# 1195   [0.027889598, 0.002860527, 0.009105943, 4.7164...
# 12403  [0.9993863, 4.1352374e-05, 8.567627e-05, 0.000...
# 7599   [0.96199745, 0.0017258201, 0.015651368, 0.0084...
# 7622   [2.6511429e-05, 0.00010664978, 0.0006003913, 0...
# 3723   [0.0029691798, 0.0032784634, 0.018381068, 0.00...
# 6832   [8.923904e-05, 0.00023563164, 0.00062966323, 0...
# 4411   [6.8033055e-06, 7.693926e-05, 0.0010072653, 0....
# 7101   [0.99659604, 0.00042780422, 0.0006639539, 0.00...
# 12312  [0.99506193, 0.00017459165, 0.0011737989, 0.00...
# 6379   [0.017500805, 0.16322714, 0.30245715, 0.029524...
# 3382   [0.016916078, 0.020015405, 0.23356813, 0.01022...
# 3045   [4.502843e-05, 0.00037659478, 0.0013259018, 0....
# 12017  [0.16594473, 0.07279214, 0.04761725, 0.6884727...
# 3068   [0.9991798, 5.4820484e-05, 0.00026993445, 0.00...
# 1866   [0.001003848, 0.0034551274, 0.0058860444, 0.98...
# 3678   [0.011048629, 0.031535722, 0.06947462, 0.87221...
# 7201   [0.05547586, 0.046446826, 0.45412216, 0.385059...
# 962    [2.6448717e-05, 6.748824e-05, 0.00083628483, 0...
# 11814  [1.2803266e-05, 5.2927608e-05, 0.0038675023, 0...
# 2230   [0.011072748, 0.10227526, 0.08098968, 0.785729...
# 12550  [0.59465533, 0.010577545, 0.17828783, 0.001849...
# 6001   [0.0877065, 0.17316926, 0.2910407, 0.15297464,...
# 8804   [0.9630198, 0.001637737, 0.014646632, 0.008917...
# 3949   [0.59635884, 0.06345442, 0.115196615, 0.102343...
# 10973  [0.00044069017, 0.0008755495, 0.0042641205, 0....
# 12010  [2.3363057e-06, 7.352392e-06, 0.00011617475, 0...
# 12755  [4.564198e-05, 0.9989932, 0.00024428123, 0.000...
# ...                                                  ...
# 2773   [0.9738885, 0.00053133495, 0.014785861, 0.0044...
# 2380   [4.904498e-07, 0.9998758, 2.8208464e-05, 5.902...
# 451    [0.015664171, 0.13949218, 0.31500313, 0.504333...
# 6020   [0.7769433, 0.011678537, 0.13442674, 0.0168187...
# 6382   [2.0966343e-06, 0.99989414, 1.582385e-05, 3.55...
# 0      [0.18095729, 0.29177326, 0.085902385, 0.170493...
# 5151   [0.12154426, 0.037147157, 0.1005495, 0.5852732...
# 9996   [0.055461433, 0.0053047016, 0.12596117, 0.7984...
# 10983  [6.040624e-05, 0.9976903, 0.0006018566, 0.0003...
# 12223  [0.99839884, 9.349225e-05, 0.0004903175, 0.000...
# 8474   [0.00024158008, 0.00026698995, 0.0069256383, 0...
# 3148   [0.9990005, 0.00010640218, 0.0002488527, 2.581...
# 11553  [9.07245e-06, 1.6166836e-05, 6.0937524e-05, 0....
# 8529   [1.7861112e-05, 0.9994541, 8.768487e-05, 1.447...
# 3391   [9.8041986e-05, 0.9963515, 0.00052369083, 6.11...
# 6953   [0.0027621773, 0.012541791, 0.8818697, 0.00599...
# 3560   [3.5530377e-06, 0.9998522, 3.0929634e-05, 1.32...
# 5045   [0.998538, 5.984948e-05, 0.00025188708, 0.0009...
# 7381   [0.0007514197, 0.9816882, 0.005184033, 0.00368...
# 7761   [0.00017789213, 0.96462303, 0.018368782, 0.002...
# 7625   [7.7540235e-06, 2.3367613e-05, 0.00050535524, ...
# 3754   [0.04078672, 0.017572088, 0.73175645, 0.013300...
# 5391   [2.3379823e-06, 5.155768e-06, 8.877756e-05, 0....
# 12364  [6.5692498e-06, 3.1897856e-05, 0.00019453735, ...
# 6887   [0.0011905413, 0.0007826755, 0.019063616, 0.97...
# 1807   [0.99937564, 1.0205e-05, 0.00027248508, 0.0002...
# 6099   [0.08284203, 0.024429064, 0.17869514, 0.025662...
# 11597  [0.04232971, 0.34506467, 0.099401124, 0.055583...
# 10691  [0.017614497, 0.0179393, 0.024201002, 0.003502...
# 2672   [0.036914576, 0.71087766, 0.08180281, 0.043848...
#
# [3844 rows x 6 columns]

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.858480749219563 !!!!!!!!

# %%
predict_df[predict_df['3_y_predict_name'] != predict_df['4_answer']]
# Out:
#                                               1_sentence  2_y_predict  \
# 818               老闆,寄,信會,收不到,同事,寄,信,收,得到,已,老闆,同事,填寫,無誤,            0
# 1006                                can,t,access,network            3
# 4205   Outlook,信件,寄出,時,Outlook,自動,重啟,無,暫存,草稿,區,已,嚴重,影...            0
# 1195                          參中,專案,無法,閱覽,專案,內容,收到,信件,通知            4
# 12403                                        郵箱,信件,無法收發,            0
# 7599                                       信件,連結,檔案,無法開啟            0
# 7622                  Meeting,Locatio,502,WLAN,無法上網,請協,助            3
# 3723                             無法,順利,簽核,表單,表單,編號,APP96            4
# 6832                                      網孔,pu19b499,不通            3
# 4411    有線,無線網路,不通,早上,變更,密碼,正常,使用,網路,到,剛剛,回到,辦公室,之後,無法使用            3
# 7101                                        兩點,之後,收不到,信件            0
# 12312                                    想將,本機,信件,資料夾,分拆            0
# 6379                                 使用,PLM,系統,無法存取,file            4
# 3382                從早,上班,到,現在,為止,無法使用,Pro,E,Creo2,可用,套數            4
# 3045                                     網路不通,開,MYQUANTA            3
# 12017                   notebook,can,t,access,some,ports            3
# 3068                        Outlook,無法收發,信,186,0234,1511            0
# 1866                                      port,shut,down            3
# 3678                             10.242,185.25,無法連結,請,幫忙            3
# 7201      說,之前,連繫,mail,一個,11,碼,料,號給,希望,正常,方式,產生,到,公用,資料夾            2
# 962                          網常,需要,重新,驗證,網孔,編號,C293,C498            3
# 11814              實驗室,南棟,5F,AG,收不到,staff,無線,是否,安裝,實體,網路            3
# 2230                                  訪客,長期,使用,帳號密碼,無法登入            3
# 12550                           outlook,預約,會議室,Lync,Icon            0
# 6001                                  說,已,提出申請,遲遲,未有,回,應            4
# 8804            執行,qrdcfs01,RMSclient,RMS,FIX,reg,後,無法開啟            0
# 3949                             OUTLOO,無法開啟,影響,週日,出差,行程            0
# 10973  BU9,有線網路,實在,太慢,慢到,連到,雲端,根本無法,執行,作業,網路,太,繁忙,造成,...            3
# 12010                                   有線網路,不通,Port,122            3
# 12755                                        SAP,208,連不上            1
# ...                                                  ...          ...
# 2773                                 outlook,安排,會議,功能,消失            0
# 2380             使用,ctrix,登入,sap,30,31,32,無法登入,以前,登入,sap            1
# 451                       出差,前有,勾,選用,OCS,依然,無法使用,出差,中,34            3
# 6020     客人,寄來,PDF,檔,裏頭,日文,無法顯示,Adobe,Reader,開啟,檔案,出現,亂碼            0
# 6382                                   SAP,218,無法連線,相關同仁            1
# 0                                         核示申請單,異常,APP75            1
# 5151                                BPM,需能,跳出,修改,帳號密碼,視窗            3
# 9996                                    Desktop,加入,廣達,網域            3
# 10983               ZAPR,ME22,兩個,t,code,work,按下去,running            1
# 12223                                   雲端,Outlook,無法,打開            0
# 8474                                       話機,正常,電腦,網路不通            3
# 3148                                     寄信,時,outlook,當掉            0
# 11553                                         有線,無線網路,不通            3
# 8529                        SAP,168,跑,SE16,速度很慢,同事,相關,人員            1
# 3391                                   欲,新增,SAP,帳號,詢問,操作            1
# 6953                                       無法,自行,安裝,win7            2
# 3560                                    SAP,268,無法,LOGIN            1
# 5045                                       Outlook,無法,收信            0
# 7381                                PDM,維護,資料,後,未,同步,SAP            1
# 7761   做,Credit,memo,時,出現,已,做過,訊息,Delivery,號碼,去,顯示,沒開...            1
# 7625     原本,使用,有線,廣達,網域,重新安裝,有線,驅動程式,後,無法,登上,廣達,網域,無線,ok            3
# 3754                   PLM,捷徑,遺失,無法,移除,PLM,人,現在,位於,廠商,無可            2
# 5391                   有線網路,不通,北棟,4F,NB5,port,C156,無線,有通            3
# 12364                                有線網路,中午,過後,不通,北棟,3F            3
# 6887              登入後,視窗,跳出,電腦,日期,網路,日期,時間,一致,導致,無法使用,網路            3
# 1807   outlook,出現,錯誤訊息,認證,已過期,更新,密碼,登入,m,exchange,稍早,...            0
# 6099                加入,project,leader,卻,無法,看到,project,東西            4
# 11597                                    系統,時間,變為,2009,年            4
# 10691                                    簽核,人員,已,離職,需,修改            4
# 2672   That,didn,t,work,We,re,sorry,but,can,t,be,foun...            1
#
#       3_y_predict_name  4_answer 5_answer_name  \
# 818         Outlook與郵件         0    Outlook與郵件
# 1006                網路         3            網路
# 4205        Outlook與郵件         0    Outlook與郵件
# 1195              資訊系統         4          資訊系統
# 12403       Outlook與郵件         0    Outlook與郵件
# 7599        Outlook與郵件         0    Outlook與郵件
# 7622                網路         3            網路
# 3723              資訊系統         4          資訊系統
# 6832                網路         3            網路
# 4411                網路         3            網路
# 7101        Outlook與郵件         0    Outlook與郵件
# 12312       Outlook與郵件         0    Outlook與郵件
# 6379              資訊系統         3            網路
# 3382              資訊系統         4          資訊系統
# 3045                網路         3            網路
# 12017               網路         3            網路
# 3068        Outlook與郵件         0    Outlook與郵件
# 1866                網路         3            網路
# 3678                網路         3            網路
# 7201                其他         1           SAP
# 962                 網路         3            網路
# 11814               網路         3            網路
# 2230                網路         3            網路
# 12550       Outlook與郵件         0    Outlook與郵件
# 6001              資訊系統         1           SAP
# 8804        Outlook與郵件         0    Outlook與郵件
# 3949        Outlook與郵件         0    Outlook與郵件
# 10973               網路         3            網路
# 12010               網路         3            網路
# 12755              SAP         1           SAP
# ...                ...       ...           ...
# 2773        Outlook與郵件         0    Outlook與郵件
# 2380               SAP         1           SAP
# 451                 網路         2            其他
# 6020        Outlook與郵件         2            其他
# 6382               SAP         1           SAP
# 0                  SAP         4          資訊系統
# 5151                網路         2            其他
# 9996                網路         3            網路
# 10983              SAP         1           SAP
# 12223       Outlook與郵件         0    Outlook與郵件
# 8474                網路         3            網路
# 3148        Outlook與郵件         0    Outlook與郵件
# 11553               網路         3            網路
# 8529               SAP         1           SAP
# 3391               SAP         1           SAP
# 6953                其他         2            其他
# 3560               SAP         1           SAP
# 5045        Outlook與郵件         0    Outlook與郵件
# 7381               SAP         1           SAP
# 7761               SAP         1           SAP
# 7625                網路         3            網路
# 3754                其他         2            其他
# 5391                網路         3            網路
# 12364               網路         3            網路
# 6887                網路         3            網路
# 1807        Outlook與郵件         0    Outlook與郵件
# 6099              資訊系統         4          資訊系統
# 11597             資訊系統         2            其他
# 10691             資訊系統         4          資訊系統
# 2672               SAP         3            網路
#
#                                  6_y_predict_probability
# 818    [0.99510807, 6.973259e-05, 0.001822849, 0.0013...
# 1006   [0.00063728454, 0.0055243243, 0.003257072, 0.9...
# 4205   [0.99446976, 0.00019931707, 0.0018677542, 0.00...
# 1195   [0.027889598, 0.002860527, 0.009105943, 4.7164...
# 12403  [0.9993863, 4.1352374e-05, 8.567627e-05, 0.000...
# 7599   [0.96199745, 0.0017258201, 0.015651368, 0.0084...
# 7622   [2.6511429e-05, 0.00010664978, 0.0006003913, 0...
# 3723   [0.0029691798, 0.0032784634, 0.018381068, 0.00...
# 6832   [8.923904e-05, 0.00023563164, 0.00062966323, 0...
# 4411   [6.8033055e-06, 7.693926e-05, 0.0010072653, 0....
# 7101   [0.99659604, 0.00042780422, 0.0006639539, 0.00...
# 12312  [0.99506193, 0.00017459165, 0.0011737989, 0.00...
# 6379   [0.017500805, 0.16322714, 0.30245715, 0.029524...
# 3382   [0.016916078, 0.020015405, 0.23356813, 0.01022...
# 3045   [4.502843e-05, 0.00037659478, 0.0013259018, 0....
# 12017  [0.16594473, 0.07279214, 0.04761725, 0.6884727...
# 3068   [0.9991798, 5.4820484e-05, 0.00026993445, 0.00...
# 1866   [0.001003848, 0.0034551274, 0.0058860444, 0.98...
# 3678   [0.011048629, 0.031535722, 0.06947462, 0.87221...
# 7201   [0.05547586, 0.046446826, 0.45412216, 0.385059...
# 962    [2.6448717e-05, 6.748824e-05, 0.00083628483, 0...
# 11814  [1.2803266e-05, 5.2927608e-05, 0.0038675023, 0...
# 2230   [0.011072748, 0.10227526, 0.08098968, 0.785729...
# 12550  [0.59465533, 0.010577545, 0.17828783, 0.001849...
# 6001   [0.0877065, 0.17316926, 0.2910407, 0.15297464,...
# 8804   [0.9630198, 0.001637737, 0.014646632, 0.008917...
# 3949   [0.59635884, 0.06345442, 0.115196615, 0.102343...
# 10973  [0.00044069017, 0.0008755495, 0.0042641205, 0....
# 12010  [2.3363057e-06, 7.352392e-06, 0.00011617475, 0...
# 12755  [4.564198e-05, 0.9989932, 0.00024428123, 0.000...
# ...                                                  ...
# 2773   [0.9738885, 0.00053133495, 0.014785861, 0.0044...
# 2380   [4.904498e-07, 0.9998758, 2.8208464e-05, 5.902...
# 451    [0.015664171, 0.13949218, 0.31500313, 0.504333...
# 6020   [0.7769433, 0.011678537, 0.13442674, 0.0168187...
# 6382   [2.0966343e-06, 0.99989414, 1.582385e-05, 3.55...
# 0      [0.18095729, 0.29177326, 0.085902385, 0.170493...
# 5151   [0.12154426, 0.037147157, 0.1005495, 0.5852732...
# 9996   [0.055461433, 0.0053047016, 0.12596117, 0.7984...
# 10983  [6.040624e-05, 0.9976903, 0.0006018566, 0.0003...
# 12223  [0.99839884, 9.349225e-05, 0.0004903175, 0.000...
# 8474   [0.00024158008, 0.00026698995, 0.0069256383, 0...
# 3148   [0.9990005, 0.00010640218, 0.0002488527, 2.581...
# 11553  [9.07245e-06, 1.6166836e-05, 6.0937524e-05, 0....
# 8529   [1.7861112e-05, 0.9994541, 8.768487e-05, 1.447...
# 3391   [9.8041986e-05, 0.9963515, 0.00052369083, 6.11...
# 6953   [0.0027621773, 0.012541791, 0.8818697, 0.00599...
# 3560   [3.5530377e-06, 0.9998522, 3.0929634e-05, 1.32...
# 5045   [0.998538, 5.984948e-05, 0.00025188708, 0.0009...
# 7381   [0.0007514197, 0.9816882, 0.005184033, 0.00368...
# 7761   [0.00017789213, 0.96462303, 0.018368782, 0.002...
# 7625   [7.7540235e-06, 2.3367613e-05, 0.00050535524, ...
# 3754   [0.04078672, 0.017572088, 0.73175645, 0.013300...
# 5391   [2.3379823e-06, 5.155768e-06, 8.877756e-05, 0....
# 12364  [6.5692498e-06, 3.1897856e-05, 0.00019453735, ...
# 6887   [0.0011905413, 0.0007826755, 0.019063616, 0.97...
# 1807   [0.99937564, 1.0205e-05, 0.00027248508, 0.0002...
# 6099   [0.08284203, 0.024429064, 0.17869514, 0.025662...
# 11597  [0.04232971, 0.34506467, 0.099401124, 0.055583...
# 10691  [0.017614497, 0.0179393, 0.024201002, 0.003502...
# 2672   [0.036914576, 0.71087766, 0.08180281, 0.043848...
#
# [3844 rows x 6 columns]

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'])
# Out:
# answer      Outlook與郵件  SAP   其他    網路  資訊系統
# predict
# Outlook與郵件        1011    2   39    20    20
# SAP                  3  377   13     9    12
# 其他                  24   12  249    44    32
# 網路                  34   14  122  1353    30
# 資訊系統                28   25   35    26   310

# %%
"""
自訂測試句子
"""

y_predict_name, y_predict, y_predict_probability = predict(x_test)
answer_name = to_cat_name(y_test)
predict_df = pd.DataFrame({
              '1_sentence':X_test,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_test,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.7777777777777778 !!!!!!!!

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'])
# Out:
# answer      Outlook與郵件  SAP  其他  網路  資訊系統
# predict
# Outlook與郵件           3    0   0   0     0
# SAP                  0    4   2   0     2
# 其他                   0    0   3   0     0
# 網路                   0    0   2   1     0
# 資訊系統                 0    0   0   0    10

# %%
"""
預測錯誤的資料觀察
"""
predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
# Out:
#          1_sentence  2_y_predict 3_y_predict_name  4_answer 5_answer_name  \
# 1   HP2014,列印,出現,亂碼            1              SAP         2            其他
# 7       BMS,系統,無法登入            1              SAP         4          資訊系統
# 11             電腦中毒            3               網路         2            其他
# 14       電腦,變,很慢,中毒            3               網路         2            其他
# 15      異常,SO,簽核,問題            1              SAP         4          資訊系統
# 25        非法,軟體安裝問題            1              SAP         2            其他
#
#                               6_y_predict_probability
# 1   [0.00815223, 0.74206096, 0.090155736, 0.008900...
# 7   [0.013914566, 0.42526808, 0.13378046, 0.166446...
# 11  [0.15921552, 0.12935695, 0.081287175, 0.578685...
# 14  [0.0078092036, 0.031065281, 0.31074408, 0.6218...
# 15  [0.0067764153, 0.6616323, 0.018461451, 0.00345...
# 25  [0.14508468, 0.2781837, 0.2199112, 0.22057861,...
