# %% [markdown]
# # the application of word2vec

# %%
from gensim.models import word2vec
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import os

## turn back to main directory
os.chdir("../")
os.getcwd()
# Out:
# '/home/jovyan/Davis_Practice/NLP'

# %%
## load word2vec model (由 part1 03_word2vec_build.ipynb 產生)
model = word2vec.Word2Vec.load('part2/word2vec_model/1999_CBOW')

# %% [markdown]
# ## similarity

# %%
## get most similarity with given words
model.wv.most_similar('系統')
# Out:
# [('項目', 0.8080171346664429),
#  ('點選', 0.7968190908432007),
#  ('首頁', 0.7850562334060669),
#  ('畫面', 0.7785091400146484),
#  ('連結', 0.7778873443603516),
#  ('介面', 0.7551491260528564),
#  ('按鈕', 0.7540853023529053),
#  ('停留', 0.7499284744262695),
#  ('頁面', 0.7397742867469788),
#  ('卻', 0.7371840476989746)]

# %%
## get most similarity with given words's relationship
model.wv.most_similar(positive=['MRO'], negative=['系統'])
# Out:
# [('ITEM', 0.5975996255874634),
#  ('P', 0.5881931185722351),
#  ('cancel', 0.5705850124359131),
#  ('GR', 0.54735267162323),
#  ('PO', 0.5463650226593018),
#  ('N', 0.5440875291824341),
#  ('金額', 0.515935480594635),
#  ('数量', 0.5047597885131836),
#  ('提供', 0.5003150105476379),
#  ('以下', 0.49566370248794556)]

# %%
model.wv.doesnt_match("SAP無法用")
# Out:
# '無'

# %% [markdown]
# ## clustering

# %%
## create a dictionary: words as key ; count as values
words = {word: vocab.count for word, vocab in model.wv.vocab.items()}

# %%
## sort and select the top 10000 count of words
words = sorted(words.items(), key=lambda x: x[1], reverse=True)
words = words[:10000]
words = np.array(words)[:, 0]
words
# Out:
# array(['無法', 'SAP', '登入', ..., '將其', '本機', 'Critix'], dtype='<U14')

# %%
## extract the word vectors 
vecs = model.wv[words]

# %%
## run clustering algorithm
kmeans = KMeans(n_clusters=50)
cluster = kmeans.fit_predict(vecs)

# %%
## print the result
df = pd.DataFrame([words.tolist(), cluster.tolist()], index=['words', 'no. cluster']).T
df.head(n=5)
# Out:
#   words no. cluster
# 0    無法          37
# 1   SAP          37
# 2    登入           6
# 3    協助          36
# 4     請          28

# %%
## print every cluster of words
data = pd.concat([d['words'].reset_index(drop=True).rename(columns={0: k}) for k, d in df.groupby('no. cluster')], axis=1)
data
# Out:
#       0            1         2        3            4    5     6        7   \
# 0     檔案           No         中       in          key   煩請    登入       EC
# 1     上傳         CS12        內部      not         down   人員    進入     Dear
# 2    NaN            F        應用    issue        excel   同仁    密碼   Sharry
# 3    NaN            行  myquanta       is            抓  NaN    連線  Shirley
# 4    NaN           Hi      icon   system       Client  NaN    電腦      NaN
# 5    NaN            S    Quanta   create          bom  NaN    安裝      NaN
# 6    NaN         CS20  Myquanta     fail         item  NaN    輸入      NaN
# 7    NaN         Item        首頁     file            檔  NaN  CAMP      NaN
# 8    NaN         CS50        在家       of         QH10  NaN    工號      NaN
# 9    NaN         CS40      Icon       on           裡面  NaN    公司      NaN
# 10   NaN           改为       EIP      log         call  NaN  帳號密碼      NaN
# 11   NaN          Qty        My       by      Invoice  NaN    遠端      NaN
# 12   NaN        PRICE       NaN      has           IP  NaN     登      NaN
# 13   NaN        Total       NaN       be      project  NaN    開機      NaN
# 14   NaN         LQFP       NaN      use     Download  NaN    入時      NaN
# 15   NaN          RPE       NaN     this          PLM  NaN   NaN      NaN
# 16   NaN            {       NaN      but         Data  NaN   NaN      NaN
# 17   NaN        MATNR       NaN   upload        Group  NaN   NaN      NaN
# 18   NaN        RMANO       NaN   cannot           裡的  NaN   NaN      NaN
# 19   NaN         Mult       NaN      Can            成  NaN   NaN      NaN
# 20   NaN        LGORT       NaN      The         COST  NaN   NaN      NaN
# 21   NaN        INSMK       NaN  message           勾選  NaN   NaN      NaN
# 22   NaN        EBELN       NaN     find          Sap  NaN   NaN      NaN
# 23   NaN        EBELP       NaN      NaN          QCA  NaN   NaN      NaN
# 24   NaN         ZRPO       NaN      NaN       Report  NaN   NaN      NaN
# 25   NaN     ZRPOITEM       NaN      NaN      Account  NaN   NaN      NaN
# 26   NaN       Serial       NaN      NaN          QCH  NaN   NaN      NaN
# 27   NaN  LALS075A001       NaN      NaN     function  NaN   NaN      NaN
# 28   NaN         TW30       NaN      NaN       credit  NaN   NaN      NaN
# 29   NaN          RSC       NaN      NaN           進度  NaN   NaN      NaN
# ..   ...          ...       ...      ...          ...  ...   ...      ...
# 140  NaN          NaN       NaN      NaN           多筆  NaN   NaN      NaN
# 141  NaN          NaN       NaN      NaN           替代  NaN   NaN      NaN
# 142  NaN          NaN       NaN      NaN      created  NaN   NaN      NaN
# 143  NaN          NaN       NaN      NaN         ZW19  NaN   NaN      NaN
# 144  NaN          NaN       NaN      NaN    Warehouse  NaN   NaN      NaN
# 145  NaN          NaN       NaN      NaN  transaction  NaN   NaN      NaN
# 146  NaN          NaN       NaN      NaN         DOWN  NaN   NaN      NaN
# 147  NaN          NaN       NaN      NaN         ZM02  NaN   NaN      NaN
# 148  NaN          NaN       NaN      NaN           SD  NaN   NaN      NaN
# 149  NaN          NaN       NaN      NaN           QT  NaN   NaN      NaN
# 150  NaN          NaN       NaN      NaN          NEW  NaN   NaN      NaN
# 151  NaN          NaN       NaN      NaN       record  NaN   NaN      NaN
# 152  NaN          NaN       NaN      NaN           想問  NaN   NaN      NaN
# 153  NaN          NaN       NaN      NaN         ZMAN  NaN   NaN      NaN
# 154  NaN          NaN       NaN      NaN         ZPA2  NaN   NaN      NaN
# 155  NaN          NaN       NaN      NaN        sap33  NaN   NaN      NaN
# 156  NaN          NaN       NaN      NaN           廠區  NaN   NaN      NaN
# 157  NaN          NaN       NaN      NaN           价格  NaN   NaN      NaN
# 158  NaN          NaN       NaN      NaN           轉檔  NaN   NaN      NaN
# 159  NaN          NaN       NaN      NaN           事宜  NaN   NaN      NaN
# 160  NaN          NaN       NaN      NaN           要開  NaN   NaN      NaN
# 161  NaN          NaN       NaN      NaN           主檔  NaN   NaN      NaN
# 162  NaN          NaN       NaN      NaN           預算  NaN   NaN      NaN
# 163  NaN          NaN       NaN      NaN         save  NaN   NaN      NaN
# 164  NaN          NaN       NaN      NaN         ZMQW  NaN   NaN      NaN
# 165  NaN          NaN       NaN      NaN          NaN  NaN   NaN      NaN
# 166  NaN          NaN       NaN      NaN          NaN  NaN   NaN      NaN
# 167  NaN          NaN       NaN      NaN          NaN  NaN   NaN      NaN
# 168  NaN          NaN       NaN      NaN          NaN  NaN   NaN      NaN
# 169  NaN          NaN       NaN      NaN          NaN  NaN   NaN      NaN
#
#       8        9  ...     40   41   42      43       44          45   46  \
# 0     申請  license ...      未    T  BOM      新增        新           做  can
# 1     請問   Citrix ...      找  NaN    說      更新       重新          執行  NaN
# 2     部門       提示 ...     看到  NaN   已經      文件       今天           跑  NaN
# 3     目前    Logon ...     採購  NaN  看不到      相同        需          SO  NaN
# 4     現在       不見 ...     自動  NaN  PDM      客人        完           開  NaN
# 5      人      KEY ...     廠商  NaN   轉到      加入       成功          動作  NaN
# 6     同事   System ...     發現  NaN   同步      原本       工作          價格  NaN
# 7     大陸        入 ...     抽單  NaN  NaN      以前       軟體    delivery  NaN
# 8     手機      登入後 ...     產生  NaN  NaN       好       直接     invoice  NaN
# 9    NaN       亂碼 ...     內容  NaN  NaN      確定     mail        cost  NaN
# 10   NaN       突然 ...     放行  NaN  NaN      不行       NB         run  NaN
# 11   NaN       網域 ...     狀況  NaN  NaN      可否       儲存    Delivery  NaN
# 12   NaN       介面 ...     專案  NaN  NaN      您好       日期      center  NaN
# 13   NaN       格式 ...      號  NaN  NaN      只能       選項          報表  NaN
# 14   NaN        退 ...     提供  NaN  NaN    ProE        回          一筆  NaN
# 15   NaN       開單 ...     請假  NaN  NaN      變更       重灌           掉  NaN
# 16   NaN  Meeting ...     取消  NaN  NaN      小時       選擇          出貨  NaN
# 17   NaN       填單 ...     代碼  NaN  NaN      成本       外帶          數量  NaN
# 18   NaN       無效 ...     欄位  NaN  NaN       C       所有          訂單  NaN
# 19   NaN     重新安裝 ...     時間  NaN  NaN      你好        機       sales  NaN
# 20   NaN       消失 ...     送出  NaN  NaN      檢查       導致          情形  NaN
# 21   NaN       存檔 ...     告知  NaN  NaN      尚未        卡          兩個  NaN
# 22   NaN       變成 ...   MRO2  NaN  NaN      新人       當機        ZV14  NaN
# 23   NaN    Login ...     情況  NaN  NaN     com       應該  background  NaN
# 24   NaN   Server ...     報廢  NaN  NaN       印  Outlook     Charles  NaN
# 25   NaN       SI ...      先  NaN  NaN      位置       名稱       Sworm  NaN
# 26   NaN     CSAP ...     離職  NaN  NaN       錯       早上        ZN26  NaN
# 27   NaN       空白 ...     費用  NaN  NaN      找到       上面        memo  NaN
# 28   NaN   quanta ...      廠  NaN  NaN      中文       員工          不出  NaN
# 29   NaN       資源 ...     訪客  NaN  NaN       Ｐ       過期           假  NaN
# ..   ...      ... ...    ...  ...  ...     ...      ...         ...  ...
# 140  NaN        達 ...    NaN  NaN  NaN      但用      NaN         NaN  NaN
# 141  NaN       按送 ...    NaN  NaN  NaN       寫      NaN         NaN  NaN
# 142  NaN       字數 ...    NaN  NaN  NaN      擴充      NaN         NaN  NaN
# 143  NaN   GWF016 ...    NaN  NaN  NaN      參考      NaN         NaN  NaN
# 144  NaN     rd10 ...    NaN  NaN  NaN      編輯      NaN         NaN  NaN
# 145  NaN       全部 ...    NaN  NaN  NaN   SALES      NaN         NaN  NaN
# 146  NaN       同樣 ...    NaN  NaN  NaN      歸檔      NaN         NaN  NaN
# 147  NaN    keyin ...    NaN  NaN  NaN      建議      NaN         NaN  NaN
# 148  NaN      NOT ...    NaN  NaN  NaN     新料號      NaN         NaN  NaN
# 149  NaN        全 ...    NaN  NaN  NaN      審核      NaN         NaN  NaN
# 150  NaN       螢幕 ...    NaN  NaN  NaN      尋找      NaN         NaN  NaN
# 151  NaN       變數 ...    NaN  NaN  NaN      組織      NaN         NaN  NaN
# 152  NaN       信任 ...    NaN  NaN  NaN      變動      NaN         NaN  NaN
# 153  NaN     開發人員 ...    NaN  NaN  NaN     申請人      NaN         NaN  NaN
