# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from glob import glob
import matplotlib.pyplot as plt

import numpy as np

# %%
data_dir_path = './'


target_label_file_name = 'mapping.txt'
target_label_file_path = '/'.join((data_dir_path, target_label_file_name))
train_dir = '/'.join((data_dir_path, 'train'))

# %%
with open(target_label_file_path) as f:
        all_lines = [line.split(', ') for line in f.read().splitlines()]

target_labels = dict()
for line in all_lines:
    target_class, target_label = line
    target_labels[target_class] = target_label

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest')
""" Create training data list """
# Out:
# ' Create training data list '

# %%
train_list = []
img_paths = []
img_labels = []
for key in target_labels.keys():
    for img_path in glob('{}/{}/*.png'.format(train_dir, key)):
        #print(img_path)
        train_list.append([img_path, target_labels[key]])
        img_paths.append(img_path)
        img_labels.append(target_labels[key])
        img = load_img('./train/akane/004.png')  # this is a PIL image
        x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
        x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

        
        # the .flow() command below generates batches of randomly transformed images
        # and saves the results to the `preview/` directory
        i = 1
        for batch_gen in datagen.flow(x, batch_size=1,
                          save_to_dir=train_dir+'/'+key, save_prefix='ad', save_format='png'):
            i += 1
            if i > 2:
                break  # otherwise the generator would loop indefinitely
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %%
# Out:
# []
