# %%
from __future__ import print_function
 
from keras.preprocessing import sequence
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout, Activation,Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D,GRU,Conv1D, MaxPooling1D,SpatialDropout1D
from keras.layers.recurrent import LSTM,GRU
from keras.layers.wrappers import Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.layers import CuDNNGRU
from keras.layers.merge import concatenate, add

from keras.layers import Input,Reshape,Conv2D,MaxPool2D, concatenate
from keras.models import model_from_json
import numpy as np
import json
import requests
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df_all = pd.read_csv('data/19999_question_category_b_is_v4.csv')
print(f"df_all shape : {df_all.shape}")
# Out:
# df_all shape : (1336, 8)

# %%
mapping = df_all.category.astype('category').cat.categories
mapping
# Out:
# Index(['BPM平台系統', 'R&D資訊系統', '內部資訊系統'], dtype='object')

# %%
from NLP_JiebaSegmentor import JiebaSegmentor
jieba_dict_path1 = "jieba/dict_taiwan.txt"
jieba_dict_path2 = "jieba/userdict.txt"
jieba_dict_path3 = "jieba/dict.txt.big"
jieba_dict_path4 = "jieba/dict.txt.small"
jieba_dict_path5 = "jieba/dict_system.txt"
jieba_stopwords_path = "jieba/stopwords.txt"

js = JiebaSegmentor(dict_path=jieba_dict_path1,
                    userdict=[jieba_dict_path2,
                              jieba_dict_path3,
                              jieba_dict_path4#,
                              #jieba_dict_path5
                             ],
                              
                    stopwords=True,
                    stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /project/at081-group3/SourceCode/19999_2RNN/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u8f81e49202a03fd1fa71a951575a5172.cache
# Loading model cost 0.565 seconds.
# Prefix dict has been built succesfully.

# %%
test_cut_raw_0 = js.lcut('FTP無法安裝', return_type='pandas')
test_cut_raw_0
# Out:
#   word
# 0  FTP
# 1   安裝

# %%
# x_train=np.loadtxt("x_train.txt",dtype=int)
# y_train=np.loadtxt("y_train.txt",dtype=int)
 
# indices = np.arange(x_train.shape[0])
# np.random.shuffle(indices)
# x_train = x_train[indices]
# y_train = y_train[indices]
 
# print('Loading data...')
# #x_train=np.loadtxt("x_train.txt",dtype=int)
# #y_train=np.loadtxt("y_train.txt",dtype=int)
# x_test=x_train[20000:]
# y_test=y_train[20000:]
# x_train=x_train[:20000]
# y_train=y_train[:20000]
# #x_test=x_train
# #y_test=y_train
# print(len(x_train), 'train sequences')
# print(len(x_test), 'test sequences')
# print(x_train[:1])
# print('Pad sequences (samples x time)')

# %%
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0  下面issue 無法open…完成後會跳到另外一個issue   但原本issue 未Ope...    R&D資訊系統     測試相關服務
# 1  1. Issue Status秀出來的文字裡面,出現斷行符號,但實際上看不到斷行效果  2....    R&D資訊系統     測試相關服務
# 2  QCMC那邊的測試人員反應無法使用QITS系統,原本NB7的使用權限被刪除,如附件一  另外...    R&D資訊系統     測試相關服務
# 3                   Chris Wu (吳振瑋)  新增 BU3 bios   人員    R&D資訊系統     測試相關服務
# 4  Please help create new platform-Chipset “AMD R...    R&D資訊系統     測試相關服務
#
#        category_c category_d category  \
# 0  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 1  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 2  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 3  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
# 4  【QITS】研發議題追蹤系統     相關操作詢問  R&D資訊系統
#
#                                    description_clean  category_target
# 0  下麵 無法open…完成後會跳到一個   但原本 未open完成      再幫忙看一下  ...                1
# 1  1.  status秀出來的文字裡面出現斷行符號但實際上看不到斷行效果  2.  assig...                1
# 2  的測試人員反應qits系統原本nb7的使用權限被刪除如附件一  原本已被刪除的權限現在又跑出...                1
# 3                                   新增 bu3 bios   人員                1
# 4  please help create new platformcpset “amd rich...                1

# %%
# w_pandas = js.lcut('無法會員登入 顯示訊息 無效的帳號或不存在 帳號'.strip(), return_type='pandas')
# w_list = list(w_pandas['word'])
# w_list

df_all.groupby(["category"]).size()
# Out:
# category
# BPM平台系統    644
# R&D資訊系統    353
# 內部資訊系統     339
# dtype: int64

# %%
def cut_to_word2(s):
    blCondition=False
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    combieNO=''
    beforeWord=''
    blAdd=True
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        conditionWord = str(combieNO) + str(w) 
        if combieNO != '' and len(w)>1 :# and len(conditionWord) == 4:
            combie = combie + w +','
            combie = combie+combieNO+w
            #print(combieNO+w)
        else:        
            if w in ['修改'] and beforeWord!='' and blCondition and len(w)>1:#,'訊息','顯示',
                combie = combie +w+','
                combie = combie+beforeWord+w
            else:
                if w not in ['無法'] and len(w)>1:
                    combie = combie + w
                else:
                    blAdd=False
                 
        if i < len(w_list) - 1 and combie !='' and blAdd:
            combie = combie + ','
            
        blAdd=True
            
        if w in ['無法','不能','加班','請假','預約'] and blCondition:#'編輯','刪除','新增','作業','更換','輸入','忘記','下載','上傳',,'安裝'#,'系統','開啟','申請','顯示','出現'
            combieNO = w
        else:
            combieNO = ''
        beforeWord=w
    return combie

# %%
def cut_to_word(s):
    blCondition=True
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    combieNO=''
    beforeWord=''
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
             
        #if w in ['修改','顯示','作業','申請單'] and beforeWord!='' and blCondition and len(w)>1:#,'訊息','預約','問題'
        combie = combie + w
        combie = combie+','+beforeWord+w
        #else:
        #    if len(w)>1:
        #        combie = combie + w
                 
        if i < len(w_list) - 1 and combie !='':
            combie = combie + ','
            
        
        beforeWord=w
    return combie    

def cut_to_word3(s):
    w_pandas = js.lcut(s, return_type='pandas')
    w_list = list(w_pandas['word'])
    combie = ''
    for i,w in enumerate(w_list):
        if w is ' ':
            continue
        
        #if len(w)>1:
        combie = combie + w
                 
        if i < len(w_list) - 1:# and len(w)>1:#
            combie = combie + ','
            
    return combie  


# print (cut_to_word('可以幫我聯絡'.strip()))
df_all['cut_words'] = df_all['description_clean'].apply(lambda s: cut_to_word3(s.strip()))

# %%
# 資料打散
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_all.head()
# Out:
#                                          description category_a category_b  \
# 0                             user 有proE 的問題  #17936    R&D資訊系統     設計相關服務
# 1              進入FTP 只是網頁模式,無法轉換或進入檔案總管模式. 以致無法上傳檔案.    R&D資訊系統       專案管理
# 2         線上系統觀看前要下載Media Player 無法執行請協助處理.EXT:12633     內部資訊系統     人資資訊系統
# 3                                         保管人的地方無法輸入    BPM平台系統    事務類相關服務
# 4  QITS(NB4) ZHN 的 Notice mail 系統一次會發出 3 封信, RD 那...    R&D資訊系統     測試相關服務
#
#                        category_c        category_d category  \
# 0  【Design Tool】Pro/E、OrCAD設計工具管理            相關操作詢問  R&D資訊系統
# 1                     【PMS】專案管理系統            相關操作詢問  R&D資訊系統
# 2                        廣達學院相關服務  e-Learning系統相關問題   內部資訊系統
# 3                        電腦外帶證申請單            相關操作詢問  BPM平台系統
# 4                  【QITS】研發議題追蹤系統            相關操作詢問  R&D資訊系統
#
#                                    description_clean  category_target  \
# 0                                          有proe 的問題                1
# 1                    進入ftp 網頁模式無法轉換或進入檔案總管模式. 無法上傳檔案                1
# 2                        線上系統觀看前要下載media player 無法執行                2
# 3                                           人的地方無法輸入                0
# 4  qitsnb4 zhn 的 notice mail 系統一次會發出封信 rd 也一次收到三封...                1
#
#                                            cut_words
# 0                                            proe,問題
# 1                  進入,ftp,網頁,模式,轉換,進入,檔案,總管,模式,上傳,檔案
# 2                     線上,系統,觀看,前要,下載,media,player,執行
# 3                                            人,地方,輸入
# 4  qitsnb4,zhn,notice,mail,系統,一次會,發出,封信,rd,一次,收到,...

# %%
df_all[3040:4010]
# Out:
# Empty DataFrame
# Columns: [description, category_a, category_b, category_c, category_d, category, description_clean, category_target, cut_words]
# Index: []

# %%
# 切分資料
X = df_all['cut_words']
y = df_all['category_target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 40)

# %%
X_train.head()
# Out:
# 880                         表示,填單,最,只能,填,20,填去,還會,跳,錯誤,訊息
# 369     因應,sit1,許多,新,客戶,公司,需要,增加,下麵,客戶,公司,名稱,qits,系統,a...
# 284                                                 開出,放行
# 1300    1,qits,欲,新增,report,report,篩選,條件,中,設定,project,n...
# 954                                              點選,請假,作業
# Name: cut_words, dtype: object

# %%
# label 做 onehot
y_train_one_hot = np_utils.to_categorical(y_train)
y_val_one_hot = np_utils.to_categorical(y_val)
print (y_train_one_hot[0])
print (y_val_one_hot[0])
# 總共類別數
num_classes = len((y_train_one_hot[0]))
print ('num_classes = {}'.format(num_classes))
# Out:
# [1. 0. 0.]
# [0. 0. 1.]
# num_classes = 3

# %%
# # 標點符號過濾
# WORD_FILTERS = '!"#$&()*+,-./:;<=>?@[\\]^_{|}~\t\n'
# 字典數量
NUM_WORDS = 5001
# 向量長度
MAX_LEN = 30

token_intent = Tokenizer(num_words=NUM_WORDS,
                        split=",")
# token_intent = Tokenizer(filters=WORD_FILTERS,
#                         num_words=NUM_WORDS,
#                         split=",")

# 斷詞後全部合併丟到fit_on_texts,組出字典
token_intent.fit_on_texts(X_train)
token_intent.fit_on_texts(X_val)

def preprocessing(x, max_len):

    #將文字轉為數字序列
    train_seq_intent = token_intent.texts_to_sequences(x)

    # 截長補短，讓所有數字序列長度一樣
    data = sequence.pad_sequences(train_seq_intent, maxlen=MAX_LEN)
    # print train_data_intent.shape
    return data

x_train = preprocessing(X_train, max_len=MAX_LEN)
x_val = preprocessing(X_val, max_len=MAX_LEN)

# %%
x_train
# Out:
# array([[   0,    0,    0, ...,  588,    5,   12],
#        [  96,   22,  297, ..., 1459,  195,  939],
#        [   0,    0,    0, ...,    0, 1460,   86],
#        ...,
#        [   0,    0,    0, ...,   19,    1,    5],
#        [   0,    0,    0, ...,  197, 2953,  342],
#        [   0,    0,    0, ..., 2956, 2957, 2958]], dtype=int32)

# %%
# set parameters:
max_features = 5001
maxlen = 100
batch_size = 20
embedding_dims = 50
filters = 100
kernel_size = 10
hidden_dims = 250
epochs = 10
train_ratio = 0.9

# %%
from keras.layers import Layer
def dot_product(x, kernel):
    """
    Wrapper for dot product operation, in order to be compatible with both
    Theano and Tensorflow
    Args:
        x (): input
        kernel (): weights
    Returns:
    """
    if K.backend() == 'tensorflow':
        return K.squeeze(K.dot(x, K.expand_dims(kernel)), axis=-1)
    else:
        return K.dot(x, kernel)
 
 
class AttentionWithContext(Layer):
    """
    Attention operation, with a context/query vector, for temporal data.
    Supports Masking.
    Follows the work of Yang et al. [https://www.cs.cmu.edu/~diyiy/docs/naacl16.pdf]
    "Hierarchical Attention Networks for Document Classification"
    by using a context vector to assist the attention
    # Input shape
        3D tensor with shape: `(samples, steps, features)`.
    # Output shape
        2D tensor with shape: `(samples, features)`.
    How to use:
    Just put it on top of an RNN Layer (GRU/LSTM/SimpleRNN) with return_sequences=True.
    The dimensions are inferred based on the output shape of the RNN.
    Note: The layer has been tested with Keras 2.0.6
    Example:
        model.add(LSTM(64, return_sequences=True))
        model.add(AttentionWithContext())
        # next add a Dense layer (for classification/regression) or whatever...
    """
 
    def __init__(self,
                 W_regularizer=None, u_regularizer=None, b_regularizer=None,
                 W_constraint=None, u_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
 
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')
 
        self.W_regularizer = regularizers.get(W_regularizer)
        self.u_regularizer = regularizers.get(u_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)
 
        self.W_constraint = constraints.get(W_constraint)
        self.u_constraint = constraints.get(u_constraint)
        self.b_constraint = constraints.get(b_constraint)
 
        self.bias = bias
        super(AttentionWithContext, self).__init__(**kwargs)
 
    def build(self, input_shape):
        assert len(input_shape) == 3
 
        self.W = self.add_weight((input_shape[-1], input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        if self.bias:
            self.b = self.add_weight((input_shape[-1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
 
        self.u = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_u'.format(self.name),
                                 regularizer=self.u_regularizer,
                                 constraint=self.u_constraint)
 
        super(AttentionWithContext, self).build(input_shape)
 
    def compute_mask(self, input, input_mask=None):
        # do not pass the mask to the next layers
        return None
 
    def call(self, x, mask=None):
        uit = dot_product(x, self.W)
 
        if self.bias:
            uit += self.b
 
        uit = K.tanh(uit)
        ait = dot_product(uit, self.u)
 
        a = K.exp(ait)
 
        # apply mask after the exp. will be re-normalized next
        if mask is not None:
            # Cast the mask to floatX to avoid float64 upcasting in theano
            a *= K.cast(mask, K.floatx())
 
        # in some cases especially in the early stages of training the sum may be almost zero
        # and this results in NaN's. A workaround is to add a very small positive number ε to the sum.
        # a /= K.cast(K.sum(a, axis=1, keepdims=True), K.floatx())
        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())
 
        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)
 
    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[-1]

# %%
# https://www.kaggle.com/qqgeogor/keras-lstm-attention-glove840b-lb-0-043
from keras.engine.topology import Layer
from keras import initializers, regularizers, constraints
from keras import backend as K
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
#75.95%
from keras.layers import core,BatchNormalization
from keras.layers import CuDNNLSTM
def BidCuDNNLSTM2(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
#     model.add(GRU(128))
    model.add(Bidirectional(CuDNNLSTM(32)))#, return_sequences=True
#    model.add(Attention(30))
#     model.add(Bidirectional(LSTM(128,implementation=2)))
    model.add(Dropout(0.5))
    model.add(Dense(16,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#84.7%,88.29%
def BidLSTM_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(LSTM(32,implementation=2, return_sequences=True))
    model.add(AttentionWithContext())
    #model.add(Flatten())
    #model.add(Dense(64,activation='tanh'))
    model.add(Dense(16,activation='relu'))
    model.add(Dropout(0.5))
    #model.add(Dense(50,activation='tanh'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#75.5%,80.9%,82%,72%
def BidLSTM(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(Bidirectional(LSTM(32,implementation=2)))
    #model.add(Attention(30))
    #model.add(Flatten())
    #model.add(Dense(64,activation='tanh'))
    model.add(Dense(16,activation='relu'))
    model.add(Dropout(0.5))
    #model.add(Dense(50,activation='tanh'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#77%
def BidCuDNNLSTM2_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
#     model.add(GRU(128))
    model.add(Bidirectional(CuDNNLSTM(32, return_sequences=True)))#
    model.add(AttentionWithContext())
#     model.add(Bidirectional(LSTM(128,implementation=2)))
    model.add(Dropout(0.75))
    model.add(Dense(16,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#74.8%
def build_model(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
#     model.add(GRU(128))
    model.add(Bidirectional(LSTM(32)))
#     model.add(Bidirectional(LSTM(128,implementation=2)))
    model.add(Dropout(0.75))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#79%,80.53%,75.59%,75.57%,77.8%,81.6%,82.4%,85.6%
#sap, 83.9%
def GRU2(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(Bidirectional(GRU(128)))#return_sequences=True
    #CuDNNGRU-64, GRU-32
    #model.add(Conv1D(32, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform"))
    #model.add(Attention(29))
    model.add(Dropout(0.75))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#70.2%,80.53%,83.65%
def GRU2_Attention(num_classes, vocab_size, sentence_max_len,embedding_dim):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=sentence_max_len))
    model.add(Bidirectional(CuDNNGRU(32,return_sequences=True)))#
    model.add(Conv1D(64, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform"))
    model.add(AttentionWithContext())
    model.add(Dropout(0.75))
    model.add(Dense(32,activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()
    return model

# %%
#69.08%
#https://github.com/jdp527/DL_Text_Classification/blob/master/models/gpu_model.py
#https://aclweb.org/anthology/C16-1329
def blstm_2dcnn(num_classes, max_features, maxlen,embed_size,
               embedding_dropout = .5,
               blstm_units = 256,
               blstm_dropout = .2,
               cnn_filters = 64,
               cnn_kernel_size = (5,5),
               max_pool_size = (5,5),
               dense_dropout = .5,
               l2_reg = .00001,
               gpus = 1):
    
    '''
    Bidirectional LSTM with Two-dimensional Max Pooling
    
    :param maxlen: max length of sequence
    :param max_features: max number of word embeddings
    :param embed_size: dimension of word embeddings
    :param embedding_matrix: embedding matrix created from embed file
    :param embedding_dropout: dropout after embedding layer
    :param blstm_units: number of lstm units for the biderectional lstm
    :param blstm_dropout: dropout after the blstm layer
    :param cnn_filters: number of CNN filters
    :param cnn_kernel_size: kernel size of the convolution
    :param max_pool_size: max pool size
    :param dense_dropout: dropout before dense layer
    :param l2_reg: l2 kernel regularizer parameter
    :gpus: number of gpus
    :returns: Keras parallel model
    '''
    
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size, #weights=[embedding_matrix], 
                  input_length=maxlen)(inp)
    x = Dropout(embedding_dropout)(x)    

    x = Bidirectional(LSTM(blstm_units, return_sequences=True), merge_mode='sum')(x)
    x = Dropout(blstm_dropout)(x)
    x = Reshape((maxlen, blstm_units, 1))(x)

    x = Conv2D(cnn_filters, kernel_size=cnn_kernel_size, padding='valid', kernel_initializer='glorot_uniform')(x)
    x = MaxPool2D(pool_size=max_pool_size)(x)

    x = Flatten()(x)
    x = Dropout(dense_dropout)(x)
    x = Dense(num_classes, activation = "softmax",  kernel_regularizer=regularizers.l2(l2_reg))(x)
    
    parallel_model = Model(inputs = inp, outputs = x)
    #parallel_model = multi_gpu_model(parallel_model, gpus=gpus)
    parallel_model.summary()
    return parallel_model
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database',)).History will not be written to the database.

# %%
#75.7%, 77.8%,77.8%
def bgru_2dcnn(num_classes, max_features, maxlen,embed_size,
               embedding_dropout = .5,
               bgru_units = 256,
               bgru_dropout = .2,
               cnn_filters = 64,
               cnn_kernel_size = (5,5),
               max_pool_size = (5,5),
               dense_dropout = .5,
               l2_reg = .00001,
               gpus = 2):
    
    '''
    Bidirectional GRU with Two-dimensional Max Pooling
    
    :param maxlen: max length of sequence
    :param max_features: max number of word embeddings
    :param embed_size: dimension of word embeddings
    :param embedding_matrix: embedding matrix created from embed file
    :param embedding_dropout: dropout after embedding layer
    :param bgru_units: number of gru units for the biderectional gru
    :param bgru_dropout: dropout after the bgru layer
    :param cnn_filters: number of cnn filters
    :param cnn_kernel_size: kernel size of the convolution
    :param max_pool_size: max pool size
    :param dense_dropout: dropout before dense layer
    :param l2_reg: l2 kernel regularizer parameter
    :gpus: number of gpus
    :returns: Keras parallel model
    '''
    
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size, #weights=[embedding_matrix], 
                  input_length=maxlen)(inp)
    x = Dropout(embedding_dropout)(x)    

    x = Bidirectional(GRU(bgru_units, return_sequences=True), merge_mode='sum')(x)
    x = Dropout(bgru_dropout)(x)
    x = Reshape((maxlen, bgru_units, 1))(x)

    x = Conv2D(cnn_filters, kernel_size=cnn_kernel_size, padding='valid', kernel_initializer='glorot_uniform')(x)
    x = MaxPool2D(pool_size=max_pool_size)(x)

    x = Flatten()(x)
    x = Dropout(dense_dropout)(x)
    x = Dense(num_classes, activation = "softmax",  kernel_regularizer=regularizers.l2(l2_reg))(x)
    
    parallel_model = Model(inputs = inp, outputs = x)
    #parallel_model = multi_gpu_model(parallel_model, gpus=gpus)
    #parallel_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return parallel_model

# %%
model = GRU2(num_classes, NUM_WORDS, MAX_LEN,32)
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 30, 32)            160032
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               123648
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 292,003
# Trainable params: 292,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_path = '{}.h5'.format('19999_rnn')

epochs = 50
batch_size = 32
train_ratio = 0.9

checkpoint = ModelCheckpoint(model_path, monitor='val_acc', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=6, verbose=1)

model_history = model.fit(x=x_train, y=y_train_one_hot,
                            batch_size=batch_size, 
                            epochs=epochs,
                            validation_split= 1 - train_ratio,
                            callbacks = [checkpoint, earlystop])
# Out:
# Train on 961 samples, validate on 107 samples
# Epoch 1/50
# 961/961 [==============================] - 4s 4ms/step - loss: 1.0587 - acc: 0.4776 - val_loss: 1.0614 - val_acc: 0.4766
#
# Epoch 00001: val_acc improved from -inf to 0.47664, saving model to 19999_rnn.h5
# Epoch 2/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.9941 - acc: 0.5088 - val_loss: 0.9791 - val_acc: 0.5514
#
# Epoch 00002: val_acc improved from 0.47664 to 0.55140, saving model to 19999_rnn.h5
# Epoch 3/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.7330 - acc: 0.6753 - val_loss: 1.0463 - val_acc: 0.6542
#
# Epoch 00003: val_acc improved from 0.55140 to 0.65421, saving model to 19999_rnn.h5
# Epoch 4/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.5361 - acc: 0.7399 - val_loss: 0.7563 - val_acc: 0.6262
#
# Epoch 00004: val_acc did not improve from 0.65421
# Epoch 5/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.3902 - acc: 0.8096 - val_loss: 0.7209 - val_acc: 0.7009
#
# Epoch 00005: val_acc improved from 0.65421 to 0.70093, saving model to 19999_rnn.h5
# Epoch 6/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.2781 - acc: 0.8918 - val_loss: 0.8125 - val_acc: 0.7009
#
# Epoch 00006: val_acc improved from 0.70093 to 0.70093, saving model to 19999_rnn.h5
# Epoch 7/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.1884 - acc: 0.9376 - val_loss: 1.1377 - val_acc: 0.7009
#
# Epoch 00007: val_acc did not improve from 0.70093
# Epoch 8/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.2189 - acc: 0.9230 - val_loss: 0.8469 - val_acc: 0.7196
#
# Epoch 00008: val_acc improved from 0.70093 to 0.71963, saving model to 19999_rnn.h5
# Epoch 9/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.1291 - acc: 0.9667 - val_loss: 0.9261 - val_acc: 0.7383
#
# Epoch 00009: val_acc improved from 0.71963 to 0.73832, saving model to 19999_rnn.h5
# Epoch 10/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.0994 - acc: 0.9667 - val_loss: 0.9360 - val_acc: 0.7103
#
# Epoch 00010: val_acc did not improve from 0.73832
# Epoch 11/50
# 961/961 [==============================] - 2s 2ms/step - loss: 0.0796 - acc: 0.9771 - val_loss: 1.2169 - val_acc: 0.7009
#
# Epoch 00011: val_acc did not improve from 0.73832
# Epoch 00011: early stopping

# %%
from keras import models 
model=models.load_model(model_path)

# %%
# %pylab inline
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['add', 'concatenate']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
show_train_history(model_history,'acc','val_acc')

# %%
show_train_history(model_history,'loss','val_loss')

# %%
def to_cat_name(x): 
        return mapping[x]
    
def predict(test):
#     model = load_model(model_path)
    y_predict_probability = model.predict(test)
    y_predict = model.predict_classes(test)

    return to_cat_name(y_predict), y_predict, y_predict_probability

def predict_class(data):
    y_predict_probability = model.predict(data, batch_size=64, verbose=1)
    predict_arr = []
    predictClass = []
    for row in y_predict_probability: 
            classIndex=0
            selectClass=0
            selectProbability=0
            for item in row: 
                #print(float(item))
                if(selectProbability <= float(item)):
                    #print(classIndex)
                    selectProbability=float(item)
                    selectClass=classIndex
                classIndex=classIndex+1
            predictClass.append(selectClass)
            
    return to_cat_name(predictClass),predictClass,y_predict_probability

y_predict_name, y_predict, y_predict_probability = predict_class(x_val)
# Out:
# 268/268 [==============================] - 0s 1ms/step

# %%
answer_name = to_cat_name(y_val)

# %%
#model.predict_classes(x_val)

# %%
x_val
# Out:
# array([[   0,    0,    0, ...,   12,  145, 2963],
#        [   0,    0,    0, ...,  251,  801,   64],
#        [   0,    0,    0, ...,  127,  207,  609],
#        ...,
#        [   0,    0,    0, ...,   52,    1,   26],
#        [   0,    0,    0, ...,  100,   16, 3256],
#        [ 883,   85, 3270, ...,   76, 1449,  311]], dtype=int32)

# %%
mapping
# Out:
# Index(['BPM平台系統', 'R&D資訊系統', '內部資訊系統'], dtype='object')

# %%
# model.predict(x_val)

# %%
# predict_df = pd.DataFrame({'1_sentence':df_test.sentence,
#               '2_y_predict':y_predict,
#               '3_y_predict_name':y_predict_name,
#               '4_answer':df_test.target,
#               '5_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
predict_df = pd.DataFrame({
              '1_sentence':X_val,
              '2_y_predict':y_predict,
              '3_y_predict_name':y_predict_name,
              '4_answer':y_val,
              '5_answer_name':answer_name,
              '6_y_predict_probability':list(y_predict_probability)})
# predict_df

# %%
# accuracy
accuracy = 1 - (float(len(predict_df[predict_df['2_y_predict'] != predict_df['4_answer']])))/(len(predict_df))
print ('accuracy : {} !!!!!!!!'.format(accuracy))
# Out:
# accuracy : 0.708955223880597 !!!!!!!!

# %%
predict_df[predict_df['2_y_predict'] != predict_df['4_answer']]
# Out:
#                                              1_sentence  2_y_predict  \
# 994                              新增,廠區,別於,維護,account,頁面            2
# 829                     號碼,bpm,非,標單,進入,系統,一片空白,試連,項目,正常            2
# 56                                       ie,顯示,停止,作業,撥放            0
# 821              填寫,績效,考核表,step,2,出現,輸入,帳號密碼,畫面,請,協助,排除            0
# 1201                 1,ie,顯示,問題,2,加入,成員,看到,資訊,檢查,通訊錄,資料            0
# 1025                                     查不到,mrb,申請單,ap            0
# 474                            轉單,位,後,已經,轉給,收到,沖銷,平臺,訊息            2
# 71                            操作,會議,事,單日,預約,功能,跳出,錯誤,訊息            0
# 42    加班,系統,問題,9,21,應該,9,月份,週期,加班,系統,show,訊息,下個月,判斷,...            0
# 361            大廳,反應,會議室,系統,幾天,異常,慢,0105,台,server,切換,問題            0
# 492       新增,機器,選,department,機器,建,機器,清單,看不到,機器,重建,重覆,sn            2
# 1161                      加入,簽核,後,系統,發,mail,提醒,需要,重新,簽核            2
# 110       fixed,available,date,日期,下拉,選單,目前,只能,選,年增,後,選單            2
# 277                             myehr,系統,時,跳出,帳號密碼,輸入,後            0
# 932                                            申請,pm,權限            2
# 900                                         電腦,外帶,攜出,列印            0
# 861                                       登入,系統,後,操作,異常            2
# 989                反映,plm,系統,忘記,密碼,問題,酖,找到,系統分類,任意,選,一個            1
# 1009               gams,系統,公務車,申請單,系統,告知,沒填,日期,已經,點選,日期            0
# 623                                     app58,無,法規,檔,列印            2
# 468                        影片,播放,到,一半,顯示,media,問題,繼續,播放            0
# 816                               bpm,網路,正常,系統,出勤,系統,登入            2
# 1038                                  組織,變更,cost,center            2
# 723                                   進入,網站,跳出,帳號,輸入,視窗            0
# 198                             項目,自動,展延,不知,是否,系統,做過,更新            2
# 481                           放行,頁面,print,鈕,下載,pdf,檔,放行            1
# 376                                            登入後,無,畫面            0
# 627                                  詢問,bpm,custom,data            2
# 741             jre8,安裝,安裝,完畢,顯示,無,安裝,agile,料號,申請,串,bom            2
# 14    以下,單號,簽核,人員,人員,請,刪除,app96,app90,app91,app92,ap...            2
# ...                                                 ...          ...
# 1137  3,11,申請,訪客,無線網路,單號,3,12,訪客,登入,今日,3,19,已,澄清,是否,...            2
# 366   report,下載,時,中文,副,檔,下載,後,顯示,亂碼,測試,管理,平臺,phase,i...            2
# 181   訪客,申請,無線網路,帳號密碼,系統,機,導致,原,訪客,申請單,訪客,申請單,通知單,號,...            1
# 1269                   mro,簽核,原本,應該,要選,同意,小心,選到,意,是否,簽核            2
# 1                     進入,ftp,網頁,模式,轉換,進入,檔案,總管,模式,上傳,檔案            2
# 425                                               myplm            2
# 848   myquanta,intrasystem,沖銷,平臺,請問,系統,發生,問題,找,哪一位,負...            2
# 520                                qex,使用,彈出,輸入,帳號密碼,畫面            0
# 683                                            出現,登入,失敗            2
# 895              加班,特別,申請,作業,頁面,出勤,紀錄,加班,補登,預報,加班,作業,正常            1
# 1179              填寫,旅費,申報單,時,選擇,比例,分攤,按下,新增,分攤,項目,後,系統            2
# 304                                     選取,到,新,加入,部門,人員            2
# 1270                                        myquanta,顯示            2
# 902   請問,qdsm,系統,1,是否,多筆,資料,一起,刪除,2,請問,之前,歸還,物品,mail...            2
# 958                                       輸入,資料,後,發生,錯誤            2
# 386                             參中,專案,閱覽,專案,內容,收到,信件,通知            2
# 585          ebooking,系統,設定,每日,預約,總和,提醒,現,發現,預約,未,收到,提醒            2
# 668                                           福委會,網站,分棧            0
# 1236                                建立,新,class,subclass            2
# 1081  sibu,gm,要求,si,申請單,簽核,流程,應為,智慧,輸入,產品,事業部,業務部,業務...            2
# 1029                                     新增,bu3,bios,人員            2
# 222                       proe,使用,中,跳出來,加,ram,8g,還會,跳出來            2
# 1312                                   請求,恊,助,行動,bpm,簽核            0
# 560                                      app01,流程,錯誤,導致            0
# 1075                 需要,8,28,申請,電腦,外帶,申請單,app84,做,刪除,動作            2
# 807                  pdm,簽核,附件,內容,使用,web,java,version,皆            2
# 482                                   出勤,系統,選單,下載,出勤,紀錄            1
# 144                                           交通車,正常,申請            0
# 547                             更新,上傳,檔案,時會,問題,程式,直接,結束            2
# 796   發票,費用,作業,時,網頁,只,選取,第一個,項目,取消,發票,重新,作業,發票,號碼,zc,zc            2
#
#      3_y_predict_name  4_answer 5_answer_name  \
# 994            內部資訊系統         1       R&D資訊系統
# 829            內部資訊系統         0       BPM平台系統
# 56            BPM平台系統         2        內部資訊系統
# 821           BPM平台系統         2        內部資訊系統
# 1201          BPM平台系統         1       R&D資訊系統
# 1025          BPM平台系統         2        內部資訊系統
# 474            內部資訊系統         0       BPM平台系統
# 71            BPM平台系統         2        內部資訊系統
# 42            BPM平台系統         2        內部資訊系統
# 361           BPM平台系統         2        內部資訊系統
# 492            內部資訊系統         1       R&D資訊系統
# 1161           內部資訊系統         0       BPM平台系統
# 110            內部資訊系統         1       R&D資訊系統
# 277           BPM平台系統         2        內部資訊系統
# 932            內部資訊系統         1       R&D資訊系統
# 900           BPM平台系統         2        內部資訊系統
# 861            內部資訊系統         1       R&D資訊系統
# 989           R&D資訊系統         0       BPM平台系統
# 1009          BPM平台系統         2        內部資訊系統
# 623            內部資訊系統         0       BPM平台系統
# 468           BPM平台系統         2        內部資訊系統
# 816            內部資訊系統         0       BPM平台系統
# 1038           內部資訊系統         0       BPM平台系統
# 723           BPM平台系統         2        內部資訊系統
# 198            內部資訊系統         0       BPM平台系統
# 481           R&D資訊系統         0       BPM平台系統
# 376           BPM平台系統         1       R&D資訊系統
# 627            內部資訊系統         0       BPM平台系統
# 741            內部資訊系統         1       R&D資訊系統
# 14             內部資訊系統         0       BPM平台系統
# ...               ...       ...           ...
# 1137           內部資訊系統         0       BPM平台系統
# 366            內部資訊系統         1       R&D資訊系統
# 181           R&D資訊系統         0       BPM平台系統
# 1269           內部資訊系統         0       BPM平台系統
# 1              內部資訊系統         1       R&D資訊系統
# 425            內部資訊系統         1       R&D資訊系統
# 848            內部資訊系統         1       R&D資訊系統
# 520           BPM平台系統         2        內部資訊系統
# 683            內部資訊系統         1       R&D資訊系統
# 895           R&D資訊系統         2        內部資訊系統
# 1179           內部資訊系統         0       BPM平台系統
# 304            內部資訊系統         1       R&D資訊系統
# 1270           內部資訊系統         1       R&D資訊系統
# 902            內部資訊系統         1       R&D資訊系統
# 958            內部資訊系統         0       BPM平台系統
# 386            內部資訊系統         1       R&D資訊系統
# 585            內部資訊系統         1       R&D資訊系統
# 668           BPM平台系統         2        內部資訊系統
# 1236           內部資訊系統         1       R&D資訊系統
# 1081           內部資訊系統         0       BPM平台系統
# 1029           內部資訊系統         1       R&D資訊系統
# 222            內部資訊系統         1       R&D資訊系統
# 1312          BPM平台系統         2        內部資訊系統
# 560           BPM平台系統         2        內部資訊系統
# 1075           內部資訊系統         0       BPM平台系統
# 807            內部資訊系統         1       R&D資訊系統
# 482           R&D資訊系統         2        內部資訊系統
# 144           BPM平台系統         2        內部資訊系統
# 547            內部資訊系統         1       R&D資訊系統
# 796            內部資訊系統         0       BPM平台系統
#
#                          6_y_predict_probability
# 994         [0.05427688, 0.030253474, 0.9154697]
# 829       [0.00096033147, 0.34320694, 0.6558327]
# 56         [0.8400089, 0.0009935348, 0.15899757]
# 821     [0.98770475, 5.8712194e-05, 0.012236515]
# 1201        [0.52009356, 0.00576103, 0.47414538]
# 1025     [0.9885492, 4.0012896e-05, 0.011410697]
# 474            [0.1504972, 0.01764678, 0.831856]
# 71         [0.8997158, 0.0006210501, 0.09966327]
# 42        [0.9934036, 7.606961e-05, 0.006520422]
# 361         [0.558242, 0.0049886396, 0.43676934]
# 492       [0.092398524, 0.023303468, 0.88429797]
# 1161        [0.25147986, 0.010775474, 0.7377446]
# 110       [0.0005905972, 0.42884064, 0.57056874]
# 277         [0.5637515, 0.004029546, 0.43221888]
# 932        [0.022058709, 0.06444108, 0.91350025]
# 900      [0.97121304, 9.273744e-05, 0.028694192]
# 861         [0.01788173, 0.036223788, 0.9458944]
# 989     [2.3180212e-08, 0.9940352, 0.0059648445]
# 1009       [0.7993732, 0.0015292203, 0.19909756]
# 623         [0.14276822, 0.016209157, 0.8410227]
# 468     [0.95168084, 0.00020501191, 0.048114147]
# 816       [0.00054781843, 0.42214578, 0.5773064]
# 1038        [0.2756711, 0.015780227, 0.70854867]
# 723        [0.9223322, 0.0004663933, 0.07720137]
# 198        [0.008538367, 0.092827864, 0.8986338]
# 481       [0.00016812644, 0.5997324, 0.40009946]
# 376       [0.67420924, 0.0026905339, 0.32310018]
# 627         [0.08955452, 0.04932077, 0.86112463]
# 741        [0.047025964, 0.033898428, 0.9190756]
# 14           [0.050829124, 0.0262336, 0.9229373]
# ...                                          ...
# 1137        [0.22378859, 0.013786985, 0.7624244]
# 366         [0.004933953, 0.12768883, 0.8673772]
# 181     [1.7051393e-08, 0.9957135, 0.0042865877]
# 1269      [0.00056996517, 0.33520976, 0.6642203]
# 1            [0.00566222, 0.11745954, 0.8768782]
# 425        [0.16139653, 0.020520063, 0.81808335]
# 848       [0.00033209744, 0.44479483, 0.5548731]
# 520       [0.9382347, 0.0002595826, 0.061505686]
# 683        [0.18858472, 0.013310258, 0.79810506]
# 895       [1.8412798e-05, 0.8313983, 0.16858321]
# 1179         [0.4470841, 0.00743728, 0.54547864]
# 304         [0.020261073, 0.049229965, 0.930509]
# 1270       [0.007578875, 0.08779503, 0.90462613]
# 902       [0.0010866383, 0.33975685, 0.65915656]
# 958          [0.2575381, 0.011538676, 0.7309232]
# 386        [0.0011015604, 0.24336371, 0.7555347]
# 585        [0.0005314906, 0.37287328, 0.6265952]
# 668        [0.73558694, 0.0019927525, 0.2624203]
# 1236       [0.09102481, 0.024220992, 0.88475424]
# 1081        [0.44060603, 0.020319875, 0.5390741]
# 1029       [0.14848112, 0.019486764, 0.83203214]
# 222        [0.015367562, 0.040285967, 0.9443465]
# 1312  [0.99942267, 5.9131037e-07, 0.00057673117]
# 560        [0.9720987, 0.0001211609, 0.02778006]
# 1075        [0.0468297, 0.038681146, 0.91448915]
# 807         [0.00876919, 0.09717215, 0.89405864]
# 482      [6.4307545e-07, 0.9684608, 0.031538453]
# 144       [0.9857594, 4.844048e-05, 0.014192287]
# 547        [0.0035510536, 0.15093967, 0.8455093]
# 796        [0.4188333, 0.0072364653, 0.57393026]
#
# [78 rows x 6 columns]

# %%
# confusion matrix
pd.crosstab(np.array(y_predict_name), np.array(answer_name),
            rownames=['predict'], colnames=['answer'])
# Out:
# answer   BPM平台系統  R&D資訊系統  內部資訊系統
# predict
# BPM平台系統       92        2      20
# R&D資訊系統        5       50       3
# 內部資訊系統        22       26      48

# %%
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)
# model.save_weights("model.h5")
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")
# loaded_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# score = loaded_model.evaluate(x_test, y_test, verbose=0)
# print(score)
